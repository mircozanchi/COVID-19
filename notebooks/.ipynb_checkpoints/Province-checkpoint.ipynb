# %%
import pandas as pd
import sys
import datetime
import matplotlib.pylab as plt
import numpy as np
from math import log, floor, ceil
from typing import Dict

# %%
START_DATE = datetime.date(2020,2,24)

# %%
def create_filename(day_str: str) -> str:
    return ('../dati-province/dpc-covid19-ita-province-' + day_str + '.csv')

# %%
def handle_Toscana_20200326_error(cases: Dict[str, int]) -> Dict[str, int]:
    cases['20200327'] = cases['20200326'] + floor((cases['20200328'] - cases['20200326'])/2)
    cases['20200328'] = cases['20200327'] + ceil((cases['20200328'] - cases['20200326'])/2)
    return cases

# %%
def calculate_and_create_chart_for_province(start_date: datetime.date, province: str):
    day = start_date
    cases: Dict[str,int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]==province]["totale_casi"])
        day: datetime.date = day + datetime.timedelta(days = 1)
    
    if df[df["denominazione_provincia"]==province]["denominazione_regione"].any()=='Toscana':
        cases = handle_Toscana_20200326_error(cases)
    
    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases per 1000 inhabitants up to today:", round(calculate_cases_to_inhabitants_ratio(cases_df_today, province),4))
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_region(start_date: datetime.date, region: str):
    day: datetime.date = start_date
    cases: Dict[str, int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[(df["denominazione_regione"]==region)&(df["denominazione_provincia"]!='In fase di definizione/aggiornamento')]["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)
        
    if region == 'Toscana':
        cases = handle_Toscana_20200326_error(cases)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_Italy(start_date: datetime.date):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]!='In fase di definizione/aggiornamento']["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)

    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_stats(cases_df):
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    cases_df_yesterday = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 1)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_five_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 5)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_six_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 6)).strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases up to today:", cases_df_today)
    print("New cases registered today:", cases_df_today-cases_df_yesterday)
    if int(cases_df_yesterday) != 0:
        print("New cases registered today in %:", round((cases_df_today-cases_df_yesterday)/cases_df_yesterday*100,2))

    print("Doubling time in the last five days:", round(calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago), 1))
    print("Doubling time yesterday:", round(calculate_doubling_time_in_the_last_five_days(cases_df_yesterday, cases_df_six_days_ago), 1))
    print("Trend of new cases (in %) in the last 5 days:", round((cases_df_today-cases_df_five_days_ago)/cases_df_five_days_ago*100,2))
    
    return

# %%
def calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago):
    if cases_df_five_days_ago ==0:
        return np.nan
    log_result = log(cases_df_today/cases_df_five_days_ago)
    if log_result != 0:
        return (5*log(2))/(log_result)
    else:
        return np.nan

# %%
def calculate_cases_to_inhabitants_ratio(cases: int, province: str) -> float:
    df_province: pd.DataFrame = pd.read_csv("../general/province.csv")
    inhabitants = df_province[df_province["Provincia"]==province]["Residenti"].str.replace('.', '', regex=True).sum()
    return int(cases)/int(inhabitants)*1000

# %% [markdown]
# # Casi di COVID-19 in Italia - COVID-19 cases in Italy

# %%
calculate_and_create_chart_for_Italy(START_DATE)
# Out:
# Total cases up to today: 129604
# New cases registered today: 3508
# New cases registered today in %: 2.78
# Doubling time in the last five days: 18.1
# Doubling time yesterday: 16.7
# Trend of new cases (in %) in the last 5 days: 21.12

# %% [markdown]
# # Casi di COVID-19 in Abruzzo - COVID-19 cases in Abruzzo

# %%
calculate_and_create_chart_for_region(START_DATE, 'Abruzzo')
# Out:
# Total cases up to today: 1721
# New cases registered today: 18
# New cases registered today in %: 1.06
# Doubling time in the last five days: 19.1
# Doubling time yesterday: 17.8
# Trend of new cases (in %) in the last 5 days: 19.85

# %% [markdown]
# ## Chieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Chieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8403
# Total cases up to today: 327
# New cases registered today: 2
# New cases registered today in %: 0.62
# Doubling time in the last five days: 30.6
# Doubling time yesterday: 23.3
# Trend of new cases (in %) in the last 5 days: 11.99

# %% [markdown]
# ## L'Aquila

# %%
calculate_and_create_chart_for_province(START_DATE, "L'Aquila")
# Out:
# Total cases per 1000 inhabitants up to today: 0.6061
# Total cases up to today: 183
# New cases registered today: 4
# New cases registered today in %: 2.23
# Doubling time in the last five days: 9.7
# Doubling time yesterday: 9.2
# Trend of new cases (in %) in the last 5 days: 42.97

# %% [markdown]
# ## Pescara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pescara')
# Out:
# Total cases per 1000 inhabitants up to today: 2.2657
# Total cases up to today: 728
# New cases registered today: 1
# New cases registered today in %: 0.14
# Doubling time in the last five days: 24.2
# Doubling time yesterday: 22.2
# Trend of new cases (in %) in the last 5 days: 15.37

# %% [markdown]
# ## Teramo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Teramo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5588
# Total cases up to today: 483
# New cases registered today: 11
# New cases registered today in %: 2.33
# Doubling time in the last five days: 15.3
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 25.45

# %% [markdown]
# # Casi di COVID-19 in Basilicata - COVID-19 cases in Basilicata

# %%
calculate_and_create_chart_for_region(START_DATE, 'Basilicata')
# Out:
# Total cases up to today: 287
# New cases registered today: 9
# New cases registered today in %: 3.24
# Doubling time in the last five days: 18.1
# Doubling time yesterday: 16.7
# Trend of new cases (in %) in the last 5 days: 21.1

# %% [markdown]
# ## Matera

# %%
calculate_and_create_chart_for_province(START_DATE, 'Matera')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7161
# Total cases up to today: 143
# New cases registered today: 7
# New cases registered today in %: 5.15
# Doubling time in the last five days: 15.3
# Doubling time yesterday: 12.9
# Trend of new cases (in %) in the last 5 days: 25.44

# %% [markdown]
# ## Potenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Potenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3885
# Total cases up to today: 144
# New cases registered today: 2
# New cases registered today in %: 1.41
# Doubling time in the last five days: 22.0
# Doubling time yesterday: 22.8
# Trend of new cases (in %) in the last 5 days: 17.07

# %% [markdown]
# # Casi di COVID-19 nella Provincia Autonoma di Bolzano - COVID-19 cases in Autonomous Province of Bolzano

# %%
calculate_and_create_chart_for_region(START_DATE, 'P.A. Bolzano')
# Out:
# Total cases up to today: 1722
# New cases registered today: 78
# New cases registered today in %: 4.74
# Doubling time in the last five days: 17.8
# Doubling time yesterday: 19.1
# Trend of new cases (in %) in the last 5 days: 21.44

# %% [markdown]
# # Casi di COVID-19 in Calabria - COVID-19 cases in Calabria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Calabria')
# Out:
# Total cases up to today: 815
# New cases registered today: 22
# New cases registered today in %: 2.77
# Doubling time in the last five days: 17.3
# Doubling time yesterday: 18.4
# Trend of new cases (in %) in the last 5 days: 22.19

# %% [markdown]
# ## Catanzaro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catanzaro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4361
# Total cases up to today: 158
# New cases registered today: 1
# New cases registered today in %: 0.64
# Doubling time in the last five days: 28.7
# Doubling time yesterday: 28.5
# Trend of new cases (in %) in the last 5 days: 12.86

# %% [markdown]
# ## Cosenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cosenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3414
# Total cases up to today: 243
# New cases registered today: 13
# New cases registered today in %: 5.65
# Doubling time in the last five days: 13.5
# Doubling time yesterday: 16.3
# Trend of new cases (in %) in the last 5 days: 29.26

# %% [markdown]
# ## Crotone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Crotone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6322
# Total cases up to today: 111
# New cases registered today: 2
# New cases registered today in %: 1.83
# Doubling time in the last five days: 20.8
# Doubling time yesterday: 21.8
# Trend of new cases (in %) in the last 5 days: 18.09

# %% [markdown]
# ## Reggio di Calabria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Reggio di Calabria')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4387
# Total cases up to today: 243
# New cases registered today: 6
# New cases registered today in %: 2.53
# Doubling time in the last five days: 18.3
# Doubling time yesterday: 17.8
# Trend of new cases (in %) in the last 5 days: 20.9

# %% [markdown]
# ## Vibo Valentia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vibo Valentia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3712
# Total cases up to today: 60
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 11.2
# Doubling time yesterday: 11.2
# Trend of new cases (in %) in the last 5 days: 36.36

# %% [markdown]
# # Casi di COVID-19 in Campania - COVID-19 cases in Campania

# %%
calculate_and_create_chart_for_region(START_DATE, 'Campania')
# Out:
# Total cases up to today: 2819
# New cases registered today: 87
# New cases registered today in %: 3.18
# Doubling time in the last five days: 11.7
# Doubling time yesterday: 9.8
# Trend of new cases (in %) in the last 5 days: 34.37

# %% [markdown]
# ## Avellino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Avellino')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8807
# Total cases up to today: 373
# New cases registered today: 18
# New cases registered today in %: 5.07
# Doubling time in the last five days: 9.4
# Doubling time yesterday: 7.7
# Trend of new cases (in %) in the last 5 days: 44.57

# %% [markdown]
# ## Benevento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Benevento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3862
# Total cases up to today: 108
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 12.0
# Doubling time yesterday: 9.9
# Trend of new cases (in %) in the last 5 days: 33.33

# %% [markdown]
# ## Caserta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caserta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3333
# Total cases up to today: 308
# New cases registered today: 8
# New cases registered today in %: 2.67
# Doubling time in the last five days: 13.4
# Doubling time yesterday: 11.3
# Trend of new cases (in %) in the last 5 days: 29.41

# %% [markdown]
# ## Napoli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Napoli')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5047
# Total cases up to today: 1568
# New cases registered today: 36
# New cases registered today in %: 2.35
# Doubling time in the last five days: 11.5
# Doubling time yesterday: 9.2
# Trend of new cases (in %) in the last 5 days: 35.06

# %% [markdown]
# ## Salerno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Salerno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4182
# Total cases up to today: 462
# New cases registered today: 25
# New cases registered today in %: 5.72
# Doubling time in the last five days: 13.9
# Doubling time yesterday: 14.0
# Trend of new cases (in %) in the last 5 days: 28.33

# %% [markdown]
# # Casi di COVID-19 in Emilia Romagna - COVID-19 cases in Emilia Romagna

# %%
calculate_and_create_chart_for_region(START_DATE, 'Emilia Romagna')
# Out:
# Total cases up to today: 0
# New cases registered today: 0
# Doubling time in the last five days: nan
# Doubling time yesterday: nan
# Trend of new cases (in %) in the last 5 days: nan
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in long_scalars
#   del sys.path[0]

# %% [markdown]
# ## Bologna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bologna')
# Out:
# Total cases per 1000 inhabitants up to today: 2.5931
# Total cases up to today: 2617
# New cases registered today: 96
# New cases registered today in %: 3.81
# Doubling time in the last five days: 15.2
# Doubling time yesterday: 13.2
# Trend of new cases (in %) in the last 5 days: 25.58

# %% [markdown]
# ## Ferrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ferrara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.464
# Total cases up to today: 510
# New cases registered today: 22
# New cases registered today in %: 4.51
# Doubling time in the last five days: 7.7
# Doubling time yesterday: 8.2
# Trend of new cases (in %) in the last 5 days: 56.44

# %% [markdown]
# ## Modena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Modena')
# Out:
# Total cases per 1000 inhabitants up to today: 3.8396
# Total cases up to today: 2691
# New cases registered today: 82
# New cases registered today in %: 3.14
# Doubling time in the last five days: 21.9
# Doubling time yesterday: 21.6
# Trend of new cases (in %) in the last 5 days: 17.15

# %% [markdown]
# ## Parma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Parma')
# Out:
# Total cases per 1000 inhabitants up to today: 5.1615
# Total cases up to today: 2317
# New cases registered today: 42
# New cases registered today in %: 1.85
# Doubling time in the last five days: 24.0
# Doubling time yesterday: 21.3
# Trend of new cases (in %) in the last 5 days: 15.56

# %% [markdown]
# ## Piacenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Piacenza')
# Out:
# Total cases per 1000 inhabitants up to today: 10.2386
# Total cases up to today: 2936
# New cases registered today: 44
# New cases registered today in %: 1.52
# Doubling time in the last five days: 44.5
# Doubling time yesterday: 37.2
# Trend of new cases (in %) in the last 5 days: 8.1

# %% [markdown]
# ## Ravenna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ravenna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8599
# Total cases up to today: 728
# New cases registered today: 20
# New cases registered today in %: 2.82
# Doubling time in the last five days: 18.7
# Doubling time yesterday: 17.4
# Trend of new cases (in %) in the last 5 days: 20.33

# %% [markdown]
# ## Reggio nell'Emilia

# %%
calculate_and_create_chart_for_province(START_DATE, "Reggio nell'Emilia")
# Out:
# Total cases per 1000 inhabitants up to today: 5.9476
# Total cases up to today: 3167
# New cases registered today: 101
# New cases registered today in %: 3.29
# Doubling time in the last five days: 16.1
# Doubling time yesterday: 12.2
# Trend of new cases (in %) in the last 5 days: 24.05

# %% [markdown]
# ## Rimini

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rimini')
# Out:
# Total cases per 1000 inhabitants up to today: 4.6766
# Total cases up to today: 1575
# New cases registered today: 22
# New cases registered today in %: 1.42
# Doubling time in the last five days: 40.2
# Doubling time yesterday: 35.1
# Trend of new cases (in %) in the last 5 days: 9.0

# %% [markdown]
# # Casi di COVID-19 in Friuli Venezia Giulia - COVID-19 cases in Friuli Venezia Giulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Friuli Venezia Giulia')
# Out:
# Total cases up to today: 2097
# New cases registered today: 55
# New cases registered today in %: 2.69
# Doubling time in the last five days: 15.5
# Doubling time yesterday: 13.6
# Trend of new cases (in %) in the last 5 days: 25.12

# %% [markdown]
# ## Gorizia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Gorizia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.852
# Total cases up to today: 119
# New cases registered today: 3
# New cases registered today in %: 2.59
# Doubling time in the last five days: 30.0
# Doubling time yesterday: 20.6
# Trend of new cases (in %) in the last 5 days: 12.26

# %% [markdown]
# ## Pordenone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pordenone')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5286
# Total cases up to today: 477
# New cases registered today: 7
# New cases registered today in %: 1.49
# Doubling time in the last five days: 26.7
# Doubling time yesterday: 23.3
# Trend of new cases (in %) in the last 5 days: 13.84

# %% [markdown]
# ## Trieste

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trieste')
# Out:
# Total cases per 1000 inhabitants up to today: 3.0168
# Total cases up to today: 708
# New cases registered today: 38
# New cases registered today in %: 5.67
# Doubling time in the last five days: 16.7
# Doubling time yesterday: 16.8
# Trend of new cases (in %) in the last 5 days: 23.13

# %% [markdown]
# ## Udine

# %%
calculate_and_create_chart_for_province(START_DATE, 'Udine')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4921
# Total cases up to today: 793
# New cases registered today: 7
# New cases registered today in %: 0.89
# Doubling time in the last five days: 10.8
# Doubling time yesterday: 9.1
# Trend of new cases (in %) in the last 5 days: 37.67

# %% [markdown]
# # Casi di COVID-19 nel Lazio - COVID-19 cases in Lazio

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lazio')
# Out:
# Total cases up to today: 4001
# New cases registered today: 150
# New cases registered today in %: 3.9
# Doubling time in the last five days: 16.6
# Doubling time yesterday: 15.4
# Trend of new cases (in %) in the last 5 days: 23.22

# %% [markdown]
# ## Frosinone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Frosinone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7585
# Total cases up to today: 374
# New cases registered today: 5
# New cases registered today in %: 1.36
# Doubling time in the last five days: 27.0
# Doubling time yesterday: 24.9
# Trend of new cases (in %) in the last 5 days: 13.68

# %% [markdown]
# ## Latina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Latina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6071
# Total cases up to today: 349
# New cases registered today: 13
# New cases registered today in %: 3.87
# Doubling time in the last five days: 13.9
# Doubling time yesterday: 12.9
# Trend of new cases (in %) in the last 5 days: 28.31

# %% [markdown]
# ## Rieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rieti')
# Out:
# Total cases per 1000 inhabitants up to today: 1.6897
# Total cases up to today: 266
# New cases registered today: 77
# New cases registered today in %: 40.74
# Doubling time in the last five days: 10.8
# Doubling time yesterday: 9.7
# Trend of new cases (in %) in the last 5 days: 37.82

# %% [markdown]
# ## Roma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Roma')
# Out:
# Total cases per 1000 inhabitants up to today: 0.636
# Total cases up to today: 2769
# New cases registered today: 55
# New cases registered today in %: 2.03
# Doubling time in the last five days: 17.1
# Doubling time yesterday: 16.0
# Trend of new cases (in %) in the last 5 days: 22.52

# %% [markdown]
# ## Viterbo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Viterbo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7617
# Total cases up to today: 243
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 15.0
# Doubling time yesterday: 11.8
# Trend of new cases (in %) in the last 5 days: 25.91

# %% [markdown]
# # Casi di COVID-19 in Liguria - COVID-19 cases in Liguria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Liguria')
# Out:
# Total cases up to today: 3739
# New cases registered today: 50
# New cases registered today in %: 1.36
# Doubling time in the last five days: 4.9
# Doubling time yesterday: 4.9
# Trend of new cases (in %) in the last 5 days: 104.32

# %% [markdown]
# ## Genova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Genova')
# Out:
# Total cases per 1000 inhabitants up to today: 2.3551
# Total cases up to today: 2002
# New cases registered today: 78
# New cases registered today in %: 4.05
# Doubling time in the last five days: 5.9
# Doubling time yesterday: 6.1
# Trend of new cases (in %) in the last 5 days: 80.69

# %% [markdown]
# ## Imperia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Imperia')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7518
# Total cases up to today: 592
# New cases registered today: 6
# New cases registered today in %: 1.02
# Doubling time in the last five days: 3.6
# Doubling time yesterday: 3.8
# Trend of new cases (in %) in the last 5 days: 161.95

# %% [markdown]
# ## La Spezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'La Spezia')
# Out:
# Total cases per 1000 inhabitants up to today: 2.039
# Total cases up to today: 450
# New cases registered today: 5
# New cases registered today in %: 1.12
# Doubling time in the last five days: 5.7
# Doubling time yesterday: 5.9
# Trend of new cases (in %) in the last 5 days: 83.67

# %% [markdown]
# ## Savona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Savona')
# Out:
# Total cases per 1000 inhabitants up to today: 2.4874
# Total cases up to today: 695
# New cases registered today: -39
# New cases registered today in %: -5.31
# Doubling time in the last five days: 3.4
# Doubling time yesterday: 3.2
# Trend of new cases (in %) in the last 5 days: 176.89

# %% [markdown]
# # Casi di COVID-19 in Lombardia - COVID-19 cases in Lombardy

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lombardia')
# Out:
# Total cases up to today: 50401
# New cases registered today: 1078
# New cases registered today in %: 2.19
# Doubling time in the last five days: 24.7
# Doubling time yesterday: 22.5
# Trend of new cases (in %) in the last 5 days: 15.04

# %% [markdown]
# ## Bergamo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bergamo')
# Out:
# Total cases per 1000 inhabitants up to today: 8.8429
# Total cases up to today: 9815
# New cases registered today: 103
# New cases registered today in %: 1.06
# Doubling time in the last five days: 42.1
# Doubling time yesterday: 35.3
# Trend of new cases (in %) in the last 5 days: 8.59

# %% [markdown]
# ## Brescia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brescia')
# Out:
# Total cases per 1000 inhabitants up to today: 7.5076
# Total cases up to today: 9477
# New cases registered today: 137
# New cases registered today in %: 1.47
# Doubling time in the last five days: 35.6
# Doubling time yesterday: 31.5
# Trend of new cases (in %) in the last 5 days: 10.22

# %% [markdown]
# ## Como

# %%
calculate_and_create_chart_for_province(START_DATE, 'Como')
# Out:
# Total cases per 1000 inhabitants up to today: 2.4542
# Total cases up to today: 1473
# New cases registered today: 89
# New cases registered today in %: 6.43
# Doubling time in the last five days: 14.4
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 27.31

# %% [markdown]
# ## Cremona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cremona')
# Out:
# Total cases per 1000 inhabitants up to today: 11.8535
# Total cases up to today: 4260
# New cases registered today: 27
# New cases registered today in %: 0.64
# Doubling time in the last five days: 44.5
# Doubling time yesterday: 38.5
# Trend of new cases (in %) in the last 5 days: 8.09

# %% [markdown]
# ## Lecco

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecco')
# Out:
# Total cases per 1000 inhabitants up to today: 5.0466
# Total cases up to today: 1712
# New cases registered today: 34
# New cases registered today in %: 2.03
# Doubling time in the last five days: 28.5
# Doubling time yesterday: 26.2
# Trend of new cases (in %) in the last 5 days: 12.93

# %% [markdown]
# ## Lodi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lodi')
# Out:
# Total cases per 1000 inhabitants up to today: 9.9329
# Total cases up to today: 2278
# New cases registered today: 23
# New cases registered today in %: 1.02
# Doubling time in the last five days: 63.5
# Doubling time yesterday: 54.5
# Trend of new cases (in %) in the last 5 days: 5.61

# %% [markdown]
# ## Mantova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Mantova')
# Out:
# Total cases per 1000 inhabitants up to today: 5.0508
# Total cases up to today: 2084
# New cases registered today: 40
# New cases registered today in %: 1.96
# Doubling time in the last five days: 19.0
# Doubling time yesterday: 18.1
# Trend of new cases (in %) in the last 5 days: 20.05

# %% [markdown]
# ## Milano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Milano')
# Out:
# Total cases per 1000 inhabitants up to today: 3.5852
# Total cases up to today: 11538
# New cases registered today: 308
# New cases registered today in %: 2.74
# Doubling time in the last five days: 18.0
# Doubling time yesterday: 15.0
# Trend of new cases (in %) in the last 5 days: 21.17

# %% [markdown]
# ## Monza e della Brianza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Monza e della Brianza')
# Out:
# Total cases per 1000 inhabitants up to today: 3.6335
# Total cases up to today: 3157
# New cases registered today: 111
# New cases registered today in %: 3.64
# Doubling time in the last five days: 16.0
# Doubling time yesterday: 16.3
# Trend of new cases (in %) in the last 5 days: 24.14

# %% [markdown]
# ## Pavia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pavia')
# Out:
# Total cases per 1000 inhabitants up to today: 4.9338
# Total cases up to today: 2700
# New cases registered today: 81
# New cases registered today in %: 3.09
# Doubling time in the last five days: 16.2
# Doubling time yesterday: 16.9
# Trend of new cases (in %) in the last 5 days: 23.85

# %% [markdown]
# ## Sondrio

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sondrio')
# Out:
# Total cases per 1000 inhabitants up to today: 3.3841
# Total cases up to today: 614
# New cases registered today: 23
# New cases registered today in %: 3.89
# Doubling time in the last five days: 14.6
# Doubling time yesterday: 15.1
# Trend of new cases (in %) in the last 5 days: 26.86

# %% [markdown]
# ## Varese

# %%
calculate_and_create_chart_for_province(START_DATE, 'Varese')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4527
# Total cases up to today: 1293
# New cases registered today: 102
# New cases registered today in %: 8.56
# Doubling time in the last five days: 10.8
# Doubling time yesterday: 12.0
# Trend of new cases (in %) in the last 5 days: 37.99

# %% [markdown]
# # Casi di COVID-19 nelle Marche - COVID-19 cases in Marche

# %%
calculate_and_create_chart_for_region(START_DATE, 'Marche')
# Out:
# Total cases up to today: 4506
# New cases registered today: 140
# New cases registered today in %: 3.21
# Doubling time in the last five days: 23.5
# Doubling time yesterday: 22.9
# Trend of new cases (in %) in the last 5 days: 15.87

# %% [markdown]
# ## Ancona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ancona')
# Out:
# Total cases per 1000 inhabitants up to today: 2.9549
# Total cases up to today: 1401
# New cases registered today: 45
# New cases registered today in %: 3.32
# Doubling time in the last five days: 19.6
# Doubling time yesterday: 17.8
# Trend of new cases (in %) in the last 5 days: 19.34

# %% [markdown]
# ## Ascoli Piceno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ascoli Piceno')
# Out:
# Total cases per 1000 inhabitants up to today: 1.122
# Total cases up to today: 235
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 72.3
# Doubling time yesterday: 60.9
# Trend of new cases (in %) in the last 5 days: 4.91

# %% [markdown]
# ## Fermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Fermo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7844
# Total cases up to today: 312
# New cases registered today: 4
# New cases registered today in %: 1.3
# Doubling time in the last five days: 20.3
# Doubling time yesterday: 20.0
# Trend of new cases (in %) in the last 5 days: 18.63

# %% [markdown]
# ## Macerata

# %%
calculate_and_create_chart_for_province(START_DATE, 'Macerata')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0036
# Total cases up to today: 639
# New cases registered today: 25
# New cases registered today in %: 4.07
# Doubling time in the last five days: 14.9
# Doubling time yesterday: 15.8
# Trend of new cases (in %) in the last 5 days: 26.28

# %% [markdown]
# ## Pesaro e Urbino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pesaro e Urbino')
# Out:
# Total cases per 1000 inhabitants up to today: 5.32
# Total cases up to today: 1919
# New cases registered today: 66
# New cases registered today in %: 3.56
# Doubling time in the last five days: 32.0
# Doubling time yesterday: 32.2
# Trend of new cases (in %) in the last 5 days: 11.44

# %% [markdown]
# # Casi di COVID-19 in Molise - COVID-19 cases in Molise¶

# %%
calculate_and_create_chart_for_region(START_DATE, 'Molise')
# Out:
# Total cases up to today: 210
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 10.1
# Doubling time yesterday: 7.6
# Trend of new cases (in %) in the last 5 days: 40.94

# %% [markdown]
# ## Campobasso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Campobasso')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7389
# Total cases up to today: 166
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 19.5
# Doubling time yesterday: 11.9
# Trend of new cases (in %) in the last 5 days: 19.42

# %% [markdown]
# ## Isernia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Isernia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5128
# Total cases up to today: 44
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 2.3
# Doubling time yesterday: 2.2
# Trend of new cases (in %) in the last 5 days: 340.0

# %% [markdown]
# # Casi di COVID-19 in Piemonte - COVID-19 cases in Piedmont

# %%
calculate_and_create_chart_for_region(START_DATE, 'Piemonte')
# Out:
# Total cases up to today: 12685
# New cases registered today: 552
# New cases registered today in %: 4.55
# Doubling time in the last five days: 12.4
# Doubling time yesterday: 12.0
# Trend of new cases (in %) in the last 5 days: 32.37

# %% [markdown]
# ## Alessandria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Alessandria')
# Out:
# Total cases per 1000 inhabitants up to today: 4.4626
# Total cases up to today: 1904
# New cases registered today: 141
# New cases registered today in %: 8.0
# Doubling time in the last five days: 10.7
# Doubling time yesterday: 11.9
# Trend of new cases (in %) in the last 5 days: 38.17

# %% [markdown]
# ## Asti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Asti')
# Out:
# Total cases per 1000 inhabitants up to today: 2.8106
# Total cases up to today: 609
# New cases registered today: 13
# New cases registered today in %: 2.18
# Doubling time in the last five days: 12.4
# Doubling time yesterday: 10.9
# Trend of new cases (in %) in the last 5 days: 32.1

# %% [markdown]
# ## Biella

# %%
calculate_and_create_chart_for_province(START_DATE, 'Biella')
# Out:
# Total cases per 1000 inhabitants up to today: 3.2652
# Total cases up to today: 583
# New cases registered today: 12
# New cases registered today in %: 2.1
# Doubling time in the last five days: 23.5
# Doubling time yesterday: 22.7
# Trend of new cases (in %) in the last 5 days: 15.9

# %% [markdown]
# ## Cuneo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cuneo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9266
# Total cases up to today: 1135
# New cases registered today: 64
# New cases registered today in %: 5.98
# Doubling time in the last five days: 9.2
# Doubling time yesterday: 9.1
# Trend of new cases (in %) in the last 5 days: 45.89

# %% [markdown]
# ## Novara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Novara')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7233
# Total cases up to today: 1008
# New cases registered today: 22
# New cases registered today in %: 2.23
# Doubling time in the last five days: 20.9
# Doubling time yesterday: 16.3
# Trend of new cases (in %) in the last 5 days: 18.03

# %% [markdown]
# ## Torino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Torino')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7131
# Total cases up to today: 6180
# New cases registered today: 195
# New cases registered today in %: 3.26
# Doubling time in the last five days: 12.8
# Doubling time yesterday: 11.7
# Trend of new cases (in %) in the last 5 days: 31.18

# %% [markdown]
# ## 	Verbano-Cusio-Ossola

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verbano-Cusio-Ossola')
# Out:
# Total cases per 1000 inhabitants up to today: 3.8769
# Total cases up to today: 619
# New cases registered today: 63
# New cases registered today in %: 11.33
# Doubling time in the last five days: 8.4
# Doubling time yesterday: 10.0
# Trend of new cases (in %) in the last 5 days: 50.98

# %% [markdown]
# ## Vercelli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vercelli')
# Out:
# Total cases per 1000 inhabitants up to today: 3.7212
# Total cases up to today: 647
# New cases registered today: 42
# New cases registered today in %: 6.94
# Doubling time in the last five days: 12.3
# Doubling time yesterday: 14.1
# Trend of new cases (in %) in the last 5 days: 32.58

# %% [markdown]
# # Casi di COVID-19 in Puglia - COVID-19 cases in Apulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Puglia')
# Out:
# Total cases up to today: 2414
# New cases registered today: 126
# New cases registered today in %: 5.51
# Doubling time in the last five days: 15.2
# Doubling time yesterday: 13.7
# Trend of new cases (in %) in the last 5 days: 25.66

# %% [markdown]
# ## Bari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6404
# Total cases up to today: 807
# New cases registered today: 17
# New cases registered today in %: 2.15
# Doubling time in the last five days: 16.6
# Doubling time yesterday: 13.9
# Trend of new cases (in %) in the last 5 days: 23.21

# %% [markdown]
# ## 	Barletta-Andria-Trani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Barletta-Andria-Trani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4509
# Total cases up to today: 177
# New cases registered today: 39
# New cases registered today in %: 28.26
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 15.9
# Trend of new cases (in %) in the last 5 days: 52.59

# %% [markdown]
# ## Brindisi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brindisi')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6472
# Total cases up to today: 257
# New cases registered today: 11
# New cases registered today in %: 4.47
# Doubling time in the last five days: 11.7
# Doubling time yesterday: 8.5
# Trend of new cases (in %) in the last 5 days: 34.55

# %% [markdown]
# ## Foggia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Foggia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9625
# Total cases up to today: 605
# New cases registered today: 41
# New cases registered today in %: 7.27
# Doubling time in the last five days: 16.4
# Doubling time yesterday: 16.5
# Trend of new cases (in %) in the last 5 days: 23.47

# %% [markdown]
# ## Lecce

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecce')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4713
# Total cases up to today: 378
# New cases registered today: 10
# New cases registered today in %: 2.72
# Doubling time in the last five days: 21.2
# Doubling time yesterday: 17.8
# Trend of new cases (in %) in the last 5 days: 17.76

# %% [markdown]
# ## Taranto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Taranto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3256
# Total cases up to today: 190
# New cases registered today: 8
# New cases registered today in %: 4.4
# Doubling time in the last five days: 13.9
# Doubling time yesterday: 9.4
# Trend of new cases (in %) in the last 5 days: 28.38

# %% [markdown]
# # Casi di COVID-19 in Sardegna - COVID-19 cases in Sardinia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sardegna')
# Out:
# Total cases up to today: 922
# New cases registered today: 15
# New cases registered today in %: 1.65
# Doubling time in the last five days: 16.3
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 23.76

# %% [markdown]
# ## Cagliari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cagliari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2605
# Total cases up to today: 146
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 15.1
# Doubling time yesterday: 12.6
# Trend of new cases (in %) in the last 5 days: 25.86

# %% [markdown]
# ## Nuoro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Nuoro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4164
# Total cases up to today: 65
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 35.8
# Doubling time yesterday: 26.4
# Trend of new cases (in %) in the last 5 days: 10.17

# %% [markdown]
# ## Oristano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Oristano')
# Out:
# Total cases per 1000 inhabitants up to today: 0.168
# Total cases up to today: 27
# New cases registered today: 3
# New cases registered today in %: 12.5
# Doubling time in the last five days: 5.9
# Doubling time yesterday: 4.0
# Trend of new cases (in %) in the last 5 days: 80.0

# %% [markdown]
# ## Sassari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sassari')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8312
# Total cases up to today: 610
# New cases registered today: 9
# New cases registered today in %: 1.5
# Doubling time in the last five days: 16.9
# Doubling time yesterday: 16.3
# Trend of new cases (in %) in the last 5 days: 22.74

# %% [markdown]
# # Casi di COVID-19 in Sicilia - COVID-19 cases in Sicily

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sicilia')
# Out:
# Total cases up to today: 2046
# New cases registered today: 52
# New cases registered today in %: 2.61
# Doubling time in the last five days: 19.8
# Doubling time yesterday: 18.1
# Trend of new cases (in %) in the last 5 days: 19.09

# %% [markdown]
# ## Agrigento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Agrigento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2466
# Total cases up to today: 109
# New cases registered today: 2
# New cases registered today in %: 1.87
# Doubling time in the last five days: 27.3
# Doubling time yesterday: 26.8
# Trend of new cases (in %) in the last 5 days: 13.54

# %% [markdown]
# ## Caltanissetta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caltanissetta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3856
# Total cases up to today: 104
# New cases registered today: 2
# New cases registered today in %: 1.96
# Doubling time in the last five days: 11.0
# Doubling time yesterday: 9.2
# Trend of new cases (in %) in the last 5 days: 36.84

# %% [markdown]
# ## Catania

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catania')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5515
# Total cases up to today: 614
# New cases registered today: 20
# New cases registered today in %: 3.37
# Doubling time in the last five days: 18.7
# Doubling time yesterday: 19.7
# Trend of new cases (in %) in the last 5 days: 20.39

# %% [markdown]
# ## Enna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Enna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7078
# Total cases up to today: 287
# New cases registered today: 3
# New cases registered today in %: 1.06
# Doubling time in the last five days: 14.0
# Doubling time yesterday: 10.3
# Trend of new cases (in %) in the last 5 days: 28.12

# %% [markdown]
# ## Messina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Messina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5686
# Total cases up to today: 362
# New cases registered today: 9
# New cases registered today in %: 2.55
# Doubling time in the last five days: 27.4
# Doubling time yesterday: 27.4
# Trend of new cases (in %) in the last 5 days: 13.48

# %% [markdown]
# ## Palermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Palermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2373
# Total cases up to today: 301
# New cases registered today: 2
# New cases registered today in %: 0.67
# Doubling time in the last five days: 40.0
# Doubling time yesterday: 26.2
# Trend of new cases (in %) in the last 5 days: 9.06

# %% [markdown]
# ## Ragusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ragusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.168
# Total cases up to today: 54
# New cases registered today: 6
# New cases registered today in %: 12.5
# Doubling time in the last five days: 16.9
# Doubling time yesterday: 31.5
# Trend of new cases (in %) in the last 5 days: 22.73

# %% [markdown]
# ## Siracusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siracusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2756
# Total cases up to today: 111
# New cases registered today: 2
# New cases registered today in %: 1.83
# Doubling time in the last five days: 27.8
# Doubling time yesterday: 21.8
# Trend of new cases (in %) in the last 5 days: 13.27

# %% [markdown]
# ## Trapani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trapani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2394
# Total cases up to today: 104
# New cases registered today: 6
# New cases registered today in %: 6.12
# Doubling time in the last five days: 10.6
# Doubling time yesterday: 11.8
# Trend of new cases (in %) in the last 5 days: 38.67

# %% [markdown]
# # Casi di COVID-19 in Toscana - COVID-19 cases in Tuscany

# %%
calculate_and_create_chart_for_region(START_DATE, 'Toscana')
# Out:
# Total cases up to today: 6001
# New cases registered today: 154
# New cases registered today in %: 2.63
# Doubling time in the last five days: 16.5
# Doubling time yesterday: 14.6
# Trend of new cases (in %) in the last 5 days: 23.3

# %% [markdown]
# ## Arezzo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Arezzo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1238
# Total cases up to today: 387
# New cases registered today: 9
# New cases registered today in %: 2.38
# Doubling time in the last five days: 28.7
# Doubling time yesterday: 26.7
# Trend of new cases (in %) in the last 5 days: 12.83

# %% [markdown]
# ## Firenze

# %%
calculate_and_create_chart_for_province(START_DATE, 'Firenze')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7438
# Total cases up to today: 1769
# New cases registered today: 54
# New cases registered today in %: 3.15
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 7.6
# Trend of new cases (in %) in the last 5 days: 52.76

# %% [markdown]
# ## Grosseto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Grosseto')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2733
# Total cases up to today: 284
# New cases registered today: 7
# New cases registered today in %: 2.53
# Doubling time in the last five days: 45.1
# Doubling time yesterday: 46.2
# Trend of new cases (in %) in the last 5 days: 7.98

# %% [markdown]
# ## Livorno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Livorno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9575
# Total cases up to today: 323
# New cases registered today: 1
# New cases registered today in %: 0.31
# Doubling time in the last five days: 38.2
# Doubling time yesterday: 24.8
# Trend of new cases (in %) in the last 5 days: 9.49

# %% [markdown]
# ## Lucca

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lucca')
# Out:
# Total cases per 1000 inhabitants up to today: 2.2767
# Total cases up to today: 888
# New cases registered today: 16
# New cases registered today in %: 1.83
# Doubling time in the last five days: 24.5
# Doubling time yesterday: 19.3
# Trend of new cases (in %) in the last 5 days: 15.18

# %% [markdown]
# ## Massa Carrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Massa Carrara')
# Out:
# Total cases per 1000 inhabitants up to today: 3.5507
# Total cases up to today: 698
# New cases registered today: 31
# New cases registered today in %: 4.65
# Doubling time in the last five days: 26.0
# Doubling time yesterday: 20.0
# Trend of new cases (in %) in the last 5 days: 14.24

# %% [markdown]
# ## Pisa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pisa')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3275
# Total cases up to today: 560
# New cases registered today: 16
# New cases registered today in %: 2.94
# Doubling time in the last five days: 26.4
# Doubling time yesterday: 24.1
# Trend of new cases (in %) in the last 5 days: 14.05

# %% [markdown]
# ## Pistoia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pistoia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3706
# Total cases up to today: 400
# New cases registered today: 6
# New cases registered today in %: 1.52
# Doubling time in the last five days: 18.9
# Doubling time yesterday: 20.2
# Trend of new cases (in %) in the last 5 days: 20.12

# %% [markdown]
# ## Prato

# %%
calculate_and_create_chart_for_province(START_DATE, 'Prato')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3432
# Total cases up to today: 342
# New cases registered today: 4
# New cases registered today in %: 1.18
# Doubling time in the last five days: 21.0
# Doubling time yesterday: 12.8
# Trend of new cases (in %) in the last 5 days: 17.93

# %% [markdown]
# ## Siena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siena')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3043
# Total cases up to today: 350
# New cases registered today: 10
# New cases registered today in %: 2.94
# Doubling time in the last five days: 30.2
# Doubling time yesterday: 28.4
# Trend of new cases (in %) in the last 5 days: 12.18

# %% [markdown]
# # Casi di COVID-19 in Provincia Autonoma di Trento - COVID-19 cases in the Autonomous Province of Trento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trento')
# Out:
# Total cases per 1000 inhabitants up to today: 4.3594
# Total cases up to today: 2348
# New cases registered today: 63
# New cases registered today in %: 2.76
# Doubling time in the last five days: 15.2
# Doubling time yesterday: 12.9
# Trend of new cases (in %) in the last 5 days: 25.56

# %% [markdown]
# # Casi di COVID-19 in Umbria - COVID-19 cases in Umbria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Umbria')
# Out:
# Total cases up to today: 1213
# New cases registered today: 13
# New cases registered today in %: 1.08
# Doubling time in the last five days: 25.3
# Doubling time yesterday: 24.7
# Trend of new cases (in %) in the last 5 days: 14.65

# %% [markdown]
# ## Perugia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Perugia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4061
# Total cases up to today: 929
# New cases registered today: 4
# New cases registered today in %: 0.43
# Doubling time in the last five days: 28.3
# Doubling time yesterday: 26.9
# Trend of new cases (in %) in the last 5 days: 13.02

# %% [markdown]
# ## Terni

# %%
calculate_and_create_chart_for_province(START_DATE, 'Terni')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2444
# Total cases up to today: 284
# New cases registered today: 9
# New cases registered today in %: 3.27
# Doubling time in the last five days: 18.7
# Doubling time yesterday: 19.4
# Trend of new cases (in %) in the last 5 days: 20.34

# %% [markdown]
# # Casi di COVID-19 in Valle d'Aosta - COVID-19 cases in Aosta Valley

# %%
calculate_and_create_chart_for_province(START_DATE, "Aosta")
# Out:
# Total cases per 1000 inhabitants up to today: 6.3444
# Total cases up to today: 805
# New cases registered today: 23
# New cases registered today in %: 2.94
# Doubling time in the last five days: 14.2
# Doubling time yesterday: 15.8
# Trend of new cases (in %) in the last 5 days: 27.58

# %% [markdown]
# # Casi di COVID-19 in Veneto - COVID-19 cases in Veneto

# %%
calculate_and_create_chart_for_region(START_DATE, 'Veneto')
# Out:
# Total cases up to today: 11296
# New cases registered today: 356
# New cases registered today in %: 3.25
# Doubling time in the last five days: 18.5
# Doubling time yesterday: 16.6
# Trend of new cases (in %) in the last 5 days: 20.59

# %% [markdown]
# ## Belluno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Belluno')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7116
# Total cases up to today: 558
# New cases registered today: 20
# New cases registered today in %: 3.72
# Doubling time in the last five days: 17.9
# Doubling time yesterday: 15.5
# Trend of new cases (in %) in the last 5 days: 21.3

# %% [markdown]
# ## Padova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Padova')
# Out:
# Total cases per 1000 inhabitants up to today: 3.0579
# Total cases up to today: 2863
# New cases registered today: 119
# New cases registered today in %: 4.34
# Doubling time in the last five days: 18.3
# Doubling time yesterday: 18.0
# Trend of new cases (in %) in the last 5 days: 20.9

# %% [markdown]
# ## Rovigo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rovigo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8508
# Total cases up to today: 203
# New cases registered today: 17
# New cases registered today in %: 9.14
# Doubling time in the last five days: 9.3
# Doubling time yesterday: 11.1
# Trend of new cases (in %) in the last 5 days: 45.0

# %% [markdown]
# ## Treviso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Treviso')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9481
# Total cases up to today: 1726
# New cases registered today: 14
# New cases registered today in %: 0.82
# Doubling time in the last five days: 33.0
# Doubling time yesterday: 29.5
# Trend of new cases (in %) in the last 5 days: 11.07

# %% [markdown]
# ## Venezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Venezia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7407
# Total cases up to today: 1487
# New cases registered today: 62
# New cases registered today in %: 4.35
# Doubling time in the last five days: 18.3
# Doubling time yesterday: 17.6
# Trend of new cases (in %) in the last 5 days: 20.8

# %% [markdown]
# ## Verona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verona')
# Out:
# Total cases per 1000 inhabitants up to today: 2.9895
# Total cases up to today: 2755
# New cases registered today: 67
# New cases registered today in %: 2.49
# Doubling time in the last five days: 18.6
# Doubling time yesterday: 14.4
# Trend of new cases (in %) in the last 5 days: 20.46

# %% [markdown]
# ## Vicenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vicenza')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9698
# Total cases up to today: 1704
# New cases registered today: 57
# New cases registered today in %: 3.46
# Doubling time in the last five days: 13.9
# Doubling time yesterday: 12.3
# Trend of new cases (in %) in the last 5 days: 28.41
