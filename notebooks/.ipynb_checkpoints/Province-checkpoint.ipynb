# %%
import pandas as pd
import sys
import datetime
import matplotlib.pylab as plt
import numpy as np
from math import log

# %%
START_DATE = datetime.date(2020,2,24)

# %%
def calculate_and_create_chart_for_province(start_date: datetime.date, province: str):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str = day.strftime("%Y%m%d")
        filename = '../dati-province/dpc-covid19-ita-province-' + day_str + '.csv'
        df = pd.read_csv(filename)
        cases[day_str] = int(df[df["denominazione_provincia"]==province]["totale_casi"])
        day = day + datetime.timedelta(days = 1)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases per 1000 inhabitants up to today:", round(calculate_cases_to_inhabitants_ratio(cases_df_today, province),4))
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()

    plt.show()
    return

# %%
def calculate_and_create_chart_for_region(start_date: datetime.date, region: str):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str = day.strftime("%Y%m%d")
        filename = '../dati-province/dpc-covid19-ita-province-' + day_str + '.csv'
        df = pd.read_csv(filename)
        cases[day_str] = int(df[(df["denominazione_regione"]==region)&(df["denominazione_provincia"]!='In fase di definizione/aggiornamento')]["totale_casi"].sum())
        day = day + datetime.timedelta(days = 1)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_Italy(start_date: datetime.date):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str = day.strftime("%Y%m%d")
        filename = '../dati-province/dpc-covid19-ita-province-' + day_str + '.csv'
        df = pd.read_csv(filename)
        cases[day_str] = int(df[df["denominazione_provincia"]!='In fase di definizione/aggiornamento']["totale_casi"].sum())
        day = day + datetime.timedelta(days = 1)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()

    plt.show()
    return

# %%
def calculate_stats(cases_df):
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    cases_df_yesterday = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 1)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_five_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 5)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_six_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 6)).strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases up to today:", cases_df_today)
    print("New cases registered today:", cases_df_today-cases_df_yesterday)
    if int(cases_df_yesterday) != 0:
        print("New cases registered today in %:", round((cases_df_today-cases_df_yesterday)/cases_df_yesterday*100,2))

    print("Doubling time in the last five days:", round(calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago), 1))
    print("Trend of new cases (in %) in the last 5 days:", round((cases_df_today-cases_df_five_days_ago)/cases_df_five_days_ago*100,2))
    print("Doubling time yesterday:", round(calculate_doubling_time_in_the_last_five_days(cases_df_yesterday, cases_df_six_days_ago), 1))
    return

# %%
def calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago):
    if cases_df_five_days_ago ==0:
        return np.nan
    log_result = log(cases_df_today/cases_df_five_days_ago)
    if log_result != 0:
        return (5*log(2))/(log_result)
    else:
        return np.nan

# %%
def calculate_cases_to_inhabitants_ratio(cases: int, province: str) -> float:
    df_province: pd.DataFrame = pd.read_csv("../general/province.csv")
    inhabitants = df_province[df_province["Provincia"]==province]["Residenti"].str.replace('.', '', regex=True).sum()
    return int(cases)/int(inhabitants)*1000

# %% [markdown]
# # Casi di COVID-19 in Italia - COVID-19 cases in Italy

# %%
calculate_and_create_chart_for_Italy(START_DATE)
# Out:
# Total cases up to today: 67044
# New cases registered today: 5014
# New cases registered today in %: 8.08
# Doubling time in the last five days: 6.5
# Trend of new cases (in %) in the last 5 days: 70.11
# Doubling time yesterday: 6.0

# %% [markdown]
# # Casi di COVID-19 in Abruzzo - COVID-19 cases in Abruzzo

# %%
calculate_and_create_chart_for_region(START_DATE, 'Abruzzo')
# Out:
# Total cases up to today: 689
# New cases registered today: 26
# New cases registered today in %: 3.92
# Doubling time in the last five days: 6.0
# Trend of new cases (in %) in the last 5 days: 78.96
# Doubling time yesterday: 3.7

# %% [markdown]
# ## Chieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Chieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3418
# Total cases up to today: 133
# New cases registered today: 4
# New cases registered today in %: 3.1
# Doubling time in the last five days: 5.3
# Trend of new cases (in %) in the last 5 days: 92.75
# Doubling time yesterday: 3.2

# %% [markdown]
# ## L'Aquila

# %%
calculate_and_create_chart_for_province(START_DATE, "L'Aquila")
# Out:
# Total cases per 1000 inhabitants up to today: 0.1557
# Total cases up to today: 47
# New cases registered today: 7
# New cases registered today in %: 17.5
# Doubling time in the last five days: 5.5
# Trend of new cases (in %) in the last 5 days: 88.0
# Doubling time yesterday: 5.0

# %% [markdown]
# ## Pescara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pescara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1484
# Total cases up to today: 369
# New cases registered today: -1
# New cases registered today in %: -0.27
# Doubling time in the last five days: 6.9
# Trend of new cases (in %) in the last 5 days: 65.47
# Doubling time yesterday: 4.1

# %% [markdown]
# ## Teramo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Teramo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4518
# Total cases up to today: 140
# New cases registered today: 16
# New cases registered today in %: 12.9
# Doubling time in the last five days: 4.8
# Trend of new cases (in %) in the last 5 days: 105.88
# Doubling time yesterday: 3.0

# %% [markdown]
# # Casi di COVID-19 in Basilicata - COVID-19 cases in Basilicata

# %%
calculate_and_create_chart_for_region(START_DATE, 'Basilicata')
# Out:
# Total cases up to today: 92
# New cases registered today: 2
# New cases registered today in %: 2.22
# Doubling time in the last five days: 3.8
# Trend of new cases (in %) in the last 5 days: 148.65
# Doubling time yesterday: 2.9

# %% [markdown]
# ## Matera

# %%
calculate_and_create_chart_for_province(START_DATE, 'Matera')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1252
# Total cases up to today: 25
# New cases registered today: 7
# New cases registered today in %: 38.89
# Doubling time in the last five days: 2.7
# Trend of new cases (in %) in the last 5 days: 257.14
# Doubling time yesterday: 2.7

# %% [markdown]
# ## Potenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Potenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1807
# Total cases up to today: 67
# New cases registered today: -5
# New cases registered today in %: -6.94
# Doubling time in the last five days: 4.3
# Trend of new cases (in %) in the last 5 days: 123.33
# Doubling time yesterday: 2.9

# %% [markdown]
# # Casi di COVID-19 nella Provincia Autonoma di Bolzano - COVID-19 cases in Autonomous Province of Bolzano

# %%
calculate_and_create_chart_for_region(START_DATE, 'P.A. Bolzano')
# Out:
# Total cases up to today: 781
# New cases registered today: 57
# New cases registered today in %: 7.87
# Doubling time in the last five days: 5.9
# Trend of new cases (in %) in the last 5 days: 79.13
# Doubling time yesterday: 5.3

# %% [markdown]
# # Casi di COVID-19 in Calabria - COVID-19 cases in Calabria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Calabria')
# Out:
# Total cases up to today: 317
# New cases registered today: 27
# New cases registered today in %: 9.31
# Doubling time in the last five days: 5.5
# Trend of new cases (in %) in the last 5 days: 87.57
# Doubling time yesterday: 4.3

# %% [markdown]
# ## Catanzaro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catanzaro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1352
# Total cases up to today: 49
# New cases registered today: 3
# New cases registered today in %: 6.52
# Doubling time in the last five days: 5.8
# Trend of new cases (in %) in the last 5 days: 81.48
# Doubling time yesterday: 4.2

# %% [markdown]
# ## Cosenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cosenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.118
# Total cases up to today: 84
# New cases registered today: 16
# New cases registered today in %: 23.53
# Doubling time in the last five days: 4.4
# Trend of new cases (in %) in the last 5 days: 121.05
# Doubling time yesterday: 4.4

# %% [markdown]
# ## Crotone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Crotone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3759
# Total cases up to today: 66
# New cases registered today: 4
# New cases registered today in %: 6.45
# Doubling time in the last five days: 6.6
# Trend of new cases (in %) in the last 5 days: 69.23
# Doubling time yesterday: 3.5

# %% [markdown]
# ## Reggio di Calabria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Reggio di Calabria')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1751
# Total cases up to today: 97
# New cases registered today: 3
# New cases registered today in %: 3.19
# Doubling time in the last five days: 6.5
# Trend of new cases (in %) in the last 5 days: 70.18
# Doubling time yesterday: 5.0

# %% [markdown]
# ## Vibo Valentia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vibo Valentia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1299
# Total cases up to today: 21
# New cases registered today: 1
# New cases registered today in %: 5.0
# Doubling time in the last five days: 3.6
# Trend of new cases (in %) in the last 5 days: 162.5
# Doubling time yesterday: 3.8

# %% [markdown]
# # Casi di COVID-19 in Campania - COVID-19 cases in Campania

# %%
calculate_and_create_chart_for_region(START_DATE, 'Campania')
# Out:
# Total cases up to today: 1091
# New cases registered today: 87
# New cases registered today in %: 8.67
# Doubling time in the last five days: 6.5
# Trend of new cases (in %) in the last 5 days: 70.47
# Doubling time yesterday: 4.3

# %% [markdown]
# ## Avellino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Avellino')
# Out:
# Total cases per 1000 inhabitants up to today: 0.366
# Total cases up to today: 155
# New cases registered today: 10
# New cases registered today in %: 6.9
# Doubling time in the last five days: 6.1
# Trend of new cases (in %) in the last 5 days: 76.14
# Doubling time yesterday: 3.6

# %% [markdown]
# ## Benevento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Benevento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0501
# Total cases up to today: 14
# New cases registered today: 1
# New cases registered today in %: 7.69
# Doubling time in the last five days: 6.2
# Trend of new cases (in %) in the last 5 days: 75.0
# Doubling time yesterday: 2.9

# %% [markdown]
# ## Caserta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caserta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1645
# Total cases up to today: 152
# New cases registered today: 28
# New cases registered today in %: 22.58
# Doubling time in the last five days: 7.2
# Trend of new cases (in %) in the last 5 days: 61.7
# Doubling time yesterday: 5.4

# %% [markdown]
# ## Napoli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Napoli')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1892
# Total cases up to today: 588
# New cases registered today: 45
# New cases registered today in %: 8.29
# Doubling time in the last five days: 7.0
# Trend of new cases (in %) in the last 5 days: 64.25
# Doubling time yesterday: 4.7

# %% [markdown]
# ## Salerno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Salerno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1647
# Total cases up to today: 182
# New cases registered today: 3
# New cases registered today in %: 1.68
# Doubling time in the last five days: 5.1
# Trend of new cases (in %) in the last 5 days: 97.83
# Doubling time yesterday: 3.4

# %% [markdown]
# # Casi di COVID-19 in Emilia Romagna - COVID-19 cases in Emilia Romagna

# %%
calculate_and_create_chart_for_region(START_DATE, 'Emilia Romagna')
# Out:
# Total cases up to today: 9254
# New cases registered today: 719
# New cases registered today in %: 8.42
# Doubling time in the last five days: 6.0
# Trend of new cases (in %) in the last 5 days: 77.48
# Doubling time yesterday: 5.5

# %% [markdown]
# ## Bologna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bologna')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9592
# Total cases up to today: 968
# New cases registered today: 135
# New cases registered today in %: 16.21
# Doubling time in the last five days: 4.7
# Trend of new cases (in %) in the last 5 days: 108.17
# Doubling time yesterday: 4.6

# %% [markdown]
# ## Ferrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ferrara')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5454
# Total cases up to today: 190
# New cases registered today: 18
# New cases registered today in %: 10.47
# Doubling time in the last five days: 3.9
# Trend of new cases (in %) in the last 5 days: 143.59
# Doubling time yesterday: 3.5

# %% [markdown]
# ## Forlì-Cesena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Forlì-Cesena')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1089
# Total cases up to today: 437
# New cases registered today: 57
# New cases registered today in %: 15.0
# Doubling time in the last five days: 5.3
# Trend of new cases (in %) in the last 5 days: 92.51
# Doubling time yesterday: 4.3

# %% [markdown]
# ## Modena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Modena')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9319
# Total cases up to today: 1354
# New cases registered today: 199
# New cases registered today in %: 17.23
# Doubling time in the last five days: 4.9
# Trend of new cases (in %) in the last 5 days: 104.22
# Doubling time yesterday: 5.0

# %% [markdown]
# ## Parma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Parma')
# Out:
# Total cases per 1000 inhabitants up to today: 3.1967
# Total cases up to today: 1435
# New cases registered today: 71
# New cases registered today in %: 5.21
# Doubling time in the last five days: 6.9
# Trend of new cases (in %) in the last 5 days: 65.13
# Doubling time yesterday: 6.5

# %% [markdown]
# ## Piacenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Piacenza')
# Out:
# Total cases per 1000 inhabitants up to today: 6.9083
# Total cases up to today: 1981
# New cases registered today: 96
# New cases registered today in %: 5.09
# Doubling time in the last five days: 10.6
# Trend of new cases (in %) in the last 5 days: 38.73
# Doubling time yesterday: 10.2

# %% [markdown]
# ## Ravenna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ravenna')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9402
# Total cases up to today: 368
# New cases registered today: 26
# New cases registered today in %: 7.6
# Doubling time in the last five days: 5.0
# Trend of new cases (in %) in the last 5 days: 98.92
# Doubling time yesterday: 4.3

# %% [markdown]
# ## Reggio nell'Emilia

# %%
calculate_and_create_chart_for_province(START_DATE, "Reggio nell'Emilia")
# Out:
# Total cases per 1000 inhabitants up to today: 2.6987
# Total cases up to today: 1437
# New cases registered today: 68
# New cases registered today in %: 4.97
# Doubling time in the last five days: 4.0
# Trend of new cases (in %) in the last 5 days: 136.35
# Doubling time yesterday: 2.9

# %% [markdown]
# ## Rimini

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rimini')
# Out:
# Total cases per 1000 inhabitants up to today: 3.2187
# Total cases up to today: 1084
# New cases registered today: 49
# New cases registered today in %: 4.73
# Doubling time in the last five days: 7.7
# Trend of new cases (in %) in the last 5 days: 56.87
# Doubling time yesterday: 6.6

# %% [markdown]
# # Casi di COVID-19 in Friuli Venezia Giulia - COVID-19 cases in Friuli Venezia Giulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Friuli Venezia Giulia')
# Out:
# Total cases up to today: 992
# New cases registered today: 62
# New cases registered today in %: 6.67
# Doubling time in the last five days: 6.9
# Trend of new cases (in %) in the last 5 days: 65.61
# Doubling time yesterday: 5.0

# %% [markdown]
# ## Gorizia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Gorizia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4081
# Total cases up to today: 57
# New cases registered today: 2
# New cases registered today in %: 3.64
# Doubling time in the last five days: 4.9
# Trend of new cases (in %) in the last 5 days: 103.57
# Doubling time yesterday: 4.4

# %% [markdown]
# ## Pordenone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pordenone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6441
# Total cases up to today: 201
# New cases registered today: 31
# New cases registered today in %: 18.24
# Doubling time in the last five days: 4.8
# Trend of new cases (in %) in the last 5 days: 107.22
# Doubling time yesterday: 4.3

# %% [markdown]
# ## Trieste

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trieste')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4019
# Total cases up to today: 329
# New cases registered today: 9
# New cases registered today in %: 2.81
# Doubling time in the last five days: 7.6
# Trend of new cases (in %) in the last 5 days: 58.17
# Doubling time yesterday: 6.0

# %% [markdown]
# ## Udine

# %%
calculate_and_create_chart_for_province(START_DATE, 'Udine')
# Out:
# Total cases per 1000 inhabitants up to today: 0.762
# Total cases up to today: 405
# New cases registered today: 20
# New cases registered today in %: 5.19
# Doubling time in the last five days: 8.2
# Trend of new cases (in %) in the last 5 days: 52.26
# Doubling time yesterday: 4.6

# %% [markdown]
# # Casi di COVID-19 nel Lazio - COVID-19 cases in Lazio

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lazio')
# Out:
# Total cases up to today: 1720
# New cases registered today: 184
# New cases registered today in %: 11.98
# Doubling time in the last five days: 4.7
# Trend of new cases (in %) in the last 5 days: 110.53
# Doubling time yesterday: 4.6

# %% [markdown]
# ## Frosinone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Frosinone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1967
# Total cases up to today: 97
# New cases registered today: 15
# New cases registered today in %: 18.29
# Doubling time in the last five days: 4.9
# Trend of new cases (in %) in the last 5 days: 102.08
# Doubling time yesterday: 8.3

# %% [markdown]
# ## Latina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Latina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3166
# Total cases up to today: 182
# New cases registered today: 23
# New cases registered today in %: 14.47
# Doubling time in the last five days: 1.7
# Trend of new cases (in %) in the last 5 days: 691.3
# Doubling time yesterday: 1.8

# %% [markdown]
# ## Rieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2096
# Total cases up to today: 33
# New cases registered today: 2
# New cases registered today in %: 6.45
# Doubling time in the last five days: 5.7
# Trend of new cases (in %) in the last 5 days: 83.33
# Doubling time yesterday: 3.7

# %% [markdown]
# ## Roma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Roma')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2956
# Total cases up to today: 1287
# New cases registered today: 116
# New cases registered today in %: 9.91
# Doubling time in the last five days: 5.4
# Trend of new cases (in %) in the last 5 days: 89.82
# Doubling time yesterday: 5.1

# %% [markdown]
# ## Viterbo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Viterbo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3793
# Total cases up to today: 121
# New cases registered today: 28
# New cases registered today in %: 30.11
# Doubling time in the last five days: 3.9
# Trend of new cases (in %) in the last 5 days: 142.0
# Doubling time yesterday: 4.0

# %% [markdown]
# # Casi di COVID-19 in Liguria - COVID-19 cases in Liguria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Liguria')
# Out:
# Total cases up to today: 1190
# New cases registered today: 46
# New cases registered today in %: 4.02
# Doubling time in the last five days: 9.4
# Trend of new cases (in %) in the last 5 days: 44.42
# Doubling time yesterday: 6.8

# %% [markdown]
# ## Genova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Genova')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8188
# Total cases up to today: 696
# New cases registered today: 7
# New cases registered today in %: 1.02
# Doubling time in the last five days: 9.8
# Trend of new cases (in %) in the last 5 days: 42.62
# Doubling time yesterday: 5.8

# %% [markdown]
# ## Imperia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Imperia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8646
# Total cases up to today: 186
# New cases registered today: 26
# New cases registered today in %: 16.25
# Doubling time in the last five days: 7.5
# Trend of new cases (in %) in the last 5 days: 58.97
# Doubling time yesterday: 7.5

# %% [markdown]
# ## La Spezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'La Spezia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4712
# Total cases up to today: 104
# New cases registered today: -6
# New cases registered today in %: -5.45
# Doubling time in the last five days: 20.7
# Trend of new cases (in %) in the last 5 days: 18.18
# Doubling time yesterday: 12.3

# %% [markdown]
# ## Savona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Savona')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7301
# Total cases up to today: 204
# New cases registered today: 19
# New cases registered today in %: 10.27
# Doubling time in the last five days: 7.8
# Trend of new cases (in %) in the last 5 days: 55.73
# Doubling time yesterday: 9.0

# %% [markdown]
# # Casi di COVID-19 in Lombardia - COVID-19 cases in Lombardy

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lombardia')
# Out:
# Total cases up to today: 30047
# New cases registered today: 1900
# New cases registered today in %: 6.75
# Doubling time in the last five days: 8.0
# Trend of new cases (in %) in the last 5 days: 54.41
# Doubling time yesterday: 7.1

# %% [markdown]
# ## Bergamo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bergamo')
# Out:
# Total cases per 1000 inhabitants up to today: 6.0616
# Total cases up to today: 6728
# New cases registered today: 257
# New cases registered today in %: 3.97
# Doubling time in the last five days: 9.4
# Trend of new cases (in %) in the last 5 days: 44.84
# Doubling time yesterday: 8.5

# %% [markdown]
# ## Brescia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brescia')
# Out:
# Total cases per 1000 inhabitants up to today: 4.9892
# Total cases up to today: 6298
# New cases registered today: 393
# New cases registered today in %: 6.66
# Doubling time in the last five days: 8.8
# Trend of new cases (in %) in the last 5 days: 48.29
# Doubling time yesterday: 7.8

# %% [markdown]
# ## Como

# %%
calculate_and_create_chart_for_province(START_DATE, 'Como')
# Out:
# Total cases per 1000 inhabitants up to today: 1.058
# Total cases up to today: 635
# New cases registered today: 54
# New cases registered today in %: 9.29
# Doubling time in the last five days: 5.5
# Trend of new cases (in %) in the last 5 days: 87.87
# Doubling time yesterday: 4.9

# %% [markdown]
# ## Cremona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cremona')
# Out:
# Total cases per 1000 inhabitants up to today: 8.5173
# Total cases up to today: 3061
# New cases registered today: 136
# New cases registered today in %: 4.65
# Doubling time in the last five days: 11.9
# Trend of new cases (in %) in the last 5 days: 33.9
# Doubling time yesterday: 11.6

# %% [markdown]
# ## Lecco

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecco')
# Out:
# Total cases per 1000 inhabitants up to today: 2.992
# Total cases up to today: 1015
# New cases registered today: 81
# New cases registered today in %: 8.67
# Doubling time in the last five days: 5.3
# Trend of new cases (in %) in the last 5 days: 91.51
# Doubling time yesterday: 5.0

# %% [markdown]
# ## Lodi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lodi')
# Out:
# Total cases per 1000 inhabitants up to today: 8.1103
# Total cases up to today: 1860
# New cases registered today: 43
# New cases registered today in %: 2.37
# Doubling time in the last five days: 17.6
# Trend of new cases (in %) in the last 5 days: 21.73
# Doubling time yesterday: 15.1

# %% [markdown]
# ## Mantova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Mantova')
# Out:
# Total cases per 1000 inhabitants up to today: 2.649
# Total cases up to today: 1093
# New cases registered today: 108
# New cases registered today in %: 10.96
# Doubling time in the last five days: 6.4
# Trend of new cases (in %) in the last 5 days: 71.86
# Doubling time yesterday: 5.3

# %% [markdown]
# ## Milano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Milano')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7715
# Total cases up to today: 5701
# New cases registered today: 375
# New cases registered today in %: 7.04
# Doubling time in the last five days: 6.3
# Trend of new cases (in %) in the last 5 days: 73.92
# Doubling time yesterday: 4.9

# %% [markdown]
# ## Monza e della Brianza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Monza e della Brianza')
# Out:
# Total cases per 1000 inhabitants up to today: 1.6735
# Total cases up to today: 1454
# New cases registered today: 324
# New cases registered today in %: 28.67
# Doubling time in the last five days: 3.2
# Trend of new cases (in %) in the last 5 days: 193.74
# Doubling time yesterday: 3.3

# %% [markdown]
# ## Pavia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pavia')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7391
# Total cases up to today: 1499
# New cases registered today: 55
# New cases registered today in %: 3.81
# Doubling time in the last five days: 8.8
# Trend of new cases (in %) in the last 5 days: 48.27
# Doubling time yesterday: 8.9

# %% [markdown]
# ## Sondrio

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sondrio')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3944
# Total cases up to today: 253
# New cases registered today: 45
# New cases registered today in %: 21.63
# Doubling time in the last five days: 7.1
# Trend of new cases (in %) in the last 5 days: 63.23
# Doubling time yesterday: 3.4

# %% [markdown]
# ## Varese

# %%
calculate_and_create_chart_for_province(START_DATE, 'Varese')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5056
# Total cases up to today: 450
# New cases registered today: 29
# New cases registered today in %: 6.89
# Doubling time in the last five days: 9.3
# Trend of new cases (in %) in the last 5 days: 45.16
# Doubling time yesterday: 7.5

# %% [markdown]
# # Casi di COVID-19 nelle Marche - COVID-19 cases in Marche

# %%
calculate_and_create_chart_for_region(START_DATE, 'Marche')
# Out:
# Total cases up to today: 2693
# New cases registered today: 159
# New cases registered today in %: 6.27
# Doubling time in the last five days: 7.6
# Trend of new cases (in %) in the last 5 days: 57.39
# Doubling time yesterday: 7.0

# %% [markdown]
# ## Ancona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ancona')
# Out:
# Total cases per 1000 inhabitants up to today: 1.584
# Total cases up to today: 751
# New cases registered today: 49
# New cases registered today in %: 6.98
# Doubling time in the last five days: 6.7
# Trend of new cases (in %) in the last 5 days: 68.01
# Doubling time yesterday: 6.2

# %% [markdown]
# ## Ascoli Piceno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ascoli Piceno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3056
# Total cases up to today: 64
# New cases registered today: 3
# New cases registered today in %: 4.92
# Doubling time in the last five days: 4.0
# Trend of new cases (in %) in the last 5 days: 137.04
# Doubling time yesterday: 3.9

# %% [markdown]
# ## Fermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Fermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.795
# Total cases up to today: 139
# New cases registered today: 6
# New cases registered today in %: 4.51
# Doubling time in the last five days: 4.8
# Trend of new cases (in %) in the last 5 days: 104.41
# Doubling time yesterday: 3.3

# %% [markdown]
# ## Macerata

# %%
calculate_and_create_chart_for_province(START_DATE, 'Macerata')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1539
# Total cases up to today: 368
# New cases registered today: 42
# New cases registered today in %: 12.88
# Doubling time in the last five days: 5.1
# Trend of new cases (in %) in the last 5 days: 97.85
# Doubling time yesterday: 4.9

# %% [markdown]
# ## Pesaro e Urbino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pesaro e Urbino')
# Out:
# Total cases per 1000 inhabitants up to today: 3.8008
# Total cases up to today: 1371
# New cases registered today: 59
# New cases registered today in %: 4.5
# Doubling time in the last five days: 10.4
# Trend of new cases (in %) in the last 5 days: 39.47
# Doubling time yesterday: 9.5

# %% [markdown]
# # Casi di COVID-19 in Molise - COVID-19 cases in Molise¶

# %%
calculate_and_create_chart_for_region(START_DATE, 'Molise')
# Out:
# Total cases up to today: 64
# New cases registered today: 6
# New cases registered today in %: 10.34
# Doubling time in the last five days: 6.3
# Trend of new cases (in %) in the last 5 days: 72.97
# Doubling time yesterday: 4.1

# %% [markdown]
# ## Campobasso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Campobasso')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2671
# Total cases up to today: 60
# New cases registered today: 6
# New cases registered today in %: 11.11
# Doubling time in the last five days: 5.8
# Trend of new cases (in %) in the last 5 days: 81.82
# Doubling time yesterday: 4.3

# %% [markdown]
# ## Isernia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Isernia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0466
# Total cases up to today: 4
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: nan
# Trend of new cases (in %) in the last 5 days: 0.0
# Doubling time yesterday: 2.5

# %% [markdown]
# # Casi di COVID-19 in Piemonte - COVID-19 cases in Piedmont

# %%
calculate_and_create_chart_for_region(START_DATE, 'Piemonte')
# Out:
# Total cases up to today: 5356
# New cases registered today: 639
# New cases registered today in %: 13.55
# Doubling time in the last five days: 3.9
# Trend of new cases (in %) in the last 5 days: 145.13
# Doubling time yesterday: 4.5

# %% [markdown]
# ## Alessandria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Alessandria')
# Out:
# Total cases per 1000 inhabitants up to today: 2.2172
# Total cases up to today: 946
# New cases registered today: 129
# New cases registered today in %: 15.79
# Doubling time in the last five days: 3.7
# Trend of new cases (in %) in the last 5 days: 152.94
# Doubling time yesterday: 4.4

# %% [markdown]
# ## Asti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Asti')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0846
# Total cases up to today: 235
# New cases registered today: 26
# New cases registered today in %: 12.44
# Doubling time in the last five days: 4.1
# Trend of new cases (in %) in the last 5 days: 132.67
# Doubling time yesterday: 4.8

# %% [markdown]
# ## Biella

# %%
calculate_and_create_chart_for_province(START_DATE, 'Biella')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5682
# Total cases up to today: 280
# New cases registered today: 27
# New cases registered today in %: 10.67
# Doubling time in the last five days: 3.7
# Trend of new cases (in %) in the last 5 days: 156.88
# Doubling time yesterday: 4.1

# %% [markdown]
# ## Cuneo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cuneo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6943
# Total cases up to today: 409
# New cases registered today: 42
# New cases registered today in %: 11.44
# Doubling time in the last five days: 3.4
# Trend of new cases (in %) in the last 5 days: 174.5
# Doubling time yesterday: 3.8

# %% [markdown]
# ## Novara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Novara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2725
# Total cases up to today: 471
# New cases registered today: 51
# New cases registered today in %: 12.14
# Doubling time in the last five days: 3.8
# Trend of new cases (in %) in the last 5 days: 147.89
# Doubling time yesterday: 4.4

# %% [markdown]
# ## Torino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Torino')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0958
# Total cases up to today: 2496
# New cases registered today: 298
# New cases registered today in %: 13.56
# Doubling time in the last five days: 4.0
# Trend of new cases (in %) in the last 5 days: 139.54
# Doubling time yesterday: 4.6

# %% [markdown]
# ## 	Verbano-Cusio-Ossola

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verbano-Cusio-Ossola')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4343
# Total cases up to today: 229
# New cases registered today: 39
# New cases registered today in %: 20.53
# Doubling time in the last five days: 3.7
# Trend of new cases (in %) in the last 5 days: 157.3
# Doubling time yesterday: 4.6

# %% [markdown]
# ## Vercelli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vercelli')
# Out:
# Total cases per 1000 inhabitants up to today: 1.6679
# Total cases up to today: 290
# New cases registered today: 27
# New cases registered today in %: 10.27
# Doubling time in the last five days: 4.4
# Trend of new cases (in %) in the last 5 days: 121.37
# Doubling time yesterday: 5.0

# %% [markdown]
# # Casi di COVID-19 in Puglia - COVID-19 cases in Apulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Puglia')
# Out:
# Total cases up to today: 936
# New cases registered today: 86
# New cases registered today in %: 10.12
# Doubling time in the last five days: 5.0
# Trend of new cases (in %) in the last 5 days: 100.86
# Doubling time yesterday: 4.2

# %% [markdown]
# ## Bari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2412
# Total cases up to today: 304
# New cases registered today: 36
# New cases registered today in %: 13.43
# Doubling time in the last five days: 4.3
# Trend of new cases (in %) in the last 5 days: 121.9
# Doubling time yesterday: 4.0

# %% [markdown]
# ## 	Barletta-Andria-Trani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Barletta-Andria-Trani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1579
# Total cases up to today: 62
# New cases registered today: 3
# New cases registered today in %: 5.08
# Doubling time in the last five days: 4.0
# Trend of new cases (in %) in the last 5 days: 138.46
# Doubling time yesterday: 3.7

# %% [markdown]
# ## Brindisi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brindisi')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2594
# Total cases up to today: 103
# New cases registered today: 1
# New cases registered today in %: 0.98
# Doubling time in the last five days: 10.9
# Trend of new cases (in %) in the last 5 days: 37.33
# Doubling time yesterday: 7.7

# %% [markdown]
# ## Foggia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Foggia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4057
# Total cases up to today: 255
# New cases registered today: 29
# New cases registered today in %: 12.83
# Doubling time in the last five days: 5.4
# Trend of new cases (in %) in the last 5 days: 90.3
# Doubling time yesterday: 3.8

# %% [markdown]
# ## Lecce

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecce')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2007
# Total cases up to today: 161
# New cases registered today: 12
# New cases registered today in %: 8.05
# Doubling time in the last five days: 4.2
# Trend of new cases (in %) in the last 5 days: 126.76
# Doubling time yesterday: 4.2

# %% [markdown]
# ## Taranto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Taranto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0874
# Total cases up to today: 51
# New cases registered today: 5
# New cases registered today in %: 10.87
# Doubling time in the last five days: 4.4
# Trend of new cases (in %) in the last 5 days: 121.74
# Doubling time yesterday: 3.9

# %% [markdown]
# # Casi di COVID-19 in Sardegna - COVID-19 cases in Sardinia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sardegna')
# Out:
# Total cases up to today: 421
# New cases registered today: 62
# New cases registered today in %: 17.27
# Doubling time in the last five days: 4.8
# Trend of new cases (in %) in the last 5 days: 104.37
# Doubling time yesterday: 3.5

# %% [markdown]
# ## Cagliari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cagliari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1142
# Total cases up to today: 64
# New cases registered today: 3
# New cases registered today in %: 4.92
# Doubling time in the last five days: 7.8
# Trend of new cases (in %) in the last 5 days: 56.1
# Doubling time yesterday: 5.4

# %% [markdown]
# ## Nuoro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Nuoro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1666
# Total cases up to today: 26
# New cases registered today: 4
# New cases registered today in %: 18.18
# Doubling time in the last five days: 16.2
# Trend of new cases (in %) in the last 5 days: 23.81
# Doubling time yesterday: 36.4

# %% [markdown]
# ## Oristano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Oristano')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0435
# Total cases up to today: 7
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 4.1
# Trend of new cases (in %) in the last 5 days: 133.33
# Doubling time yesterday: 4.1

# %% [markdown]
# ## Sassari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sassari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9276
# Total cases up to today: 309
# New cases registered today: 49
# New cases registered today in %: 18.85
# Doubling time in the last five days: 4.1
# Trend of new cases (in %) in the last 5 days: 130.6
# Doubling time yesterday: 2.8

# %% [markdown]
# # Casi di COVID-19 in Sicilia - COVID-19 cases in Sicily

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sicilia')
# Out:
# Total cases up to today: 846
# New cases registered today: 125
# New cases registered today in %: 17.34
# Doubling time in the last five days: 3.8
# Trend of new cases (in %) in the last 5 days: 148.82
# Doubling time yesterday: 3.7

# %% [markdown]
# ## Agrigento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Agrigento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1063
# Total cases up to today: 47
# New cases registered today: 2
# New cases registered today in %: 4.44
# Doubling time in the last five days: 6.3
# Trend of new cases (in %) in the last 5 days: 74.07
# Doubling time yesterday: 5.5

# %% [markdown]
# ## Caltanissetta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caltanissetta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1483
# Total cases up to today: 40
# New cases registered today: 11
# New cases registered today in %: 37.93
# Doubling time in the last five days: 2.9
# Trend of new cases (in %) in the last 5 days: 233.33
# Doubling time yesterday: 2.2

# %% [markdown]
# ## Catania

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catania')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2569
# Total cases up to today: 286
# New cases registered today: 12
# New cases registered today in %: 4.38
# Doubling time in the last five days: 5.4
# Trend of new cases (in %) in the last 5 days: 89.4
# Doubling time yesterday: 4.7

# %% [markdown]
# ## Enna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Enna')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3749
# Total cases up to today: 63
# New cases registered today: 19
# New cases registered today in %: 43.18
# Doubling time in the last five days: 3.2
# Trend of new cases (in %) in the last 5 days: 200.0
# Doubling time yesterday: 2.0

# %% [markdown]
# ## Messina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Messina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2183
# Total cases up to today: 139
# New cases registered today: 19
# New cases registered today in %: 15.83
# Doubling time in the last five days: 1.6
# Trend of new cases (in %) in the last 5 days: 768.75
# Doubling time yesterday: 1.7

# %% [markdown]
# ## Palermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Palermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.134
# Total cases up to today: 170
# New cases registered today: 61
# New cases registered today in %: 55.96
# Doubling time in the last five days: 2.9
# Trend of new cases (in %) in the last 5 days: 226.92
# Doubling time yesterday: 4.1

# %% [markdown]
# ## Ragusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ragusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.028
# Total cases up to today: 9
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 13.8
# Trend of new cases (in %) in the last 5 days: 28.57
# Doubling time yesterday: 8.5

# %% [markdown]
# ## Siracusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siracusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1216
# Total cases up to today: 49
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 8.8
# Trend of new cases (in %) in the last 5 days: 48.48
# Doubling time yesterday: 6.2

# %% [markdown]
# ## Trapani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trapani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.099
# Total cases up to today: 43
# New cases registered today: 1
# New cases registered today in %: 2.38
# Doubling time in the last five days: 4.8
# Trend of new cases (in %) in the last 5 days: 104.76
# Doubling time yesterday: 3.6

# %% [markdown]
# # Casi di COVID-19 in Toscana - COVID-19 cases in Tuscany

# %%
calculate_and_create_chart_for_region(START_DATE, 'Toscana')
# Out:
# Total cases up to today: 2699
# New cases registered today: 238
# New cases registered today in %: 9.67
# Doubling time in the last five days: 5.8
# Trend of new cases (in %) in the last 5 days: 82.12
# Doubling time yesterday: 5.6

# %% [markdown]
# ## Arezzo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Arezzo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6127
# Total cases up to today: 211
# New cases registered today: 10
# New cases registered today in %: 4.98
# Doubling time in the last five days: 5.5
# Trend of new cases (in %) in the last 5 days: 86.73
# Doubling time yesterday: 10.0

# %% [markdown]
# ## Firenze

# %%
calculate_and_create_chart_for_province(START_DATE, 'Firenze')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6132
# Total cases up to today: 622
# New cases registered today: 74
# New cases registered today in %: 13.5
# Doubling time in the last five days: 6.0
# Trend of new cases (in %) in the last 5 days: 78.22
# Doubling time yesterday: 5.6

# %% [markdown]
# ## Grosseto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Grosseto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6277
# Total cases up to today: 140
# New cases registered today: 12
# New cases registered today in %: 9.38
# Doubling time in the last five days: 7.7
# Trend of new cases (in %) in the last 5 days: 57.3
# Doubling time yesterday: 5.5

# %% [markdown]
# ## Livorno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Livorno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4802
# Total cases up to today: 162
# New cases registered today: 22
# New cases registered today in %: 15.71
# Doubling time in the last five days: 3.6
# Trend of new cases (in %) in the last 5 days: 161.29
# Doubling time yesterday: 4.3

# %% [markdown]
# ## Lucca

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lucca')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9922
# Total cases up to today: 387
# New cases registered today: 24
# New cases registered today in %: 6.61
# Doubling time in the last five days: 6.7
# Trend of new cases (in %) in the last 5 days: 68.26
# Doubling time yesterday: 6.1

# %% [markdown]
# ## Massa Carrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Massa Carrara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5973
# Total cases up to today: 314
# New cases registered today: 25
# New cases registered today in %: 8.65
# Doubling time in the last five days: 7.7
# Trend of new cases (in %) in the last 5 days: 57.0
# Doubling time yesterday: 7.0

# %% [markdown]
# ## Pisa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pisa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6756
# Total cases up to today: 285
# New cases registered today: 19
# New cases registered today in %: 7.14
# Doubling time in the last five days: 5.2
# Trend of new cases (in %) in the last 5 days: 95.21
# Doubling time yesterday: 4.5

# %% [markdown]
# ## Pistoia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pistoia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8327
# Total cases up to today: 243
# New cases registered today: 14
# New cases registered today in %: 6.11
# Doubling time in the last five days: 6.7
# Trend of new cases (in %) in the last 5 days: 67.59
# Doubling time yesterday: 5.5

# %% [markdown]
# ## Prato

# %%
calculate_and_create_chart_for_province(START_DATE, 'Prato')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6245
# Total cases up to today: 159
# New cases registered today: 22
# New cases registered today in %: 16.06
# Doubling time in the last five days: 4.2
# Trend of new cases (in %) in the last 5 days: 127.14
# Doubling time yesterday: 4.1

# %% [markdown]
# ## Siena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siena')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6559
# Total cases up to today: 176
# New cases registered today: 16
# New cases registered today in %: 10.0
# Doubling time in the last five days: 4.3
# Trend of new cases (in %) in the last 5 days: 125.64
# Doubling time yesterday: 4.7

# %% [markdown]
# # Casi di COVID-19 in Provincia Autonoma di Trento - COVID-19 cases in the Autonomous Province of Trento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trento')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0609
# Total cases up to today: 1110
# New cases registered today: 87
# New cases registered today in %: 8.5
# Doubling time in the last five days: 4.6
# Trend of new cases (in %) in the last 5 days: 112.24
# Doubling time yesterday: 4.3

# %% [markdown]
# # Casi di COVID-19 in Umbria - COVID-19 cases in Umbria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Umbria')
# Out:
# Total cases up to today: 627
# New cases registered today: 69
# New cases registered today in %: 12.37
# Doubling time in the last five days: 5.2
# Trend of new cases (in %) in the last 5 days: 95.94
# Doubling time yesterday: 4.1

# %% [markdown]
# ## Perugia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Perugia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7144
# Total cases up to today: 472
# New cases registered today: 48
# New cases registered today in %: 11.32
# Doubling time in the last five days: 5.0
# Trend of new cases (in %) in the last 5 days: 100.0
# Doubling time yesterday: 3.6

# %% [markdown]
# ## Terni

# %%
calculate_and_create_chart_for_province(START_DATE, 'Terni')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6792
# Total cases up to today: 155
# New cases registered today: 21
# New cases registered today in %: 15.67
# Doubling time in the last five days: 5.7
# Trend of new cases (in %) in the last 5 days: 84.52
# Doubling time yesterday: 5.8

# %% [markdown]
# # Casi di COVID-19 in Valle d'Aosta - COVID-19 cases in Aosta Valley

# %%
calculate_and_create_chart_for_province(START_DATE, "Aosta")
# Out:
# Total cases per 1000 inhabitants up to today: 3.1525
# Total cases up to today: 400
# New cases registered today: 7
# New cases registered today in %: 1.78
# Doubling time in the last five days: 5.6
# Trend of new cases (in %) in the last 5 days: 86.05
# Doubling time yesterday: 4.0

# %% [markdown]
# # Casi di COVID-19 in Veneto - COVID-19 cases in Veneto

# %%
calculate_and_create_chart_for_region(START_DATE, 'Veneto')
# Out:
# Total cases up to today: 5719
# New cases registered today: 426
# New cases registered today in %: 8.05
# Doubling time in the last five days: 6.5
# Trend of new cases (in %) in the last 5 days: 70.82
# Doubling time yesterday: 6.4

# %% [markdown]
# ## Belluno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Belluno')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3267
# Total cases up to today: 273
# New cases registered today: 19
# New cases registered today in %: 7.48
# Doubling time in the last five days: 5.8
# Trend of new cases (in %) in the last 5 days: 82.0
# Doubling time yesterday: 5.8

# %% [markdown]
# ## Padova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Padova')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5636
# Total cases up to today: 1464
# New cases registered today: 93
# New cases registered today in %: 6.78
# Doubling time in the last five days: 7.5
# Trend of new cases (in %) in the last 5 days: 58.44
# Doubling time yesterday: 7.9

# %% [markdown]
# ## Rovigo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rovigo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3437
# Total cases up to today: 82
# New cases registered today: 2
# New cases registered today in %: 2.5
# Doubling time in the last five days: 7.6
# Trend of new cases (in %) in the last 5 days: 57.69
# Doubling time yesterday: 3.9

# %% [markdown]
# ## Treviso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Treviso')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2314
# Total cases up to today: 1091
# New cases registered today: 92
# New cases registered today in %: 9.21
# Doubling time in the last five days: 6.4
# Trend of new cases (in %) in the last 5 days: 71.27
# Doubling time yesterday: 6.6

# %% [markdown]
# ## Venezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Venezia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9798
# Total cases up to today: 837
# New cases registered today: 38
# New cases registered today in %: 4.76
# Doubling time in the last five days: 6.1
# Trend of new cases (in %) in the last 5 days: 76.21
# Doubling time yesterday: 5.5

# %% [markdown]
# ## Verona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verona')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3325
# Total cases up to today: 1228
# New cases registered today: 129
# New cases registered today in %: 11.74
# Doubling time in the last five days: 6.0
# Trend of new cases (in %) in the last 5 days: 79.01
# Doubling time yesterday: 6.2

# %% [markdown]
# ## Vicenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vicenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.86
# Total cases up to today: 744
# New cases registered today: 53
# New cases registered today in %: 7.67
# Doubling time in the last five days: 6.2
# Trend of new cases (in %) in the last 5 days: 75.47
# Doubling time yesterday: 6.1
