# %%
import pandas as pd
import sys
import datetime
import matplotlib.pylab as plt
import numpy as np
from math import log, floor, ceil
from typing import Dict

# %%
START_DATE = datetime.date(2020,2,24)

# %%
def create_filename(day_str: str) -> str:
    return ('../dati-province/dpc-covid19-ita-province-' + day_str + '.csv')

# %%
def handle_Toscana_20200326_error(cases: Dict[str, int]) -> Dict[str, int]:
    cases['20200327'] = cases['20200326'] + floor((cases['20200328'] - cases['20200326'])/2)
    cases['20200328'] = cases['20200327'] + ceil((cases['20200328'] - cases['20200326'])/2)
    return cases

# %%
def calculate_and_create_chart_for_province(start_date: datetime.date, province: str):
    day = start_date
    cases: Dict[str,int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]==province]["totale_casi"])
        day: datetime.date = day + datetime.timedelta(days = 1)
    
    if df[df["denominazione_provincia"]==province]["denominazione_regione"].any()=='Toscana':
        cases = handle_Toscana_20200326_error(cases)
    
    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases per 1000 inhabitants up to today:", round(calculate_cases_to_inhabitants_ratio(cases_df_today, province),4))
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_region(start_date: datetime.date, region: str):
    day: datetime.date = start_date
    cases: Dict[str, int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[(df["denominazione_regione"]==region)&(df["denominazione_provincia"]!='In fase di definizione/aggiornamento')]["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)
        
    if region == 'Toscana':
        cases = handle_Toscana_20200326_error(cases)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_Italy(start_date: datetime.date):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]!='In fase di definizione/aggiornamento']["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)

    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_stats(cases_df):
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    cases_df_yesterday = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 1)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_five_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 5)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_six_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 6)).strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases up to today:", cases_df_today)
    print("New cases registered today:", cases_df_today-cases_df_yesterday)
    if int(cases_df_yesterday) != 0:
        print("New cases registered today in %:", round((cases_df_today-cases_df_yesterday)/cases_df_yesterday*100,2))

    print("Doubling time in the last five days:", round(calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago), 1))
    print("Doubling time yesterday:", round(calculate_doubling_time_in_the_last_five_days(cases_df_yesterday, cases_df_six_days_ago), 1))
    print("Trend of new cases (in %) in the last 5 days:", round((cases_df_today-cases_df_five_days_ago)/cases_df_five_days_ago*100,2))
    
    return

# %%
def calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago):
    if cases_df_five_days_ago ==0:
        return np.nan
    log_result = log(cases_df_today/cases_df_five_days_ago)
    if log_result != 0:
        return (5*log(2))/(log_result)
    else:
        return np.nan

# %%
def calculate_cases_to_inhabitants_ratio(cases: int, province: str) -> float:
    df_province: pd.DataFrame = pd.read_csv("../general/province.csv")
    inhabitants = df_province[df_province["Provincia"]==province]["Residenti"].str.replace('.', '', regex=True).sum()
    return int(cases)/int(inhabitants)*1000

# %% [markdown]
# # Casi di COVID-19 in Italia - COVID-19 cases in Italy

# %%
calculate_and_create_chart_for_Italy(START_DATE)
# Out:
# Total cases up to today: 107004
# New cases registered today: 4564
# New cases registered today in %: 4.46
# Doubling time in the last five days: 14.0
# Doubling time yesterday: 12.7
# Trend of new cases (in %) in the last 5 days: 28.15

# %% [markdown]
# # Casi di COVID-19 in Abruzzo - COVID-19 cases in Abruzzo

# %%
calculate_and_create_chart_for_region(START_DATE, 'Abruzzo')
# Out:
# Total cases up to today: 1436
# New cases registered today: 35
# New cases registered today in %: 2.5
# Doubling time in the last five days: 10.0
# Doubling time yesterday: 8.8
# Trend of new cases (in %) in the last 5 days: 41.2

# %% [markdown]
# ## Chieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Chieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7503
# Total cases up to today: 292
# New cases registered today: 12
# New cases registered today in %: 4.29
# Doubling time in the last five days: 8.0
# Doubling time yesterday: 7.4
# Trend of new cases (in %) in the last 5 days: 54.5

# %% [markdown]
# ## L'Aquila

# %%
calculate_and_create_chart_for_province(START_DATE, "L'Aquila")
# Out:
# Total cases per 1000 inhabitants up to today: 0.424
# Total cases up to today: 128
# New cases registered today: 5
# New cases registered today in %: 4.07
# Doubling time in the last five days: 6.5
# Doubling time yesterday: 5.3
# Trend of new cases (in %) in the last 5 days: 70.67

# %% [markdown]
# ## Pescara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pescara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9638
# Total cases up to today: 631
# New cases registered today: 9
# New cases registered today in %: 1.45
# Doubling time in the last five days: 12.3
# Doubling time yesterday: 10.3
# Trend of new cases (in %) in the last 5 days: 32.56

# %% [markdown]
# ## Teramo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Teramo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2425
# Total cases up to today: 385
# New cases registered today: 9
# New cases registered today in %: 2.39
# Doubling time in the last five days: 10.5
# Doubling time yesterday: 9.6
# Trend of new cases (in %) in the last 5 days: 38.99

# %% [markdown]
# # Casi di COVID-19 in Basilicata - COVID-19 cases in Basilicata

# %%
calculate_and_create_chart_for_region(START_DATE, 'Basilicata')
# Out:
# Total cases up to today: 237
# New cases registered today: 11
# New cases registered today in %: 4.87
# Doubling time in the last five days: 7.7
# Doubling time yesterday: 6.6
# Trend of new cases (in %) in the last 5 days: 56.95

# %% [markdown]
# ## Matera

# %%
calculate_and_create_chart_for_province(START_DATE, 'Matera')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5709
# Total cases up to today: 114
# New cases registered today: 10
# New cases registered today in %: 9.62
# Doubling time in the last five days: 4.5
# Doubling time yesterday: 4.5
# Trend of new cases (in %) in the last 5 days: 115.09

# %% [markdown]
# ## Potenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Potenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3318
# Total cases up to today: 123
# New cases registered today: 1
# New cases registered today in %: 0.82
# Doubling time in the last five days: 15.3
# Doubling time yesterday: 9.9
# Trend of new cases (in %) in the last 5 days: 25.51

# %% [markdown]
# # Casi di COVID-19 nella Provincia Autonoma di Bolzano - COVID-19 cases in Autonomous Province of Bolzano

# %%
calculate_and_create_chart_for_region(START_DATE, 'P.A. Bolzano')
# Out:
# Total cases up to today: 1418
# New cases registered today: 47
# New cases registered today in %: 3.43
# Doubling time in the last five days: 10.0
# Doubling time yesterday: 8.4
# Trend of new cases (in %) in the last 5 days: 41.38

# %% [markdown]
# # Casi di COVID-19 in Calabria - COVID-19 cases in Calabria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Calabria')
# Out:
# Total cases up to today: 667
# New cases registered today: 10
# New cases registered today in %: 1.52
# Doubling time in the last five days: 11.4
# Doubling time yesterday: 6.7
# Trend of new cases (in %) in the last 5 days: 35.57

# %% [markdown]
# ## Catanzaro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catanzaro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3864
# Total cases up to today: 140
# New cases registered today: 1
# New cases registered today in %: 0.72
# Doubling time in the last five days: 17.6
# Doubling time yesterday: 3.6
# Trend of new cases (in %) in the last 5 days: 21.74

# %% [markdown]
# ## Cosenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cosenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2641
# Total cases up to today: 188
# New cases registered today: 2
# New cases registered today in %: 1.08
# Doubling time in the last five days: 9.0
# Doubling time yesterday: 6.3
# Trend of new cases (in %) in the last 5 days: 46.88

# %% [markdown]
# ## Crotone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Crotone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5354
# Total cases up to today: 94
# New cases registered today: 1
# New cases registered today in %: 1.08
# Doubling time in the last five days: 21.5
# Doubling time yesterday: 23.0
# Trend of new cases (in %) in the last 5 days: 17.5

# %% [markdown]
# ## Reggio di Calabria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Reggio di Calabria')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3629
# Total cases up to today: 201
# New cases registered today: 6
# New cases registered today in %: 3.08
# Doubling time in the last five days: 9.6
# Doubling time yesterday: 7.5
# Trend of new cases (in %) in the last 5 days: 43.57

# %% [markdown]
# ## Vibo Valentia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vibo Valentia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2722
# Total cases up to today: 44
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 8.3
# Doubling time yesterday: 7.7
# Trend of new cases (in %) in the last 5 days: 51.72

# %% [markdown]
# # Casi di COVID-19 in Campania - COVID-19 cases in Campania

# %%
calculate_and_create_chart_for_region(START_DATE, 'Campania')
# Out:
# Total cases up to today: 2098
# New cases registered today: 181
# New cases registered today in %: 9.44
# Doubling time in the last five days: 7.9
# Doubling time yesterday: 8.6
# Trend of new cases (in %) in the last 5 days: 54.95

# %% [markdown]
# ## Avellino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Avellino')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6092
# Total cases up to today: 258
# New cases registered today: 32
# New cases registered today in %: 14.16
# Doubling time in the last five days: 9.9
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 41.76

# %% [markdown]
# ## Benevento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Benevento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2896
# Total cases up to today: 81
# New cases registered today: 5
# New cases registered today in %: 6.58
# Doubling time in the last five days: 2.1
# Doubling time yesterday: 2.0
# Trend of new cases (in %) in the last 5 days: 440.0

# %% [markdown]
# ## Caserta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caserta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2575
# Total cases up to today: 238
# New cases registered today: 17
# New cases registered today in %: 7.69
# Doubling time in the last five days: 12.2
# Doubling time yesterday: 15.6
# Trend of new cases (in %) in the last 5 days: 32.96

# %% [markdown]
# ## Napoli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Napoli')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3737
# Total cases up to today: 1161
# New cases registered today: 108
# New cases registered today in %: 10.26
# Doubling time in the last five days: 7.6
# Doubling time yesterday: 7.5
# Trend of new cases (in %) in the last 5 days: 58.17

# %% [markdown]
# ## Salerno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Salerno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3259
# Total cases up to today: 360
# New cases registered today: 19
# New cases registered today in %: 5.57
# Doubling time in the last five days: 8.9
# Doubling time yesterday: 10.4
# Trend of new cases (in %) in the last 5 days: 47.54

# %% [markdown]
# # Casi di COVID-19 in Emilia Romagna - COVID-19 cases in Emilia Romagna

# %%
calculate_and_create_chart_for_region(START_DATE, 'Emilia Romagna')
# Out:
# Total cases up to today: 0
# New cases registered today: 0
# Doubling time in the last five days: nan
# Doubling time yesterday: nan
# Trend of new cases (in %) in the last 5 days: nan
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in long_scalars
#   del sys.path[0]

# %% [markdown]
# ## Bologna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bologna')
# Out:
# Total cases per 1000 inhabitants up to today: 2.065
# Total cases up to today: 2084
# New cases registered today: 144
# New cases registered today in %: 7.42
# Doubling time in the last five days: 8.9
# Doubling time yesterday: 7.9
# Trend of new cases (in %) in the last 5 days: 47.49

# %% [markdown]
# ## Ferrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ferrara')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9358
# Total cases up to today: 326
# New cases registered today: 6
# New cases registered today in %: 1.88
# Doubling time in the last five days: 12.0
# Doubling time yesterday: 8.4
# Trend of new cases (in %) in the last 5 days: 33.61

# %% [markdown]
# ## Modena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Modena')
# Out:
# Total cases per 1000 inhabitants up to today: 3.2774
# Total cases up to today: 2297
# New cases registered today: 75
# New cases registered today in %: 3.38
# Doubling time in the last five days: 13.4
# Doubling time yesterday: 12.3
# Trend of new cases (in %) in the last 5 days: 29.63

# %% [markdown]
# ## Parma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Parma')
# Out:
# Total cases per 1000 inhabitants up to today: 4.4665
# Total cases up to today: 2005
# New cases registered today: 72
# New cases registered today in %: 3.72
# Doubling time in the last five days: 20.3
# Doubling time yesterday: 19.0
# Trend of new cases (in %) in the last 5 days: 18.64

# %% [markdown]
# ## Piacenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Piacenza')
# Out:
# Total cases per 1000 inhabitants up to today: 9.4714
# Total cases up to today: 2716
# New cases registered today: 81
# New cases registered today in %: 3.07
# Doubling time in the last five days: 19.6
# Doubling time yesterday: 19.9
# Trend of new cases (in %) in the last 5 days: 19.33

# %% [markdown]
# ## Ravenna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ravenna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5457
# Total cases up to today: 605
# New cases registered today: 25
# New cases registered today in %: 4.31
# Doubling time in the last five days: 16.1
# Doubling time yesterday: 13.8
# Trend of new cases (in %) in the last 5 days: 23.98

# %% [markdown]
# ## Reggio nell'Emilia

# %%
calculate_and_create_chart_for_province(START_DATE, "Reggio nell'Emilia")
# Out:
# Total cases per 1000 inhabitants up to today: 4.7945
# Total cases up to today: 2553
# New cases registered today: 246
# New cases registered today in %: 10.66
# Doubling time in the last five days: 11.0
# Doubling time yesterday: 11.3
# Trend of new cases (in %) in the last 5 days: 37.18

# %% [markdown]
# ## Rimini

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rimini')
# Out:
# Total cases per 1000 inhabitants up to today: 4.2906
# Total cases up to today: 1445
# New cases registered today: 38
# New cases registered today in %: 2.7
# Doubling time in the last five days: 25.9
# Doubling time yesterday: 20.6
# Trend of new cases (in %) in the last 5 days: 14.32

# %% [markdown]
# # Casi di COVID-19 in Friuli Venezia Giulia - COVID-19 cases in Friuli Venezia Giulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Friuli Venezia Giulia')
# Out:
# Total cases up to today: 1676
# New cases registered today: 92
# New cases registered today in %: 5.81
# Doubling time in the last five days: 14.0
# Doubling time yesterday: 13.1
# Trend of new cases (in %) in the last 5 days: 28.04

# %% [markdown]
# ## Gorizia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Gorizia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7589
# Total cases up to today: 106
# New cases registered today: 8
# New cases registered today in %: 8.16
# Doubling time in the last five days: 11.8
# Doubling time yesterday: 13.0
# Trend of new cases (in %) in the last 5 days: 34.18

# %% [markdown]
# ## Pordenone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pordenone')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3427
# Total cases up to today: 419
# New cases registered today: 14
# New cases registered today in %: 3.46
# Doubling time in the last five days: 14.9
# Doubling time yesterday: 10.9
# Trend of new cases (in %) in the last 5 days: 26.2

# %% [markdown]
# ## Trieste

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trieste')
# Out:
# Total cases per 1000 inhabitants up to today: 2.4501
# Total cases up to today: 575
# New cases registered today: 30
# New cases registered today in %: 5.5
# Doubling time in the last five days: 10.3
# Doubling time yesterday: 10.0
# Trend of new cases (in %) in the last 5 days: 39.9

# %% [markdown]
# ## Udine

# %%
calculate_and_create_chart_for_province(START_DATE, 'Udine')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0838
# Total cases up to today: 576
# New cases registered today: 40
# New cases registered today in %: 7.46
# Doubling time in the last five days: 20.6
# Doubling time yesterday: 22.7
# Trend of new cases (in %) in the last 5 days: 18.28

# %% [markdown]
# # Casi di COVID-19 nel Lazio - COVID-19 cases in Lazio

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lazio')
# Out:
# Total cases up to today: 3247
# New cases registered today: 170
# New cases registered today in %: 5.52
# Doubling time in the last five days: 9.7
# Doubling time yesterday: 9.0
# Trend of new cases (in %) in the last 5 days: 42.85

# %% [markdown]
# ## Frosinone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Frosinone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6673
# Total cases up to today: 329
# New cases registered today: 8
# New cases registered today in %: 2.49
# Doubling time in the last five days: 6.4
# Doubling time yesterday: 4.8
# Trend of new cases (in %) in the last 5 days: 72.25

# %% [markdown]
# ## Latina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Latina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4731
# Total cases up to today: 272
# New cases registered today: 15
# New cases registered today in %: 5.84
# Doubling time in the last five days: 13.9
# Doubling time yesterday: 15.7
# Trend of new cases (in %) in the last 5 days: 28.3

# %% [markdown]
# ## Rieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rieti')
# Out:
# Total cases per 1000 inhabitants up to today: 1.226
# Total cases up to today: 193
# New cases registered today: 61
# New cases registered today in %: 46.21
# Doubling time in the last five days: 2.3
# Doubling time yesterday: 3.0
# Trend of new cases (in %) in the last 5 days: 348.84

# %% [markdown]
# ## Roma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Roma')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5191
# Total cases up to today: 2260
# New cases registered today: 74
# New cases registered today in %: 3.39
# Doubling time in the last five days: 12.2
# Doubling time yesterday: 10.4
# Trend of new cases (in %) in the last 5 days: 32.71

# %% [markdown]
# ## Viterbo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Viterbo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.605
# Total cases up to today: 193
# New cases registered today: 12
# New cases registered today in %: 6.63
# Doubling time in the last five days: 7.8
# Doubling time yesterday: 8.8
# Trend of new cases (in %) in the last 5 days: 55.65

# %% [markdown]
# # Casi di COVID-19 in Liguria - COVID-19 cases in Liguria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Liguria')
# Out:
# Total cases up to today: 1830
# New cases registered today: 4
# New cases registered today in %: 0.22
# Doubling time in the last five days: 15.7
# Doubling time yesterday: 11.0
# Trend of new cases (in %) in the last 5 days: 24.74

# %% [markdown]
# ## Genova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Genova')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3034
# Total cases up to today: 1108
# New cases registered today: 13
# New cases registered today in %: 1.19
# Doubling time in the last five days: 11.4
# Doubling time yesterday: 9.6
# Trend of new cases (in %) in the last 5 days: 35.62

# %% [markdown]
# ## Imperia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Imperia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0505
# Total cases up to today: 226
# New cases registered today: -8
# New cases registered today in %: -3.42
# Doubling time in the last five days: 63.5
# Doubling time yesterday: 33.5
# Trend of new cases (in %) in the last 5 days: 5.61

# %% [markdown]
# ## La Spezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'La Spezia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1101
# Total cases up to today: 245
# New cases registered today: -3
# New cases registered today in %: -1.21
# Doubling time in the last five days: 24.8
# Doubling time yesterday: 6.8
# Trend of new cases (in %) in the last 5 days: 15.02

# %% [markdown]
# ## Savona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Savona')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8983
# Total cases up to today: 251
# New cases registered today: 2
# New cases registered today in %: 0.8
# Doubling time in the last five days: 29.3
# Doubling time yesterday: 19.8
# Trend of new cases (in %) in the last 5 days: 12.56

# %% [markdown]
# # Casi di COVID-19 in Lombardia - COVID-19 cases in Lombardy

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lombardia')
# Out:
# Total cases up to today: 43810
# New cases registered today: 1527
# New cases registered today in %: 3.61
# Doubling time in the last five days: 19.0
# Doubling time yesterday: 16.1
# Trend of new cases (in %) in the last 5 days: 20.05

# %% [markdown]
# ## Bergamo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bergamo')
# Out:
# Total cases per 1000 inhabitants up to today: 8.1437
# Total cases up to today: 9039
# New cases registered today: 236
# New cases registered today in %: 2.68
# Doubling time in the last five days: 30.2
# Doubling time yesterday: 20.9
# Trend of new cases (in %) in the last 5 days: 12.15

# %% [markdown]
# ## Brescia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brescia')
# Out:
# Total cases per 1000 inhabitants up to today: 6.8113
# Total cases up to today: 8598
# New cases registered today: 231
# New cases registered today in %: 2.76
# Doubling time in the last five days: 21.3
# Doubling time yesterday: 18.4
# Trend of new cases (in %) in the last 5 days: 17.7

# %% [markdown]
# ## Como

# %%
calculate_and_create_chart_for_province(START_DATE, 'Como')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9277
# Total cases up to today: 1157
# New cases registered today: 56
# New cases registered today in %: 5.09
# Doubling time in the last five days: 9.9
# Doubling time yesterday: 9.4
# Trend of new cases (in %) in the last 5 days: 41.79

# %% [markdown]
# ## Cremona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cremona')
# Out:
# Total cases per 1000 inhabitants up to today: 10.9659
# Total cases up to today: 3941
# New cases registered today: 72
# New cases registered today in %: 1.86
# Doubling time in the last five days: 28.9
# Doubling time yesterday: 25.1
# Trend of new cases (in %) in the last 5 days: 12.73

# %% [markdown]
# ## Lecco

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecco')
# Out:
# Total cases per 1000 inhabitants up to today: 4.4688
# Total cases up to today: 1516
# New cases registered today: 46
# New cases registered today in %: 3.13
# Doubling time in the last five days: 15.4
# Doubling time yesterday: 14.6
# Trend of new cases (in %) in the last 5 days: 25.29

# %% [markdown]
# ## Lodi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lodi')
# Out:
# Total cases per 1000 inhabitants up to today: 9.4053
# Total cases up to today: 2157
# New cases registered today: 41
# New cases registered today in %: 1.94
# Doubling time in the last five days: 47.8
# Doubling time yesterday: 47.8
# Trend of new cases (in %) in the last 5 days: 7.53

# %% [markdown]
# ## Mantova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Mantova')
# Out:
# Total cases per 1000 inhabitants up to today: 4.2074
# Total cases up to today: 1736
# New cases registered today: 48
# New cases registered today in %: 2.84
# Doubling time in the last five days: 16.0
# Doubling time yesterday: 11.5
# Trend of new cases (in %) in the last 5 days: 24.18

# %% [markdown]
# ## Milano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Milano')
# Out:
# Total cases per 1000 inhabitants up to today: 2.9588
# Total cases up to today: 9522
# New cases registered today: 611
# New cases registered today in %: 6.86
# Doubling time in the last five days: 14.3
# Doubling time yesterday: 13.7
# Trend of new cases (in %) in the last 5 days: 27.49

# %% [markdown]
# ## Monza e della Brianza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Monza e della Brianza')
# Out:
# Total cases per 1000 inhabitants up to today: 2.9268
# Total cases up to today: 2543
# New cases registered today: 81
# New cases registered today in %: 3.29
# Doubling time in the last five days: 13.0
# Doubling time yesterday: 10.2
# Trend of new cases (in %) in the last 5 days: 30.54

# %% [markdown]
# ## Pavia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pavia')
# Out:
# Total cases per 1000 inhabitants up to today: 3.9835
# Total cases up to today: 2180
# New cases registered today: 47
# New cases registered today in %: 2.2
# Doubling time in the last five days: 14.3
# Doubling time yesterday: 14.7
# Trend of new cases (in %) in the last 5 days: 27.34

# %% [markdown]
# ## Sondrio

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sondrio')
# Out:
# Total cases per 1000 inhabitants up to today: 2.6676
# Total cases up to today: 484
# New cases registered today: 14
# New cases registered today in %: 2.98
# Doubling time in the last five days: 11.9
# Doubling time yesterday: 9.4
# Trend of new cases (in %) in the last 5 days: 33.7

# %% [markdown]
# ## Varese

# %%
calculate_and_create_chart_for_province(START_DATE, 'Varese')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0528
# Total cases up to today: 937
# New cases registered today: 44
# New cases registered today in %: 4.93
# Doubling time in the last five days: 12.6
# Doubling time yesterday: 6.0
# Trend of new cases (in %) in the last 5 days: 31.79

# %% [markdown]
# # Casi di COVID-19 nelle Marche - COVID-19 cases in Marche

# %%
calculate_and_create_chart_for_region(START_DATE, 'Marche')
# Out:
# Total cases up to today: 3889
# New cases registered today: 135
# New cases registered today in %: 3.6
# Doubling time in the last five days: 16.2
# Doubling time yesterday: 17.0
# Trend of new cases (in %) in the last 5 days: 23.77

# %% [markdown]
# ## Ancona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ancona')
# Out:
# Total cases per 1000 inhabitants up to today: 2.4761
# Total cases up to today: 1174
# New cases registered today: 58
# New cases registered today in %: 5.2
# Doubling time in the last five days: 13.3
# Doubling time yesterday: 13.9
# Trend of new cases (in %) in the last 5 days: 29.72

# %% [markdown]
# ## Ascoli Piceno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ascoli Piceno')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0695
# Total cases up to today: 224
# New cases registered today: 2
# New cases registered today in %: 0.9
# Doubling time in the last five days: 5.4
# Doubling time yesterday: 5.0
# Trend of new cases (in %) in the last 5 days: 89.83

# %% [markdown]
# ## Fermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Fermo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5042
# Total cases up to today: 263
# New cases registered today: 4
# New cases registered today in %: 1.54
# Doubling time in the last five days: 28.6
# Doubling time yesterday: 14.5
# Trend of new cases (in %) in the last 5 days: 12.88

# %% [markdown]
# ## Macerata

# %%
calculate_and_create_chart_for_province(START_DATE, 'Macerata')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5866
# Total cases up to today: 506
# New cases registered today: 13
# New cases registered today in %: 2.64
# Doubling time in the last five days: 16.7
# Doubling time yesterday: 17.6
# Trend of new cases (in %) in the last 5 days: 23.11

# %% [markdown]
# ## Pesaro e Urbino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pesaro e Urbino')
# Out:
# Total cases per 1000 inhabitants up to today: 4.7739
# Total cases up to today: 1722
# New cases registered today: 58
# New cases registered today in %: 3.49
# Doubling time in the last five days: 22.4
# Doubling time yesterday: 28.6
# Trend of new cases (in %) in the last 5 days: 16.75

# %% [markdown]
# # Casi di COVID-19 in Molise - COVID-19 cases in Molise¶

# %%
calculate_and_create_chart_for_region(START_DATE, 'Molise')
# Out:
# Total cases up to today: 149
# New cases registered today: 16
# New cases registered today in %: 12.03
# Doubling time in the last five days: 8.7
# Doubling time yesterday: 10.0
# Trend of new cases (in %) in the last 5 days: 49.0

# %% [markdown]
# ## Campobasso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Campobasso')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6188
# Total cases up to today: 139
# New cases registered today: 15
# New cases registered today in %: 12.1
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 9.2
# Trend of new cases (in %) in the last 5 days: 52.75

# %% [markdown]
# ## Isernia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Isernia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1165
# Total cases up to today: 10
# New cases registered today: 1
# New cases registered today in %: 11.11
# Doubling time in the last five days: 32.9
# Doubling time yesterday: nan
# Trend of new cases (in %) in the last 5 days: 11.11

# %% [markdown]
# # Casi di COVID-19 in Piemonte - COVID-19 cases in Piedmont

# %%
calculate_and_create_chart_for_region(START_DATE, 'Piemonte')
# Out:
# Total cases up to today: 9583
# New cases registered today: 493
# New cases registered today in %: 5.42
# Doubling time in the last five days: 10.6
# Doubling time yesterday: 9.7
# Trend of new cases (in %) in the last 5 days: 38.68

# %% [markdown]
# ## Alessandria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Alessandria')
# Out:
# Total cases per 1000 inhabitants up to today: 3.2298
# Total cases up to today: 1378
# New cases registered today: 61
# New cases registered today in %: 4.63
# Doubling time in the last five days: 15.8
# Doubling time yesterday: 11.7
# Trend of new cases (in %) in the last 5 days: 24.59

# %% [markdown]
# ## Asti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Asti')
# Out:
# Total cases per 1000 inhabitants up to today: 2.1276
# Total cases up to today: 461
# New cases registered today: 27
# New cases registered today in %: 6.22
# Doubling time in the last five days: 8.3
# Doubling time yesterday: 8.0
# Trend of new cases (in %) in the last 5 days: 52.15

# %% [markdown]
# ## Biella

# %%
calculate_and_create_chart_for_province(START_DATE, 'Biella')
# Out:
# Total cases per 1000 inhabitants up to today: 2.8171
# Total cases up to today: 503
# New cases registered today: 13
# New cases registered today in %: 2.65
# Doubling time in the last five days: 11.0
# Doubling time yesterday: 9.2
# Trend of new cases (in %) in the last 5 days: 37.06

# %% [markdown]
# ## Cuneo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cuneo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3206
# Total cases up to today: 778
# New cases registered today: 47
# New cases registered today in %: 6.43
# Doubling time in the last five days: 8.5
# Doubling time yesterday: 8.5
# Trend of new cases (in %) in the last 5 days: 50.19

# %% [markdown]
# ## Novara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Novara')
# Out:
# Total cases per 1000 inhabitants up to today: 2.3072
# Total cases up to today: 854
# New cases registered today: 57
# New cases registered today in %: 7.15
# Doubling time in the last five days: 10.3
# Doubling time yesterday: 10.7
# Trend of new cases (in %) in the last 5 days: 40.23

# %% [markdown]
# ## Torino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Torino')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0682
# Total cases up to today: 4711
# New cases registered today: 256
# New cases registered today in %: 5.75
# Doubling time in the last five days: 10.3
# Doubling time yesterday: 9.6
# Trend of new cases (in %) in the last 5 days: 40.17

# %% [markdown]
# ## 	Verbano-Cusio-Ossola

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verbano-Cusio-Ossola')
# Out:
# Total cases per 1000 inhabitants up to today: 2.5679
# Total cases up to today: 410
# New cases registered today: 17
# New cases registered today in %: 4.33
# Doubling time in the last five days: 9.8
# Doubling time yesterday: 8.0
# Trend of new cases (in %) in the last 5 days: 42.36

# %% [markdown]
# ## Vercelli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vercelli')
# Out:
# Total cases per 1000 inhabitants up to today: 2.8067
# Total cases up to today: 488
# New cases registered today: 15
# New cases registered today in %: 3.17
# Doubling time in the last five days: 11.2
# Doubling time yesterday: 10.1
# Trend of new cases (in %) in the last 5 days: 36.31

# %% [markdown]
# # Casi di COVID-19 in Puglia - COVID-19 cases in Apulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Puglia')
# Out:
# Total cases up to today: 1921
# New cases registered today: 144
# New cases registered today in %: 8.1
# Doubling time in the last five days: 8.5
# Doubling time yesterday: 8.0
# Trend of new cases (in %) in the last 5 days: 50.2

# %% [markdown]
# ## Bari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5198
# Total cases up to today: 655
# New cases registered today: 39
# New cases registered today in %: 6.33
# Doubling time in the last five days: 8.9
# Doubling time yesterday: 7.5
# Trend of new cases (in %) in the last 5 days: 47.52

# %% [markdown]
# ## 	Barletta-Andria-Trani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Barletta-Andria-Trani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2955
# Total cases up to today: 116
# New cases registered today: 5
# New cases registered today in %: 4.5
# Doubling time in the last five days: 15.0
# Doubling time yesterday: 13.0
# Trend of new cases (in %) in the last 5 days: 26.09

# %% [markdown]
# ## Brindisi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brindisi')
# Out:
# Total cases per 1000 inhabitants up to today: 0.481
# Total cases up to today: 191
# New cases registered today: 27
# New cases registered today in %: 16.46
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 11.7
# Trend of new cases (in %) in the last 5 days: 52.8

# %% [markdown]
# ## Foggia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Foggia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7796
# Total cases up to today: 490
# New cases registered today: 33
# New cases registered today in %: 7.22
# Doubling time in the last five days: 8.4
# Doubling time yesterday: 8.6
# Trend of new cases (in %) in the last 5 days: 50.77

# %% [markdown]
# ## Lecce

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecce')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4002
# Total cases up to today: 321
# New cases registered today: 18
# New cases registered today in %: 5.94
# Doubling time in the last five days: 8.6
# Doubling time yesterday: 6.4
# Trend of new cases (in %) in the last 5 days: 49.3

# %% [markdown]
# ## Taranto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Taranto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2537
# Total cases up to today: 148
# New cases registered today: 22
# New cases registered today in %: 17.46
# Doubling time in the last five days: 5.4
# Doubling time yesterday: 6.5
# Trend of new cases (in %) in the last 5 days: 89.74

# %% [markdown]
# # Casi di COVID-19 in Sardegna - COVID-19 cases in Sardinia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sardegna')
# Out:
# Total cases up to today: 745
# New cases registered today: 23
# New cases registered today in %: 3.19
# Doubling time in the last five days: 10.2
# Doubling time yesterday: 9.1
# Trend of new cases (in %) in the last 5 days: 40.57

# %% [markdown]
# ## Cagliari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cagliari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.207
# Total cases up to today: 116
# New cases registered today: 5
# New cases registered today in %: 4.5
# Doubling time in the last five days: 10.4
# Doubling time yesterday: 11.9
# Trend of new cases (in %) in the last 5 days: 39.76

# %% [markdown]
# ## Nuoro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Nuoro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.378
# Total cases up to today: 59
# New cases registered today: 2
# New cases registered today in %: 3.51
# Doubling time in the last five days: 27.4
# Doubling time yesterday: 37.8
# Trend of new cases (in %) in the last 5 days: 13.46

# %% [markdown]
# ## Oristano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Oristano')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0933
# Total cases up to today: 15
# New cases registered today: 5
# New cases registered today in %: 50.0
# Doubling time in the last five days: 6.8
# Doubling time yesterday: 9.7
# Trend of new cases (in %) in the last 5 days: 66.67

# %% [markdown]
# ## Sassari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sassari')
# Out:
# Total cases per 1000 inhabitants up to today: 1.492
# Total cases up to today: 497
# New cases registered today: 11
# New cases registered today in %: 2.26
# Doubling time in the last five days: 8.9
# Doubling time yesterday: 9.0
# Trend of new cases (in %) in the last 5 days: 47.92

# %% [markdown]
# # Casi di COVID-19 in Sicilia - COVID-19 cases in Sicily

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sicilia')
# Out:
# Total cases up to today: 1718
# New cases registered today: 71
# New cases registered today in %: 4.31
# Doubling time in the last five days: 10.9
# Doubling time yesterday: 10.0
# Trend of new cases (in %) in the last 5 days: 37.44

# %% [markdown]
# ## Agrigento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Agrigento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2172
# Total cases up to today: 96
# New cases registered today: 2
# New cases registered today in %: 2.13
# Doubling time in the last five days: 6.9
# Doubling time yesterday: 6.5
# Trend of new cases (in %) in the last 5 days: 65.52

# %% [markdown]
# ## Caltanissetta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caltanissetta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2818
# Total cases up to today: 76
# New cases registered today: 6
# New cases registered today in %: 8.57
# Doubling time in the last five days: 10.7
# Doubling time yesterday: 10.3
# Trend of new cases (in %) in the last 5 days: 38.18

# %% [markdown]
# ## Catania

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catania')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4581
# Total cases up to today: 510
# New cases registered today: 12
# New cases registered today in %: 2.41
# Doubling time in the last five days: 10.4
# Doubling time yesterday: 9.5
# Trend of new cases (in %) in the last 5 days: 39.73

# %% [markdown]
# ## Enna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Enna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3329
# Total cases up to today: 224
# New cases registered today: 21
# New cases registered today in %: 10.34
# Doubling time in the last five days: 9.4
# Doubling time yesterday: 8.2
# Trend of new cases (in %) in the last 5 days: 44.52

# %% [markdown]
# ## Messina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Messina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5011
# Total cases up to today: 319
# New cases registered today: 8
# New cases registered today in %: 2.57
# Doubling time in the last five days: 10.2
# Doubling time yesterday: 10.1
# Trend of new cases (in %) in the last 5 days: 40.53

# %% [markdown]
# ## Palermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Palermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2176
# Total cases up to today: 276
# New cases registered today: 14
# New cases registered today in %: 5.34
# Doubling time in the last five days: 14.7
# Doubling time yesterday: 14.1
# Trend of new cases (in %) in the last 5 days: 26.61

# %% [markdown]
# ## Ragusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ragusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1369
# Total cases up to today: 44
# New cases registered today: 1
# New cases registered today in %: 2.33
# Doubling time in the last five days: 10.9
# Doubling time yesterday: 8.1
# Trend of new cases (in %) in the last 5 days: 37.5

# %% [markdown]
# ## Siracusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siracusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2433
# Total cases up to today: 98
# New cases registered today: 5
# New cases registered today in %: 5.38
# Doubling time in the last five days: 16.1
# Doubling time yesterday: 18.4
# Trend of new cases (in %) in the last 5 days: 24.05

# %% [markdown]
# ## Trapani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trapani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1726
# Total cases up to today: 75
# New cases registered today: 2
# New cases registered today in %: 2.74
# Doubling time in the last five days: 16.8
# Doubling time yesterday: 8.7
# Trend of new cases (in %) in the last 5 days: 22.95

# %% [markdown]
# # Casi di COVID-19 in Toscana - COVID-19 cases in Tuscany

# %%
calculate_and_create_chart_for_region(START_DATE, 'Toscana')
# Out:
# Total cases up to today: 4867
# New cases registered today: 259
# New cases registered today in %: 5.62
# Doubling time in the last five days: 10.7
# Doubling time yesterday: 9.7
# Trend of new cases (in %) in the last 5 days: 38.23

# %% [markdown]
# ## Arezzo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Arezzo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.996
# Total cases up to today: 343
# New cases registered today: 11
# New cases registered today in %: 3.31
# Doubling time in the last five days: 12.5
# Doubling time yesterday: 12.0
# Trend of new cases (in %) in the last 5 days: 31.92

# %% [markdown]
# ## Firenze

# %%
calculate_and_create_chart_for_province(START_DATE, 'Firenze')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1415
# Total cases up to today: 1158
# New cases registered today: 71
# New cases registered today in %: 6.53
# Doubling time in the last five days: 9.7
# Doubling time yesterday: 9.8
# Trend of new cases (in %) in the last 5 days: 43.14

# %% [markdown]
# ## Grosseto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Grosseto')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1791
# Total cases up to today: 263
# New cases registered today: 6
# New cases registered today in %: 2.33
# Doubling time in the last five days: 13.6
# Doubling time yesterday: 8.9
# Trend of new cases (in %) in the last 5 days: 28.92

# %% [markdown]
# ## Livorno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Livorno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8745
# Total cases up to today: 295
# New cases registered today: 15
# New cases registered today in %: 5.36
# Doubling time in the last five days: 10.5
# Doubling time yesterday: 10.9
# Trend of new cases (in %) in the last 5 days: 39.15

# %% [markdown]
# ## Lucca

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lucca')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9767
# Total cases up to today: 771
# New cases registered today: 42
# New cases registered today in %: 5.76
# Doubling time in the last five days: 10.2
# Doubling time yesterday: 8.3
# Trend of new cases (in %) in the last 5 days: 40.44

# %% [markdown]
# ## Massa Carrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Massa Carrara')
# Out:
# Total cases per 1000 inhabitants up to today: 3.1081
# Total cases up to today: 611
# New cases registered today: 50
# New cases registered today in %: 8.91
# Doubling time in the last five days: 8.3
# Doubling time yesterday: 6.7
# Trend of new cases (in %) in the last 5 days: 51.99

# %% [markdown]
# ## Pisa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pisa')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1639
# Total cases up to today: 491
# New cases registered today: 20
# New cases registered today in %: 4.25
# Doubling time in the last five days: 12.7
# Doubling time yesterday: 11.7
# Trend of new cases (in %) in the last 5 days: 31.28

# %% [markdown]
# ## Pistoia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pistoia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.141
# Total cases up to today: 333
# New cases registered today: 1
# New cases registered today in %: 0.3
# Doubling time in the last five days: 20.4
# Doubling time yesterday: 15.1
# Trend of new cases (in %) in the last 5 days: 18.51

# %% [markdown]
# ## Prato

# %%
calculate_and_create_chart_for_province(START_DATE, 'Prato')
# Out:
# Total cases per 1000 inhabitants up to today: 1.139
# Total cases up to today: 290
# New cases registered today: 32
# New cases registered today in %: 12.4
# Doubling time in the last five days: 9.7
# Doubling time yesterday: 11.1
# Trend of new cases (in %) in the last 5 days: 42.86

# %% [markdown]
# ## Siena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siena')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1627
# Total cases up to today: 312
# New cases registered today: 11
# New cases registered today in %: 3.65
# Doubling time in the last five days: 10.6
# Doubling time yesterday: 10.4
# Trend of new cases (in %) in the last 5 days: 38.67

# %% [markdown]
# # Casi di COVID-19 in Provincia Autonoma di Trento - COVID-19 cases in the Autonomous Province of Trento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trento')
# Out:
# Total cases per 1000 inhabitants up to today: 3.4719
# Total cases up to today: 1870
# New cases registered today: 124
# New cases registered today in %: 7.1
# Doubling time in the last five days: 11.7
# Doubling time yesterday: 11.7
# Trend of new cases (in %) in the last 5 days: 34.44

# %% [markdown]
# # Casi di COVID-19 in Umbria - COVID-19 cases in Umbria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Umbria')
# Out:
# Total cases up to today: 1058
# New cases registered today: 15
# New cases registered today in %: 1.44
# Doubling time in the last five days: 16.1
# Doubling time yesterday: 11.8
# Trend of new cases (in %) in the last 5 days: 24.03

# %% [markdown]
# ## Perugia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Perugia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2442
# Total cases up to today: 822
# New cases registered today: 9
# New cases registered today in %: 1.11
# Doubling time in the last five days: 15.6
# Doubling time yesterday: 11.4
# Trend of new cases (in %) in the last 5 days: 24.92

# %% [markdown]
# ## Terni

# %%
calculate_and_create_chart_for_province(START_DATE, 'Terni')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0341
# Total cases up to today: 236
# New cases registered today: 6
# New cases registered today in %: 2.61
# Doubling time in the last five days: 18.2
# Doubling time yesterday: 13.5
# Trend of new cases (in %) in the last 5 days: 21.03

# %% [markdown]
# # Casi di COVID-19 in Valle d'Aosta - COVID-19 cases in Aosta Valley

# %%
calculate_and_create_chart_for_province(START_DATE, "Aosta")
# Out:
# Total cases per 1000 inhabitants up to today: 4.9731
# Total cases up to today: 631
# New cases registered today: 3
# New cases registered today in %: 0.48
# Doubling time in the last five days: 10.4
# Doubling time yesterday: 8.0
# Trend of new cases (in %) in the last 5 days: 39.6

# %% [markdown]
# # Casi di COVID-19 in Veneto - COVID-19 cases in Veneto

# %%
calculate_and_create_chart_for_region(START_DATE, 'Veneto')
# Out:
# Total cases up to today: 9367
# New cases registered today: 491
# New cases registered today in %: 5.53
# Doubling time in the last five days: 13.3
# Doubling time yesterday: 12.2
# Trend of new cases (in %) in the last 5 days: 29.77

# %% [markdown]
# ## Belluno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Belluno')
# Out:
# Total cases per 1000 inhabitants up to today: 2.2354
# Total cases up to today: 460
# New cases registered today: 30
# New cases registered today in %: 6.98
# Doubling time in the last five days: 10.3
# Doubling time yesterday: 10.9
# Trend of new cases (in %) in the last 5 days: 39.82

# %% [markdown]
# ## Padova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Padova')
# Out:
# Total cases per 1000 inhabitants up to today: 2.5292
# Total cases up to today: 2368
# New cases registered today: 104
# New cases registered today in %: 4.59
# Doubling time in the last five days: 15.4
# Doubling time yesterday: 14.3
# Trend of new cases (in %) in the last 5 days: 25.22

# %% [markdown]
# ## Rovigo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rovigo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5868
# Total cases up to today: 140
# New cases registered today: 4
# New cases registered today in %: 2.94
# Doubling time in the last five days: 25.2
# Doubling time yesterday: 16.3
# Trend of new cases (in %) in the last 5 days: 14.75

# %% [markdown]
# ## Treviso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Treviso')
# Out:
# Total cases per 1000 inhabitants up to today: 1.754
# Total cases up to today: 1554
# New cases registered today: 32
# New cases registered today in %: 2.1
# Doubling time in the last five days: 20.3
# Doubling time yesterday: 17.9
# Trend of new cases (in %) in the last 5 days: 18.63

# %% [markdown]
# ## Venezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Venezia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.441
# Total cases up to today: 1231
# New cases registered today: 61
# New cases registered today in %: 5.21
# Doubling time in the last five days: 13.7
# Doubling time yesterday: 14.4
# Trend of new cases (in %) in the last 5 days: 28.9

# %% [markdown]
# ## Verona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verona')
# Out:
# Total cases per 1000 inhabitants up to today: 2.4817
# Total cases up to today: 2287
# New cases registered today: 175
# New cases registered today in %: 8.29
# Doubling time in the last five days: 10.5
# Doubling time yesterday: 8.5
# Trend of new cases (in %) in the last 5 days: 39.03

# %% [markdown]
# ## Vicenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vicenza')
# Out:
# Total cases per 1000 inhabitants up to today: 1.534
# Total cases up to today: 1327
# New cases registered today: 85
# New cases registered today in %: 6.84
# Doubling time in the last five days: 10.9
# Doubling time yesterday: 10.7
# Trend of new cases (in %) in the last 5 days: 37.37
