# %%
import pandas as pd
import sys
import datetime
import matplotlib.pylab as plt
import numpy as np
from math import log, floor, ceil
from typing import Dict

# %%
START_DATE = datetime.date(2020,2,24)

# %%
def create_filename(day_str: str) -> str:
    return ('../dati-province/dpc-covid19-ita-province-' + day_str + '.csv')

# %%
def handle_Toscana_20200326_error(cases: Dict[str, int]) -> Dict[str, int]:
    cases['20200327'] = cases['20200326'] + floor((cases['20200328'] - cases['20200326'])/2)
    cases['20200328'] = cases['20200327'] + ceil((cases['20200328'] - cases['20200326'])/2)
    return cases

# %%
def calculate_and_create_chart_for_province(start_date: datetime.date, province: str):
    day = start_date
    cases: Dict[str,int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]==province]["totale_casi"])
        day: datetime.date = day + datetime.timedelta(days = 1)
    
    if df[df["denominazione_provincia"]==province]["denominazione_regione"].any()=='Toscana':
        cases = handle_Toscana_20200326_error(cases)
    
    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases per 1000 inhabitants up to today:", round(calculate_cases_to_inhabitants_ratio(cases_df_today, province),4))
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_region(start_date: datetime.date, region: str):
    day: datetime.date = start_date
    cases: Dict[str, int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[(df["denominazione_regione"]==region)&(df["denominazione_provincia"]!='In fase di definizione/aggiornamento')]["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)
        
    if region == 'Toscana':
        cases = handle_Toscana_20200326_error(cases)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_Italy(start_date: datetime.date):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]!='In fase di definizione/aggiornamento']["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)

    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_stats(cases_df):
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    cases_df_yesterday = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 1)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_five_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 5)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_six_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 6)).strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases up to today:", cases_df_today)
    print("New cases registered today:", cases_df_today-cases_df_yesterday)
    if int(cases_df_yesterday) != 0:
        print("New cases registered today in %:", round((cases_df_today-cases_df_yesterday)/cases_df_yesterday*100,2))

    print("Doubling time in the last five days:", round(calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago), 1))
    print("Doubling time yesterday:", round(calculate_doubling_time_in_the_last_five_days(cases_df_yesterday, cases_df_six_days_ago), 1))
    print("Trend of new cases (in %) in the last 5 days:", round((cases_df_today-cases_df_five_days_ago)/cases_df_five_days_ago*100,2))
    
    return

# %%
def calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago):
    if cases_df_five_days_ago ==0:
        return np.nan
    log_result = log(cases_df_today/cases_df_five_days_ago)
    if log_result != 0:
        return (5*log(2))/(log_result)
    else:
        return np.nan

# %%
def calculate_cases_to_inhabitants_ratio(cases: int, province: str) -> float:
    df_province: pd.DataFrame = pd.read_csv("../general/province.csv")
    inhabitants = df_province[df_province["Provincia"]==province]["Residenti"].str.replace('.', '', regex=True).sum()
    return int(cases)/int(inhabitants)*1000

# %% [markdown]
# # Casi di COVID-19 in Italia - COVID-19 cases in Italy

# %%
calculate_and_create_chart_for_Italy(START_DATE)
# Out:
# Total cases up to today: 137082
# New cases registered today: 4606
# New cases registered today in %: 3.48
# Doubling time in the last five days: 20.8
# Doubling time yesterday: 20.1
# Trend of new cases (in %) in the last 5 days: 18.16

# %% [markdown]
# # Casi di COVID-19 in Abruzzo - COVID-19 cases in Abruzzo

# %%
calculate_and_create_chart_for_region(START_DATE, 'Abruzzo')
# Out:
# Total cases up to today: 1859
# New cases registered today: 60
# New cases registered today in %: 3.34
# Doubling time in the last five days: 20.0
# Doubling time yesterday: 18.9
# Trend of new cases (in %) in the last 5 days: 18.94

# %% [markdown]
# ## Chieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Chieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9276
# Total cases up to today: 361
# New cases registered today: 18
# New cases registered today in %: 5.25
# Doubling time in the last five days: 22.8
# Doubling time yesterday: 25.2
# Trend of new cases (in %) in the last 5 days: 16.45

# %% [markdown]
# ## L'Aquila

# %%
calculate_and_create_chart_for_province(START_DATE, "L'Aquila")
# Out:
# Total cases per 1000 inhabitants up to today: 0.6525
# Total cases up to today: 197
# New cases registered today: 8
# New cases registered today in %: 4.23
# Doubling time in the last five days: 20.2
# Doubling time yesterday: 11.5
# Trend of new cases (in %) in the last 5 days: 18.67

# %% [markdown]
# ## Pescara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pescara')
# Out:
# Total cases per 1000 inhabitants up to today: 2.3996
# Total cases up to today: 771
# New cases registered today: 15
# New cases registered today in %: 1.98
# Doubling time in the last five days: 24.4
# Doubling time yesterday: 22.0
# Trend of new cases (in %) in the last 5 days: 15.25

# %% [markdown]
# ## Teramo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Teramo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7105
# Total cases up to today: 530
# New cases registered today: 19
# New cases registered today in %: 3.72
# Doubling time in the last five days: 14.6
# Doubling time yesterday: 16.1
# Trend of new cases (in %) in the last 5 days: 26.79

# %% [markdown]
# # Casi di COVID-19 in Basilicata - COVID-19 cases in Basilicata

# %%
calculate_and_create_chart_for_region(START_DATE, 'Basilicata')
# Out:
# Total cases up to today: 297
# New cases registered today: 6
# New cases registered today in %: 2.06
# Doubling time in the last five days: 26.8
# Doubling time yesterday: 20.6
# Trend of new cases (in %) in the last 5 days: 13.79

# %% [markdown]
# ## Matera

# %%
calculate_and_create_chart_for_province(START_DATE, 'Matera')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7261
# Total cases up to today: 145
# New cases registered today: 1
# New cases registered today in %: 0.69
# Doubling time in the last five days: 22.2
# Doubling time yesterday: 17.4
# Trend of new cases (in %) in the last 5 days: 16.94

# %% [markdown]
# ## Potenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Potenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4101
# Total cases up to today: 152
# New cases registered today: 5
# New cases registered today in %: 3.4
# Doubling time in the last five days: 33.4
# Doubling time yesterday: 25.0
# Trend of new cases (in %) in the last 5 days: 10.95

# %% [markdown]
# # Casi di COVID-19 nella Provincia Autonoma di Bolzano - COVID-19 cases in Autonomous Province of Bolzano

# %%
calculate_and_create_chart_for_region(START_DATE, 'P.A. Bolzano')
# Out:
# Total cases up to today: 1835
# New cases registered today: 24
# New cases registered today in %: 1.33
# Doubling time in the last five days: 21.3
# Doubling time yesterday: 17.1
# Trend of new cases (in %) in the last 5 days: 17.7

# %% [markdown]
# # Casi di COVID-19 in Calabria - COVID-19 cases in Calabria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Calabria')
# Out:
# Total cases up to today: 857
# New cases registered today: 26
# New cases registered today in %: 3.13
# Doubling time in the last five days: 21.8
# Doubling time yesterday: 18.5
# Trend of new cases (in %) in the last 5 days: 17.24

# %% [markdown]
# ## Catanzaro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catanzaro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4664
# Total cases up to today: 169
# New cases registered today: 7
# New cases registered today in %: 4.32
# Doubling time in the last five days: 29.1
# Doubling time yesterday: 33.3
# Trend of new cases (in %) in the last 5 days: 12.67

# %% [markdown]
# ## Cosenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cosenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3737
# Total cases up to today: 266
# New cases registered today: 12
# New cases registered today in %: 4.72
# Doubling time in the last five days: 12.8
# Doubling time yesterday: 12.9
# Trend of new cases (in %) in the last 5 days: 31.03

# %% [markdown]
# ## Crotone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Crotone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6436
# Total cases up to today: 113
# New cases registered today: 1
# New cases registered today in %: 0.89
# Doubling time in the last five days: 54.2
# Doubling time yesterday: 19.8
# Trend of new cases (in %) in the last 5 days: 6.6

# %% [markdown]
# ## Reggio di Calabria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Reggio di Calabria')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4478
# Total cases up to today: 248
# New cases registered today: 5
# New cases registered today in %: 2.06
# Doubling time in the last five days: 26.9
# Doubling time yesterday: 21.6
# Trend of new cases (in %) in the last 5 days: 13.76

# %% [markdown]
# ## Vibo Valentia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vibo Valentia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3774
# Total cases up to today: 61
# New cases registered today: 1
# New cases registered today in %: 1.67
# Doubling time in the last five days: 28.4
# Doubling time yesterday: 15.5
# Trend of new cases (in %) in the last 5 days: 12.96

# %% [markdown]
# # Casi di COVID-19 in Campania - COVID-19 cases in Campania

# %%
calculate_and_create_chart_for_region(START_DATE, 'Campania')
# Out:
# Total cases up to today: 3017
# New cases registered today: 89
# New cases registered today in %: 3.04
# Doubling time in the last five days: 19.1
# Doubling time yesterday: 14.2
# Trend of new cases (in %) in the last 5 days: 19.86

# %% [markdown]
# ## Avellino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Avellino')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8925
# Total cases up to today: 378
# New cases registered today: 3
# New cases registered today in %: 0.8
# Doubling time in the last five days: 32.7
# Doubling time yesterday: 13.5
# Trend of new cases (in %) in the last 5 days: 11.18

# %% [markdown]
# ## Benevento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Benevento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4756
# Total cases up to today: 133
# New cases registered today: 22
# New cases registered today in %: 19.82
# Doubling time in the last five days: 7.7
# Doubling time yesterday: 13.0
# Trend of new cases (in %) in the last 5 days: 56.47

# %% [markdown]
# ## Caserta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caserta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3776
# Total cases up to today: 349
# New cases registered today: 18
# New cases registered today in %: 5.44
# Doubling time in the last five days: 12.4
# Doubling time yesterday: 13.3
# Trend of new cases (in %) in the last 5 days: 32.2

# %% [markdown]
# ## Napoli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Napoli')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5369
# Total cases up to today: 1668
# New cases registered today: 25
# New cases registered today in %: 1.52
# Doubling time in the last five days: 22.3
# Doubling time yesterday: 13.8
# Trend of new cases (in %) in the last 5 days: 16.81

# %% [markdown]
# ## Salerno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Salerno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4426
# Total cases up to today: 489
# New cases registered today: 21
# New cases registered today in %: 4.49
# Doubling time in the last five days: 17.3
# Doubling time yesterday: 17.8
# Trend of new cases (in %) in the last 5 days: 22.25

# %% [markdown]
# # Casi di COVID-19 in Emilia Romagna - COVID-19 cases in Emilia Romagna

# %%
calculate_and_create_chart_for_region(START_DATE, 'Emilia Romagna')
# Out:
# Total cases up to today: 0
# New cases registered today: 0
# Doubling time in the last five days: nan
# Doubling time yesterday: nan
# Trend of new cases (in %) in the last 5 days: nan
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in long_scalars
#   del sys.path[0]

# %% [markdown]
# ## Bologna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bologna')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7328
# Total cases up to today: 2758
# New cases registered today: 102
# New cases registered today in %: 3.84
# Doubling time in the last five days: 21.0
# Doubling time yesterday: 19.6
# Trend of new cases (in %) in the last 5 days: 17.91

# %% [markdown]
# ## Ferrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ferrara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5444
# Total cases up to today: 538
# New cases registered today: 16
# New cases registered today in %: 3.07
# Doubling time in the last five days: 9.1
# Doubling time yesterday: 8.1
# Trend of new cases (in %) in the last 5 days: 46.2

# %% [markdown]
# ## Modena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Modena')
# Out:
# Total cases per 1000 inhabitants up to today: 4.0108
# Total cases up to today: 2811
# New cases registered today: 53
# New cases registered today in %: 1.92
# Doubling time in the last five days: 29.4
# Doubling time yesterday: 26.2
# Trend of new cases (in %) in the last 5 days: 12.53

# %% [markdown]
# ## Parma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Parma')
# Out:
# Total cases per 1000 inhabitants up to today: 5.3353
# Total cases up to today: 2395
# New cases registered today: 30
# New cases registered today in %: 1.27
# Doubling time in the last five days: 24.8
# Doubling time yesterday: 24.2
# Trend of new cases (in %) in the last 5 days: 14.98

# %% [markdown]
# ## Piacenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Piacenza')
# Out:
# Total cases per 1000 inhabitants up to today: 10.392
# Total cases up to today: 2980
# New cases registered today: 27
# New cases registered today in %: 0.91
# Doubling time in the last five days: 59.4
# Doubling time yesterday: 52.7
# Trend of new cases (in %) in the last 5 days: 6.01

# %% [markdown]
# ## Ravenna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ravenna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9059
# Total cases up to today: 746
# New cases registered today: 8
# New cases registered today in %: 1.08
# Doubling time in the last five days: 27.0
# Doubling time yesterday: 21.3
# Trend of new cases (in %) in the last 5 days: 13.72

# %% [markdown]
# ## Reggio nell'Emilia

# %%
calculate_and_create_chart_for_province(START_DATE, "Reggio nell'Emilia")
# Out:
# Total cases per 1000 inhabitants up to today: 6.295
# Total cases up to today: 3352
# New cases registered today: 137
# New cases registered today in %: 4.26
# Doubling time in the last five days: 19.3
# Doubling time yesterday: 18.5
# Trend of new cases (in %) in the last 5 days: 19.71

# %% [markdown]
# ## Rimini

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rimini')
# Out:
# Total cases per 1000 inhabitants up to today: 4.7389
# Total cases up to today: 1596
# New cases registered today: 12
# New cases registered today in %: 0.76
# Doubling time in the last five days: 63.3
# Doubling time yesterday: 41.1
# Trend of new cases (in %) in the last 5 days: 5.63

# %% [markdown]
# # Casi di COVID-19 in Friuli Venezia Giulia - COVID-19 cases in Friuli Venezia Giulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Friuli Venezia Giulia')
# Out:
# Total cases up to today: 2211
# New cases registered today: 66
# New cases registered today in %: 3.08
# Doubling time in the last five days: 20.9
# Doubling time yesterday: 19.2
# Trend of new cases (in %) in the last 5 days: 18.05

# %% [markdown]
# ## Gorizia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Gorizia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8663
# Total cases up to today: 121
# New cases registered today: 2
# New cases registered today in %: 1.68
# Doubling time in the last five days: 40.2
# Doubling time yesterday: 44.1
# Trend of new cases (in %) in the last 5 days: 9.01

# %% [markdown]
# ## Pordenone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pordenone')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5927
# Total cases up to today: 497
# New cases registered today: 17
# New cases registered today in %: 3.54
# Doubling time in the last five days: 36.5
# Doubling time yesterday: 40.9
# Trend of new cases (in %) in the last 5 days: 9.96

# %% [markdown]
# ## Trieste

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trieste')
# Out:
# Total cases per 1000 inhabitants up to today: 3.2512
# Total cases up to today: 763
# New cases registered today: 30
# New cases registered today in %: 4.09
# Doubling time in the last five days: 17.9
# Doubling time yesterday: 17.0
# Trend of new cases (in %) in the last 5 days: 21.3

# %% [markdown]
# ## Udine

# %%
calculate_and_create_chart_for_province(START_DATE, 'Udine')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5617
# Total cases up to today: 830
# New cases registered today: 17
# New cases registered today in %: 2.09
# Doubling time in the last five days: 17.5
# Doubling time yesterday: 14.6
# Trend of new cases (in %) in the last 5 days: 21.88

# %% [markdown]
# # Casi di COVID-19 nel Lazio - COVID-19 cases in Lazio

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lazio')
# Out:
# Total cases up to today: 4231
# New cases registered today: 114
# New cases registered today in %: 2.77
# Doubling time in the last five days: 20.6
# Doubling time yesterday: 18.5
# Trend of new cases (in %) in the last 5 days: 18.35

# %% [markdown]
# ## Frosinone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Frosinone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.862
# Total cases up to today: 425
# New cases registered today: 24
# New cases registered today in %: 5.99
# Doubling time in the last five days: 19.0
# Doubling time yesterday: 19.0
# Trend of new cases (in %) in the last 5 days: 20.06

# %% [markdown]
# ## Latina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Latina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6332
# Total cases up to today: 364
# New cases registered today: 8
# New cases registered today in %: 2.25
# Doubling time in the last five days: 19.2
# Doubling time yesterday: 14.4
# Trend of new cases (in %) in the last 5 days: 19.74

# %% [markdown]
# ## Rieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rieti')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7088
# Total cases up to today: 269
# New cases registered today: 1
# New cases registered today in %: 0.37
# Doubling time in the last five days: 9.7
# Doubling time yesterday: 9.8
# Trend of new cases (in %) in the last 5 days: 43.09

# %% [markdown]
# ## Roma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Roma')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6684
# Total cases up to today: 2910
# New cases registered today: 80
# New cases registered today in %: 2.83
# Doubling time in the last five days: 23.0
# Doubling time yesterday: 20.7
# Trend of new cases (in %) in the last 5 days: 16.26

# %% [markdown]
# ## Viterbo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Viterbo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8244
# Total cases up to today: 263
# New cases registered today: 1
# New cases registered today in %: 0.38
# Doubling time in the last five days: 22.9
# Doubling time yesterday: 19.3
# Trend of new cases (in %) in the last 5 days: 16.37

# %% [markdown]
# # Casi di COVID-19 in Liguria - COVID-19 cases in Liguria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Liguria')
# Out:
# Total cases up to today: 4843
# New cases registered today: 1047
# New cases registered today in %: 27.58
# Doubling time in the last five days: 3.9
# Doubling time yesterday: 4.9
# Trend of new cases (in %) in the last 5 days: 143.37

# %% [markdown]
# ## Genova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Genova')
# Out:
# Total cases per 1000 inhabitants up to today: 3.2762
# Total cases up to today: 2785
# New cases registered today: 628
# New cases registered today in %: 29.11
# Doubling time in the last five days: 4.0
# Doubling time yesterday: 5.5
# Trend of new cases (in %) in the last 5 days: 136.02

# %% [markdown]
# ## Imperia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Imperia')
# Out:
# Total cases per 1000 inhabitants up to today: 3.714
# Total cases up to today: 799
# New cases registered today: 132
# New cases registered today in %: 19.79
# Doubling time in the last five days: 2.7
# Doubling time yesterday: 3.1
# Trend of new cases (in %) in the last 5 days: 258.3

# %% [markdown]
# ## La Spezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'La Spezia')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7413
# Total cases up to today: 605
# New cases registered today: 142
# New cases registered today in %: 30.67
# Doubling time in the last five days: 5.5
# Doubling time yesterday: 5.6
# Trend of new cases (in %) in the last 5 days: 87.31

# %% [markdown]
# ## Savona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Savona')
# Out:
# Total cases per 1000 inhabitants up to today: 2.3407
# Total cases up to today: 654
# New cases registered today: 145
# New cases registered today in %: 28.49
# Doubling time in the last five days: 3.8
# Doubling time yesterday: 4.7
# Trend of new cases (in %) in the last 5 days: 147.73

# %% [markdown]
# # Casi di COVID-19 in Lombardia - COVID-19 cases in Lombardy

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lombardia')
# Out:
# Total cases up to today: 52232
# New cases registered today: 1054
# New cases registered today in %: 2.06
# Doubling time in the last five days: 29.8
# Doubling time yesterday: 27.3
# Trend of new cases (in %) in the last 5 days: 12.35

# %% [markdown]
# ## Bergamo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bergamo')
# Out:
# Total cases per 1000 inhabitants up to today: 8.9474
# Total cases up to today: 9931
# New cases registered today: 63
# New cases registered today in %: 0.64
# Doubling time in the last five days: 54.1
# Doubling time yesterday: 47.3
# Trend of new cases (in %) in the last 5 days: 6.61

# %% [markdown]
# ## Brescia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brescia')
# Out:
# Total cases per 1000 inhabitants up to today: 7.8498
# Total cases up to today: 9909
# New cases registered today: 315
# New cases registered today in %: 3.28
# Doubling time in the last five days: 36.6
# Doubling time yesterday: 38.0
# Trend of new cases (in %) in the last 5 days: 9.93

# %% [markdown]
# ## Como

# %%
calculate_and_create_chart_for_province(START_DATE, 'Como')
# Out:
# Total cases per 1000 inhabitants up to today: 2.5692
# Total cases up to today: 1542
# New cases registered today: 17
# New cases registered today in %: 1.11
# Doubling time in the last five days: 16.9
# Doubling time yesterday: 14.7
# Trend of new cases (in %) in the last 5 days: 22.77

# %% [markdown]
# ## Cremona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cremona')
# Out:
# Total cases per 1000 inhabitants up to today: 12.3043
# Total cases up to today: 4422
# New cases registered today: 99
# New cases registered today in %: 2.29
# Doubling time in the last five days: 45.4
# Doubling time yesterday: 41.2
# Trend of new cases (in %) in the last 5 days: 7.93

# %% [markdown]
# ## Lecco

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecco')
# Out:
# Total cases per 1000 inhabitants up to today: 5.1734
# Total cases up to today: 1755
# New cases registered today: 24
# New cases registered today in %: 1.39
# Doubling time in the last five days: 36.0
# Doubling time yesterday: 31.8
# Trend of new cases (in %) in the last 5 days: 10.1

# %% [markdown]
# ## Lodi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lodi')
# Out:
# Total cases per 1000 inhabitants up to today: 10.2338
# Total cases up to today: 2347
# New cases registered today: 26
# New cases registered today in %: 1.12
# Doubling time in the last five days: 59.4
# Doubling time yesterday: 59.2
# Trend of new cases (in %) in the last 5 days: 6.01

# %% [markdown]
# ## Mantova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Mantova')
# Out:
# Total cases per 1000 inhabitants up to today: 5.3707
# Total cases up to today: 2216
# New cases registered today: 74
# New cases registered today in %: 3.45
# Doubling time in the last five days: 21.4
# Doubling time yesterday: 18.8
# Trend of new cases (in %) in the last 5 days: 17.62

# %% [markdown]
# ## Milano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Milano')
# Out:
# Total cases per 1000 inhabitants up to today: 3.7409
# Total cases up to today: 12039
# New cases registered today: 252
# New cases registered today in %: 2.14
# Doubling time in the last five days: 23.5
# Doubling time yesterday: 21.1
# Trend of new cases (in %) in the last 5 days: 15.86

# %% [markdown]
# ## Monza e della Brianza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Monza e della Brianza')
# Out:
# Total cases per 1000 inhabitants up to today: 3.7567
# Total cases up to today: 3264
# New cases registered today: 58
# New cases registered today in %: 1.81
# Doubling time in the last five days: 21.3
# Doubling time yesterday: 17.6
# Trend of new cases (in %) in the last 5 days: 17.66

# %% [markdown]
# ## Pavia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pavia')
# Out:
# Total cases per 1000 inhabitants up to today: 5.1585
# Total cases up to today: 2823
# New cases registered today: 88
# New cases registered today in %: 3.22
# Doubling time in the last five days: 18.1
# Doubling time yesterday: 19.3
# Trend of new cases (in %) in the last 5 days: 21.11

# %% [markdown]
# ## Sondrio

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sondrio')
# Out:
# Total cases per 1000 inhabitants up to today: 3.5053
# Total cases up to today: 636
# New cases registered today: 16
# New cases registered today in %: 2.58
# Doubling time in the last five days: 20.5
# Doubling time yesterday: 19.1
# Trend of new cases (in %) in the last 5 days: 18.44

# %% [markdown]
# ## Varese

# %%
calculate_and_create_chart_for_province(START_DATE, 'Varese')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5145
# Total cases up to today: 1348
# New cases registered today: 22
# New cases registered today in %: 1.66
# Doubling time in the last five days: 16.0
# Doubling time yesterday: 12.4
# Trend of new cases (in %) in the last 5 days: 24.24

# %% [markdown]
# # Casi di COVID-19 nelle Marche - COVID-19 cases in Marche

# %%
calculate_and_create_chart_for_region(START_DATE, 'Marche')
# Out:
# Total cases up to today: 4740
# New cases registered today: 142
# New cases registered today in %: 3.09
# Doubling time in the last five days: 25.6
# Doubling time yesterday: 25.4
# Trend of new cases (in %) in the last 5 days: 14.49

# %% [markdown]
# ## Ancona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ancona')
# Out:
# Total cases per 1000 inhabitants up to today: 3.0688
# Total cases up to today: 1455
# New cases registered today: 26
# New cases registered today in %: 1.82
# Doubling time in the last five days: 24.5
# Doubling time yesterday: 20.9
# Trend of new cases (in %) in the last 5 days: 15.2

# %% [markdown]
# ## Ascoli Piceno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ascoli Piceno')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1268
# Total cases up to today: 236
# New cases registered today: 1
# New cases registered today in %: 0.43
# Doubling time in the last five days: 202.7
# Doubling time yesterday: 100.1
# Trend of new cases (in %) in the last 5 days: 1.72

# %% [markdown]
# ## Fermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Fermo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9102
# Total cases up to today: 334
# New cases registered today: 20
# New cases registered today in %: 6.37
# Doubling time in the last five days: 30.4
# Doubling time yesterday: 34.5
# Trend of new cases (in %) in the last 5 days: 12.08

# %% [markdown]
# ## Macerata

# %%
calculate_and_create_chart_for_province(START_DATE, 'Macerata')
# Out:
# Total cases per 1000 inhabitants up to today: 2.2388
# Total cases up to today: 714
# New cases registered today: 50
# New cases registered today in %: 7.53
# Doubling time in the last five days: 14.4
# Doubling time yesterday: 15.8
# Trend of new cases (in %) in the last 5 days: 27.27

# %% [markdown]
# ## Pesaro e Urbino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pesaro e Urbino')
# Out:
# Total cases per 1000 inhabitants up to today: 5.5474
# Total cases up to today: 2001
# New cases registered today: 45
# New cases registered today in %: 2.3
# Doubling time in the last five days: 30.5
# Doubling time yesterday: 32.1
# Trend of new cases (in %) in the last 5 days: 12.04

# %% [markdown]
# # Casi di COVID-19 in Molise - COVID-19 cases in Molise¶

# %%
calculate_and_create_chart_for_region(START_DATE, 'Molise')
# Out:
# Total cases up to today: 209
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 14.3
# Doubling time yesterday: 11.1
# Trend of new cases (in %) in the last 5 days: 27.44

# %% [markdown]
# ## Campobasso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Campobasso')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7389
# Total cases up to today: 166
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 32.1
# Doubling time yesterday: 22.2
# Trend of new cases (in %) in the last 5 days: 11.41

# %% [markdown]
# ## Isernia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Isernia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5011
# Total cases up to today: 43
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 3.3
# Doubling time yesterday: 2.5
# Trend of new cases (in %) in the last 5 days: 186.67

# %% [markdown]
# # Casi di COVID-19 in Piemonte - COVID-19 cases in Piedmont

# %%
calculate_and_create_chart_for_region(START_DATE, 'Piemonte')
# Out:
# Total cases up to today: 13624
# New cases registered today: 528
# New cases registered today in %: 4.03
# Doubling time in the last five days: 14.4
# Doubling time yesterday: 13.5
# Trend of new cases (in %) in the last 5 days: 27.32

# %% [markdown]
# ## Alessandria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Alessandria')
# Out:
# Total cases per 1000 inhabitants up to today: 4.7251
# Total cases up to today: 2016
# New cases registered today: 70
# New cases registered today in %: 3.6
# Doubling time in the last five days: 11.5
# Doubling time yesterday: 11.2
# Trend of new cases (in %) in the last 5 days: 35.21

# %% [markdown]
# ## Asti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Asti')
# Out:
# Total cases per 1000 inhabitants up to today: 2.9676
# Total cases up to today: 643
# New cases registered today: 14
# New cases registered today in %: 2.23
# Doubling time in the last five days: 16.8
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 22.94

# %% [markdown]
# ## Biella

# %%
calculate_and_create_chart_for_province(START_DATE, 'Biella')
# Out:
# Total cases per 1000 inhabitants up to today: 3.3604
# Total cases up to today: 600
# New cases registered today: 9
# New cases registered today in %: 1.52
# Doubling time in the last five days: 34.1
# Doubling time yesterday: 28.4
# Trend of new cases (in %) in the last 5 days: 10.7

# %% [markdown]
# ## Cuneo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cuneo')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0828
# Total cases up to today: 1227
# New cases registered today: 40
# New cases registered today in %: 3.37
# Doubling time in the last five days: 9.4
# Doubling time yesterday: 9.6
# Trend of new cases (in %) in the last 5 days: 44.35

# %% [markdown]
# ## Novara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Novara')
# Out:
# Total cases per 1000 inhabitants up to today: 3.0961
# Total cases up to today: 1146
# New cases registered today: 73
# New cases registered today in %: 6.8
# Doubling time in the last five days: 16.6
# Doubling time yesterday: 20.0
# Trend of new cases (in %) in the last 5 days: 23.23

# %% [markdown]
# ## Torino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Torino')
# Out:
# Total cases per 1000 inhabitants up to today: 2.8953
# Total cases up to today: 6595
# New cases registered today: 220
# New cases registered today in %: 3.45
# Doubling time in the last five days: 15.8
# Doubling time yesterday: 14.2
# Trend of new cases (in %) in the last 5 days: 24.55

# %% [markdown]
# ## 	Verbano-Cusio-Ossola

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verbano-Cusio-Ossola')
# Out:
# Total cases per 1000 inhabitants up to today: 4.5032
# Total cases up to today: 719
# New cases registered today: 89
# New cases registered today in %: 14.13
# Doubling time in the last five days: 9.8
# Doubling time yesterday: 9.9
# Trend of new cases (in %) in the last 5 days: 42.38

# %% [markdown]
# ## Vercelli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vercelli')
# Out:
# Total cases per 1000 inhabitants up to today: 3.8995
# Total cases up to today: 678
# New cases registered today: 13
# New cases registered today in %: 1.95
# Doubling time in the last five days: 19.0
# Doubling time yesterday: 14.1
# Trend of new cases (in %) in the last 5 days: 20.0

# %% [markdown]
# # Casi di COVID-19 in Puglia - COVID-19 cases in Apulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Puglia')
# Out:
# Total cases up to today: 2599
# New cases registered today: 115
# New cases registered today in %: 4.63
# Doubling time in the last five days: 18.4
# Doubling time yesterday: 18.1
# Trend of new cases (in %) in the last 5 days: 20.77

# %% [markdown]
# ## Bari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6833
# Total cases up to today: 861
# New cases registered today: 27
# New cases registered today in %: 3.24
# Doubling time in the last five days: 23.1
# Doubling time yesterday: 19.8
# Trend of new cases (in %) in the last 5 days: 16.19

# %% [markdown]
# ## 	Barletta-Andria-Trani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Barletta-Andria-Trani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5401
# Total cases up to today: 212
# New cases registered today: 35
# New cases registered today in %: 19.77
# Doubling time in the last five days: 7.0
# Doubling time yesterday: 10.2
# Trend of new cases (in %) in the last 5 days: 64.34

# %% [markdown]
# ## Brindisi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brindisi')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7152
# Total cases up to today: 284
# New cases registered today: 22
# New cases registered today in %: 8.4
# Doubling time in the last five days: 13.1
# Doubling time yesterday: 15.0
# Trend of new cases (in %) in the last 5 days: 30.28

# %% [markdown]
# ## Foggia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Foggia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0373
# Total cases up to today: 652
# New cases registered today: 17
# New cases registered today in %: 2.68
# Doubling time in the last five days: 16.3
# Doubling time yesterday: 14.7
# Trend of new cases (in %) in the last 5 days: 23.72

# %% [markdown]
# ## Lecce

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecce')
# Out:
# Total cases per 1000 inhabitants up to today: 0.485
# Total cases up to today: 389
# New cases registered today: 5
# New cases registered today in %: 1.3
# Doubling time in the last five days: 43.2
# Doubling time yesterday: 41.2
# Trend of new cases (in %) in the last 5 days: 8.36

# %% [markdown]
# ## Taranto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Taranto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3445
# Total cases up to today: 201
# New cases registered today: 9
# New cases registered today in %: 4.69
# Doubling time in the last five days: 28.5
# Doubling time yesterday: 21.2
# Trend of new cases (in %) in the last 5 days: 12.92

# %% [markdown]
# # Casi di COVID-19 in Sardegna - COVID-19 cases in Sardinia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sardegna')
# Out:
# Total cases up to today: 975
# New cases registered today: 40
# New cases registered today in %: 4.28
# Doubling time in the last five days: 20.7
# Doubling time yesterday: 21.2
# Trend of new cases (in %) in the last 5 days: 18.18

# %% [markdown]
# ## Cagliari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cagliari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2695
# Total cases up to today: 151
# New cases registered today: 3
# New cases registered today in %: 2.03
# Doubling time in the last five days: 29.0
# Doubling time yesterday: 21.5
# Trend of new cases (in %) in the last 5 days: 12.69

# %% [markdown]
# ## Nuoro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Nuoro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4292
# Total cases up to today: 67
# New cases registered today: 2
# New cases registered today in %: 3.08
# Doubling time in the last five days: 44.7
# Doubling time yesterday: 43.3
# Trend of new cases (in %) in the last 5 days: 8.06

# %% [markdown]
# ## Oristano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Oristano')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1804
# Total cases up to today: 29
# New cases registered today: 1
# New cases registered today in %: 3.57
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 7.8
# Trend of new cases (in %) in the last 5 days: 52.63

# %% [markdown]
# ## Sassari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sassari')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9633
# Total cases up to today: 654
# New cases registered today: 34
# New cases registered today in %: 5.48
# Doubling time in the last five days: 19.4
# Doubling time yesterday: 21.6
# Trend of new cases (in %) in the last 5 days: 19.56

# %% [markdown]
# # Casi di COVID-19 in Sicilia - COVID-19 cases in Sicily

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sicilia')
# Out:
# Total cases up to today: 2159
# New cases registered today: 62
# New cases registered today in %: 2.96
# Doubling time in the last five days: 23.2
# Doubling time yesterday: 22.0
# Trend of new cases (in %) in the last 5 days: 16.14

# %% [markdown]
# ## Agrigento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Agrigento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2556
# Total cases up to today: 113
# New cases registered today: 3
# New cases registered today in %: 2.73
# Doubling time in the last five days: 28.4
# Doubling time yesterday: 30.0
# Trend of new cases (in %) in the last 5 days: 13.0

# %% [markdown]
# ## Caltanissetta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caltanissetta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3967
# Total cases up to today: 107
# New cases registered today: 2
# New cases registered today in %: 1.9
# Doubling time in the last five days: 13.6
# Doubling time yesterday: 12.7
# Trend of new cases (in %) in the last 5 days: 28.92

# %% [markdown]
# ## Catania

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catania')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5803
# Total cases up to today: 646
# New cases registered today: 16
# New cases registered today in %: 2.54
# Doubling time in the last five days: 24.0
# Doubling time yesterday: 23.6
# Trend of new cases (in %) in the last 5 days: 15.56

# %% [markdown]
# ## Enna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Enna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7614
# Total cases up to today: 296
# New cases registered today: 7
# New cases registered today in %: 2.42
# Doubling time in the last five days: 24.5
# Doubling time yesterday: 17.9
# Trend of new cases (in %) in the last 5 days: 15.18

# %% [markdown]
# ## Messina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Messina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5906
# Total cases up to today: 376
# New cases registered today: 6
# New cases registered today in %: 1.62
# Doubling time in the last five days: 31.6
# Doubling time yesterday: 25.5
# Trend of new cases (in %) in the last 5 days: 11.57

# %% [markdown]
# ## Palermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Palermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2594
# Total cases up to today: 329
# New cases registered today: 12
# New cases registered today in %: 3.79
# Doubling time in the last five days: 27.5
# Doubling time yesterday: 29.6
# Trend of new cases (in %) in the last 5 days: 13.45

# %% [markdown]
# ## Ragusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ragusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1743
# Total cases up to today: 56
# New cases registered today: 2
# New cases registered today in %: 3.7
# Doubling time in the last five days: 17.6
# Doubling time yesterday: 19.0
# Trend of new cases (in %) in the last 5 days: 21.74

# %% [markdown]
# ## Siracusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siracusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3029
# Total cases up to today: 122
# New cases registered today: 9
# New cases registered today in %: 7.96
# Doubling time in the last five days: 24.7
# Doubling time yesterday: 30.9
# Trend of new cases (in %) in the last 5 days: 15.09

# %% [markdown]
# ## Trapani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trapani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2624
# Total cases up to today: 114
# New cases registered today: 5
# New cases registered today in %: 4.59
# Doubling time in the last five days: 10.1
# Doubling time yesterday: 11.2
# Trend of new cases (in %) in the last 5 days: 40.74

# %% [markdown]
# # Casi di COVID-19 in Toscana - COVID-19 cases in Tuscany

# %%
calculate_and_create_chart_for_region(START_DATE, 'Toscana')
# Out:
# Total cases up to today: 6379
# New cases registered today: 206
# New cases registered today in %: 3.34
# Doubling time in the last five days: 23.3
# Doubling time yesterday: 22.0
# Trend of new cases (in %) in the last 5 days: 16.0

# %% [markdown]
# ## Arezzo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Arezzo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1557
# Total cases up to today: 398
# New cases registered today: 2
# New cases registered today in %: 0.51
# Doubling time in the last five days: 32.7
# Doubling time yesterday: 33.4
# Trend of new cases (in %) in the last 5 days: 11.17

# %% [markdown]
# ## Firenze

# %%
calculate_and_create_chart_for_province(START_DATE, 'Firenze')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8444
# Total cases up to today: 1871
# New cases registered today: 66
# New cases registered today in %: 3.66
# Doubling time in the last five days: 18.0
# Doubling time yesterday: 14.4
# Trend of new cases (in %) in the last 5 days: 21.26

# %% [markdown]
# ## Grosseto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Grosseto')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3002
# Total cases up to today: 290
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 36.9
# Doubling time yesterday: 36.9
# Trend of new cases (in %) in the last 5 days: 9.85

# %% [markdown]
# ## Livorno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Livorno')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0346
# Total cases up to today: 349
# New cases registered today: 13
# New cases registered today in %: 3.87
# Doubling time in the last five days: 27.0
# Doubling time yesterday: 31.5
# Trend of new cases (in %) in the last 5 days: 13.68

# %% [markdown]
# ## Lucca

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lucca')
# Out:
# Total cases per 1000 inhabitants up to today: 2.4459
# Total cases up to today: 954
# New cases registered today: 34
# New cases registered today in %: 3.7
# Doubling time in the last five days: 28.0
# Doubling time yesterday: 25.2
# Trend of new cases (in %) in the last 5 days: 13.17

# %% [markdown]
# ## Massa Carrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Massa Carrara')
# Out:
# Total cases per 1000 inhabitants up to today: 3.9119
# Total cases up to today: 769
# New cases registered today: 35
# New cases registered today in %: 4.77
# Doubling time in the last five days: 19.5
# Doubling time yesterday: 26.5
# Trend of new cases (in %) in the last 5 days: 19.41

# %% [markdown]
# ## Pisa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pisa')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4033
# Total cases up to today: 592
# New cases registered today: 8
# New cases registered today in %: 1.37
# Doubling time in the last five days: 26.3
# Doubling time yesterday: 27.6
# Trend of new cases (in %) in the last 5 days: 14.07

# %% [markdown]
# ## Pistoia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pistoia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5419
# Total cases up to today: 450
# New cases registered today: 46
# New cases registered today in %: 11.39
# Doubling time in the last five days: 15.7
# Doubling time yesterday: 22.4
# Trend of new cases (in %) in the last 5 days: 24.65

# %% [markdown]
# ## Prato

# %%
calculate_and_create_chart_for_province(START_DATE, 'Prato')
# Out:
# Total cases per 1000 inhabitants up to today: 1.355
# Total cases up to today: 345
# New cases registered today: 1
# New cases registered today in %: 0.29
# Doubling time in the last five days: 52.6
# Doubling time yesterday: 20.7
# Trend of new cases (in %) in the last 5 days: 6.81

# %% [markdown]
# ## Siena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siena')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3453
# Total cases up to today: 361
# New cases registered today: 1
# New cases registered today in %: 0.28
# Doubling time in the last five days: 50.4
# Doubling time yesterday: 46.2
# Trend of new cases (in %) in the last 5 days: 7.12

# %% [markdown]
# # Casi di COVID-19 in Provincia Autonoma di Trento - COVID-19 cases in the Autonomous Province of Trento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trento')
# Out:
# Total cases per 1000 inhabitants up to today: 4.831
# Total cases up to today: 2602
# New cases registered today: 126
# New cases registered today in %: 5.09
# Doubling time in the last five days: 16.5
# Doubling time yesterday: 16.3
# Trend of new cases (in %) in the last 5 days: 23.38

# %% [markdown]
# # Casi di COVID-19 in Umbria - COVID-19 cases in Umbria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Umbria')
# Out:
# Total cases up to today: 1244
# New cases registered today: 23
# New cases registered today in %: 1.88
# Doubling time in the last five days: 40.1
# Doubling time yesterday: 30.5
# Trend of new cases (in %) in the last 5 days: 9.03

# %% [markdown]
# ## Perugia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Perugia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4243
# Total cases up to today: 941
# New cases registered today: 8
# New cases registered today in %: 0.86
# Doubling time in the last five days: 55.5
# Doubling time yesterday: 34.6
# Trend of new cases (in %) in the last 5 days: 6.45

# %% [markdown]
# ## Terni

# %%
calculate_and_create_chart_for_province(START_DATE, 'Terni')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3277
# Total cases up to today: 303
# New cases registered today: 15
# New cases registered today in %: 5.21
# Doubling time in the last five days: 21.0
# Doubling time yesterday: 22.0
# Trend of new cases (in %) in the last 5 days: 17.9

# %% [markdown]
# # Casi di COVID-19 in Valle d'Aosta - COVID-19 cases in Aosta Valley

# %%
calculate_and_create_chart_for_province(START_DATE, "Aosta")
# Out:
# Total cases per 1000 inhabitants up to today: 6.6991
# Total cases up to today: 850
# New cases registered today: 15
# New cases registered today in %: 1.8
# Doubling time in the last five days: 20.7
# Doubling time yesterday: 15.5
# Trend of new cases (in %) in the last 5 days: 18.22

# %% [markdown]
# # Casi di COVID-19 in Veneto - COVID-19 cases in Veneto

# %%
calculate_and_create_chart_for_region(START_DATE, 'Veneto')
# Out:
# Total cases up to today: 12085
# New cases registered today: 454
# New cases registered today in %: 3.9
# Doubling time in the last five days: 20.6
# Doubling time yesterday: 21.1
# Trend of new cases (in %) in the last 5 days: 18.34

# %% [markdown]
# ## Belluno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Belluno')
# Out:
# Total cases per 1000 inhabitants up to today: 2.9254
# Total cases up to today: 602
# New cases registered today: 25
# New cases registered today in %: 4.33
# Doubling time in the last five days: 18.5
# Doubling time yesterday: 20.4
# Trend of new cases (in %) in the last 5 days: 20.64

# %% [markdown]
# ## Padova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Padova')
# Out:
# Total cases per 1000 inhabitants up to today: 3.264
# Total cases up to today: 3056
# New cases registered today: 91
# New cases registered today in %: 3.07
# Doubling time in the last five days: 19.3
# Doubling time yesterday: 19.8
# Trend of new cases (in %) in the last 5 days: 19.7

# %% [markdown]
# ## Rovigo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rovigo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9724
# Total cases up to today: 232
# New cases registered today: 14
# New cases registered today in %: 6.42
# Doubling time in the last five days: 13.7
# Doubling time yesterday: 9.6
# Trend of new cases (in %) in the last 5 days: 28.89

# %% [markdown]
# ## Treviso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Treviso')
# Out:
# Total cases per 1000 inhabitants up to today: 2.1028
# Total cases up to today: 1863
# New cases registered today: 125
# New cases registered today in %: 7.19
# Doubling time in the last five days: 29.6
# Doubling time yesterday: 43.9
# Trend of new cases (in %) in the last 5 days: 12.43

# %% [markdown]
# ## Venezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Venezia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9081
# Total cases up to today: 1630
# New cases registered today: 87
# New cases registered today in %: 5.64
# Doubling time in the last five days: 16.5
# Doubling time yesterday: 19.6
# Trend of new cases (in %) in the last 5 days: 23.39

# %% [markdown]
# ## Verona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verona')
# Out:
# Total cases per 1000 inhabitants up to today: 3.1686
# Total cases up to today: 2920
# New cases registered today: 64
# New cases registered today in %: 2.24
# Doubling time in the last five days: 21.6
# Doubling time yesterday: 20.2
# Trend of new cases (in %) in the last 5 days: 17.36

# %% [markdown]
# ## Vicenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vicenza')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0599
# Total cases up to today: 1782
# New cases registered today: 48
# New cases registered today in %: 2.77
# Doubling time in the last five days: 21.3
# Doubling time yesterday: 18.2
# Trend of new cases (in %) in the last 5 days: 17.7
