# %%
import pandas as pd
import sys
import datetime
import matplotlib.pylab as plt
import numpy as np
from math import log

# %%
START_DATE = datetime.date(2020,2,24)

# %%
def calculate_and_create_chart_for_province(start_date: datetime.date, province: str):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str = day.strftime("%Y%m%d")
        filename = '../dati-province/dpc-covid19-ita-province-' + day_str + '.csv'
        df = pd.read_csv(filename)
        cases[day_str] = int(df[df["denominazione_provincia"]==province]["totale_casi"])
        day = day + datetime.timedelta(days = 1)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases per 1000 inhabitants up to today:", round(calculate_cases_to_inhabitants_ratio(cases_df_today, province),4))
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()

    plt.show()
    return

# %%
def calculate_and_create_chart_for_region(start_date: datetime.date, region: str):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str = day.strftime("%Y%m%d")
        filename = '../dati-province/dpc-covid19-ita-province-' + day_str + '.csv'
        df = pd.read_csv(filename)
        cases[day_str] = int(df[(df["denominazione_regione"]==region)&(df["denominazione_provincia"]!='In fase di definizione/aggiornamento')]["totale_casi"].sum())
        day = day + datetime.timedelta(days = 1)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_Italy(start_date: datetime.date):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str = day.strftime("%Y%m%d")
        filename = '../dati-province/dpc-covid19-ita-province-' + day_str + '.csv'
        df = pd.read_csv(filename)
        cases[day_str] = int(df[df["denominazione_provincia"]!='In fase di definizione/aggiornamento']["totale_casi"].sum())
        day = day + datetime.timedelta(days = 1)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()

    plt.show()
    return

# %%
def calculate_stats(cases_df):
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    cases_df_yesterday = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 1)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_five_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 5)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_six_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 6)).strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases up to today:", cases_df_today)
    print("New cases registered today:", cases_df_today-cases_df_yesterday)
    if int(cases_df_yesterday) != 0:
        print("New cases registered today in %:", round((cases_df_today-cases_df_yesterday)/cases_df_yesterday*100,2))

    print("Doubling time in the last five days:", round(calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago), 1))
    print("Doubling time yesterday:", round(calculate_doubling_time_in_the_last_five_days(cases_df_yesterday, cases_df_six_days_ago), 1))
    print("Trend of new cases (in %) in the last 5 days:", round((cases_df_today-cases_df_five_days_ago)/cases_df_five_days_ago*100,2))
    
    return

# %%
def calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago):
    if cases_df_five_days_ago ==0:
        return np.nan
    log_result = log(cases_df_today/cases_df_five_days_ago)
    if log_result != 0:
        return (5*log(2))/(log_result)
    else:
        return np.nan

# %%
def calculate_cases_to_inhabitants_ratio(cases: int, province: str) -> float:
    df_province: pd.DataFrame = pd.read_csv("../general/province.csv")
    inhabitants = df_province[df_province["Provincia"]==province]["Residenti"].str.replace('.', '', regex=True).sum()
    return int(cases)/int(inhabitants)*1000

# %% [markdown]
# # Casi di COVID-19 in Italia - COVID-19 cases in Italy

# %%
calculate_and_create_chart_for_Italy(START_DATE)
# Out:
# Total cases up to today: 72104
# New cases registered today: 5060
# New cases registered today in %: 7.55
# Doubling time in the last five days: 7.7
# Doubling time yesterday: 6.5
# Trend of new cases (in %) in the last 5 days: 57.14

# %% [markdown]
# # Casi di COVID-19 in Abruzzo - COVID-19 cases in Abruzzo

# %%
calculate_and_create_chart_for_region(START_DATE, 'Abruzzo')
# Out:
# Total cases up to today: 813
# New cases registered today: 124
# New cases registered today in %: 18.0
# Doubling time in the last five days: 5.8
# Doubling time yesterday: 6.0
# Trend of new cases (in %) in the last 5 days: 81.07

# %% [markdown]
# ## Chieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Chieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3752
# Total cases up to today: 146
# New cases registered today: 13
# New cases registered today in %: 9.77
# Doubling time in the last five days: 5.8
# Doubling time yesterday: 5.3
# Trend of new cases (in %) in the last 5 days: 82.5

# %% [markdown]
# ## L'Aquila

# %%
calculate_and_create_chart_for_province(START_DATE, "L'Aquila")
# Out:
# Total cases per 1000 inhabitants up to today: 0.1987
# Total cases up to today: 60
# New cases registered today: 13
# New cases registered today in %: 27.66
# Doubling time in the last five days: 4.8
# Doubling time yesterday: 5.5
# Trend of new cases (in %) in the last 5 days: 106.9

# %% [markdown]
# ## Pescara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pescara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2823
# Total cases up to today: 412
# New cases registered today: 43
# New cases registered today in %: 11.65
# Doubling time in the last five days: 7.5
# Doubling time yesterday: 6.9
# Trend of new cases (in %) in the last 5 days: 59.07

# %% [markdown]
# ## Teramo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Teramo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6293
# Total cases up to today: 195
# New cases registered today: 55
# New cases registered today in %: 39.29
# Doubling time in the last five days: 3.9
# Doubling time yesterday: 4.8
# Trend of new cases (in %) in the last 5 days: 140.74

# %% [markdown]
# # Casi di COVID-19 in Basilicata - COVID-19 cases in Basilicata

# %%
calculate_and_create_chart_for_region(START_DATE, 'Basilicata')
# Out:
# Total cases up to today: 106
# New cases registered today: 14
# New cases registered today in %: 15.22
# Doubling time in the last five days: 4.9
# Doubling time yesterday: 3.8
# Trend of new cases (in %) in the last 5 days: 103.85

# %% [markdown]
# ## Matera

# %%
calculate_and_create_chart_for_province(START_DATE, 'Matera')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1803
# Total cases up to today: 36
# New cases registered today: 11
# New cases registered today in %: 44.0
# Doubling time in the last five days: 2.5
# Doubling time yesterday: 2.7
# Trend of new cases (in %) in the last 5 days: 300.0

# %% [markdown]
# ## Potenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Potenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1888
# Total cases up to today: 70
# New cases registered today: 3
# New cases registered today in %: 4.48
# Doubling time in the last five days: 7.1
# Doubling time yesterday: 4.3
# Trend of new cases (in %) in the last 5 days: 62.79

# %% [markdown]
# # Casi di COVID-19 nella Provincia Autonoma di Bolzano - COVID-19 cases in Autonomous Province of Bolzano

# %%
calculate_and_create_chart_for_region(START_DATE, 'P.A. Bolzano')
# Out:
# Total cases up to today: 858
# New cases registered today: 77
# New cases registered today in %: 9.86
# Doubling time in the last five days: 7.7
# Doubling time yesterday: 5.9
# Trend of new cases (in %) in the last 5 days: 56.57

# %% [markdown]
# # Casi di COVID-19 in Calabria - COVID-19 cases in Calabria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Calabria')
# Out:
# Total cases up to today: 349
# New cases registered today: 32
# New cases registered today in %: 10.09
# Doubling time in the last five days: 6.5
# Doubling time yesterday: 5.5
# Trend of new cases (in %) in the last 5 days: 70.24

# %% [markdown]
# ## Catanzaro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catanzaro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1408
# Total cases up to today: 51
# New cases registered today: 2
# New cases registered today in %: 4.08
# Doubling time in the last five days: 8.5
# Doubling time yesterday: 5.8
# Trend of new cases (in %) in the last 5 days: 50.0

# %% [markdown]
# ## Cosenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cosenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1391
# Total cases up to today: 99
# New cases registered today: 15
# New cases registered today in %: 17.86
# Doubling time in the last five days: 4.4
# Doubling time yesterday: 4.4
# Trend of new cases (in %) in the last 5 days: 120.0

# %% [markdown]
# ## Crotone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Crotone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4044
# Total cases up to today: 71
# New cases registered today: 5
# New cases registered today in %: 7.58
# Doubling time in the last five days: 7.6
# Doubling time yesterday: 6.6
# Trend of new cases (in %) in the last 5 days: 57.78

# %% [markdown]
# ## Reggio di Calabria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Reggio di Calabria')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1896
# Total cases up to today: 105
# New cases registered today: 8
# New cases registered today in %: 8.25
# Doubling time in the last five days: 9.5
# Doubling time yesterday: 6.5
# Trend of new cases (in %) in the last 5 days: 43.84

# %% [markdown]
# ## Vibo Valentia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vibo Valentia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1423
# Total cases up to today: 23
# New cases registered today: 2
# New cases registered today in %: 9.52
# Doubling time in the last five days: 3.3
# Doubling time yesterday: 3.6
# Trend of new cases (in %) in the last 5 days: 187.5

# %% [markdown]
# # Casi di COVID-19 in Campania - COVID-19 cases in Campania

# %%
calculate_and_create_chart_for_region(START_DATE, 'Campania')
# Out:
# Total cases up to today: 1197
# New cases registered today: 106
# New cases registered today in %: 9.72
# Doubling time in the last five days: 7.0
# Doubling time yesterday: 6.5
# Trend of new cases (in %) in the last 5 days: 63.52

# %% [markdown]
# ## Avellino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Avellino')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4061
# Total cases up to today: 172
# New cases registered today: 17
# New cases registered today in %: 10.97
# Doubling time in the last five days: 6.1
# Doubling time yesterday: 6.1
# Trend of new cases (in %) in the last 5 days: 77.32

# %% [markdown]
# ## Benevento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Benevento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0501
# Total cases up to today: 14
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 6.2
# Doubling time yesterday: 6.2
# Trend of new cases (in %) in the last 5 days: 75.0

# %% [markdown]
# ## Caserta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caserta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1785
# Total cases up to today: 165
# New cases registered today: 13
# New cases registered today in %: 8.55
# Doubling time in the last five days: 6.4
# Doubling time yesterday: 7.2
# Trend of new cases (in %) in the last 5 days: 71.88

# %% [markdown]
# ## Napoli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Napoli')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2015
# Total cases up to today: 626
# New cases registered today: 38
# New cases registered today in %: 6.46
# Doubling time in the last five days: 8.5
# Doubling time yesterday: 7.0
# Trend of new cases (in %) in the last 5 days: 50.48

# %% [markdown]
# ## Salerno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Salerno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1991
# Total cases up to today: 220
# New cases registered today: 38
# New cases registered today in %: 20.88
# Doubling time in the last five days: 5.3
# Doubling time yesterday: 5.1
# Trend of new cases (in %) in the last 5 days: 91.3

# %% [markdown]
# # Casi di COVID-19 in Emilia Romagna - COVID-19 cases in Emilia Romagna

# %%
calculate_and_create_chart_for_region(START_DATE, 'Emilia Romagna')
# Out:
# Total cases up to today: 10054
# New cases registered today: 800
# New cases registered today in %: 8.64
# Doubling time in the last five days: 6.6
# Doubling time yesterday: 6.0
# Trend of new cases (in %) in the last 5 days: 68.47

# %% [markdown]
# ## Bologna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bologna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0969
# Total cases up to today: 1107
# New cases registered today: 139
# New cases registered today in %: 14.36
# Doubling time in the last five days: 5.0
# Doubling time yesterday: 4.7
# Trend of new cases (in %) in the last 5 days: 100.54

# %% [markdown]
# ## Ferrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ferrara')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5856
# Total cases up to today: 204
# New cases registered today: 14
# New cases registered today in %: 7.37
# Doubling time in the last five days: 5.0
# Doubling time yesterday: 3.9
# Trend of new cases (in %) in the last 5 days: 100.0

# %% [markdown]
# ## Forlì-Cesena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Forlì-Cesena')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1521
# Total cases up to today: 454
# New cases registered today: 17
# New cases registered today in %: 3.89
# Doubling time in the last five days: 5.8
# Doubling time yesterday: 5.3
# Trend of new cases (in %) in the last 5 days: 81.6

# %% [markdown]
# ## Modena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Modena')
# Out:
# Total cases per 1000 inhabitants up to today: 2.1873
# Total cases up to today: 1533
# New cases registered today: 179
# New cases registered today in %: 13.22
# Doubling time in the last five days: 5.0
# Doubling time yesterday: 4.9
# Trend of new cases (in %) in the last 5 days: 99.87

# %% [markdown]
# ## Parma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Parma')
# Out:
# Total cases per 1000 inhabitants up to today: 3.3972
# Total cases up to today: 1525
# New cases registered today: 90
# New cases registered today in %: 6.27
# Doubling time in the last five days: 7.8
# Doubling time yesterday: 6.9
# Trend of new cases (in %) in the last 5 days: 55.77

# %% [markdown]
# ## Piacenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Piacenza')
# Out:
# Total cases per 1000 inhabitants up to today: 7.4
# Total cases up to today: 2122
# New cases registered today: 141
# New cases registered today in %: 7.12
# Doubling time in the last five days: 11.6
# Doubling time yesterday: 10.6
# Trend of new cases (in %) in the last 5 days: 34.73

# %% [markdown]
# ## Ravenna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ravenna')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9887
# Total cases up to today: 387
# New cases registered today: 19
# New cases registered today in %: 5.16
# Doubling time in the last five days: 5.8
# Doubling time yesterday: 5.0
# Trend of new cases (in %) in the last 5 days: 81.69

# %% [markdown]
# ## Reggio nell'Emilia

# %%
calculate_and_create_chart_for_province(START_DATE, "Reggio nell'Emilia")
# Out:
# Total cases per 1000 inhabitants up to today: 2.9785
# Total cases up to today: 1586
# New cases registered today: 149
# New cases registered today in %: 10.37
# Doubling time in the last five days: 4.8
# Doubling time yesterday: 4.0
# Trend of new cases (in %) in the last 5 days: 105.17

# %% [markdown]
# ## Rimini

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rimini')
# Out:
# Total cases per 1000 inhabitants up to today: 3.3731
# Total cases up to today: 1136
# New cases registered today: 52
# New cases registered today in %: 4.8
# Doubling time in the last five days: 8.5
# Doubling time yesterday: 7.7
# Trend of new cases (in %) in the last 5 days: 50.07

# %% [markdown]
# # Casi di COVID-19 in Friuli Venezia Giulia - COVID-19 cases in Friuli Venezia Giulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Friuli Venezia Giulia')
# Out:
# Total cases up to today: 1128
# New cases registered today: 136
# New cases registered today in %: 13.71
# Doubling time in the last five days: 6.4
# Doubling time yesterday: 6.9
# Trend of new cases (in %) in the last 5 days: 71.95

# %% [markdown]
# ## Gorizia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Gorizia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4654
# Total cases up to today: 65
# New cases registered today: 8
# New cases registered today in %: 14.04
# Doubling time in the last five days: 4.5
# Doubling time yesterday: 4.9
# Trend of new cases (in %) in the last 5 days: 116.67

# %% [markdown]
# ## Pordenone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pordenone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8877
# Total cases up to today: 277
# New cases registered today: 76
# New cases registered today in %: 37.81
# Doubling time in the last five days: 3.9
# Doubling time yesterday: 4.8
# Trend of new cases (in %) in the last 5 days: 142.98

# %% [markdown]
# ## Trieste

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trieste')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5127
# Total cases up to today: 355
# New cases registered today: 26
# New cases registered today in %: 7.9
# Doubling time in the last five days: 7.0
# Doubling time yesterday: 7.6
# Trend of new cases (in %) in the last 5 days: 64.35

# %% [markdown]
# ## Udine

# %%
calculate_and_create_chart_for_province(START_DATE, 'Udine')
# Out:
# Total cases per 1000 inhabitants up to today: 0.811
# Total cases up to today: 431
# New cases registered today: 26
# New cases registered today in %: 6.42
# Doubling time in the last five days: 9.2
# Doubling time yesterday: 8.2
# Trend of new cases (in %) in the last 5 days: 45.61

# %% [markdown]
# # Casi di COVID-19 nel Lazio - COVID-19 cases in Lazio

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lazio')
# Out:
# Total cases up to today: 1893
# New cases registered today: 173
# New cases registered today in %: 10.06
# Doubling time in the last five days: 5.5
# Doubling time yesterday: 4.7
# Trend of new cases (in %) in the last 5 days: 88.73

# %% [markdown]
# ## Frosinone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Frosinone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.215
# Total cases up to today: 106
# New cases registered today: 9
# New cases registered today in %: 9.28
# Doubling time in the last five days: 4.9
# Doubling time yesterday: 4.9
# Trend of new cases (in %) in the last 5 days: 103.85

# %% [markdown]
# ## Latina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Latina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3444
# Total cases up to today: 198
# New cases registered today: 16
# New cases registered today in %: 8.79
# Doubling time in the last five days: 6.4
# Doubling time yesterday: 1.7
# Trend of new cases (in %) in the last 5 days: 72.17

# %% [markdown]
# ## Rieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2477
# Total cases up to today: 39
# New cases registered today: 6
# New cases registered today in %: 18.18
# Doubling time in the last five days: 4.5
# Doubling time yesterday: 5.7
# Trend of new cases (in %) in the last 5 days: 116.67

# %% [markdown]
# ## Roma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Roma')
# Out:
# Total cases per 1000 inhabitants up to today: 0.328
# Total cases up to today: 1428
# New cases registered today: 141
# New cases registered today in %: 10.96
# Doubling time in the last five days: 5.4
# Doubling time yesterday: 5.4
# Trend of new cases (in %) in the last 5 days: 89.14

# %% [markdown]
# ## Viterbo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Viterbo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3824
# Total cases up to today: 122
# New cases registered today: 1
# New cases registered today in %: 0.83
# Doubling time in the last five days: 5.2
# Doubling time yesterday: 3.9
# Trend of new cases (in %) in the last 5 days: 93.65

# %% [markdown]
# # Casi di COVID-19 in Liguria - COVID-19 cases in Liguria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Liguria')
# Out:
# Total cases up to today: 1306
# New cases registered today: 116
# New cases registered today in %: 9.75
# Doubling time in the last five days: 10.0
# Doubling time yesterday: 9.4
# Trend of new cases (in %) in the last 5 days: 41.34

# %% [markdown]
# ## Genova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Genova')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9199
# Total cases up to today: 782
# New cases registered today: 86
# New cases registered today in %: 12.36
# Doubling time in the last five days: 8.8
# Doubling time yesterday: 9.8
# Trend of new cases (in %) in the last 5 days: 48.39

# %% [markdown]
# ## Imperia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Imperia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8228
# Total cases up to today: 177
# New cases registered today: -9
# New cases registered today in %: -4.84
# Doubling time in the last five days: 17.4
# Doubling time yesterday: 7.5
# Trend of new cases (in %) in the last 5 days: 22.07

# %% [markdown]
# ## La Spezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'La Spezia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6208
# Total cases up to today: 137
# New cases registered today: 33
# New cases registered today in %: 31.73
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 20.7
# Trend of new cases (in %) in the last 5 days: 52.22

# %% [markdown]
# ## Savona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Savona')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7516
# Total cases up to today: 210
# New cases registered today: 6
# New cases registered today in %: 2.94
# Doubling time in the last five days: 13.4
# Doubling time yesterday: 7.8
# Trend of new cases (in %) in the last 5 days: 29.63

# %% [markdown]
# # Casi di COVID-19 in Lombardia - COVID-19 cases in Lombardy

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lombardia')
# Out:
# Total cases up to today: 31658
# New cases registered today: 1611
# New cases registered today in %: 5.36
# Doubling time in the last five days: 9.3
# Doubling time yesterday: 8.0
# Trend of new cases (in %) in the last 5 days: 45.25

# %% [markdown]
# ## Bergamo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bergamo')
# Out:
# Total cases per 1000 inhabitants up to today: 6.3716
# Total cases up to today: 7072
# New cases registered today: 344
# New cases registered today in %: 5.11
# Doubling time in the last five days: 11.0
# Doubling time yesterday: 9.4
# Trend of new cases (in %) in the last 5 days: 37.21

# %% [markdown]
# ## Brescia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brescia')
# Out:
# Total cases per 1000 inhabitants up to today: 5.2261
# Total cases up to today: 6597
# New cases registered today: 299
# New cases registered today in %: 4.75
# Doubling time in the last five days: 9.9
# Doubling time yesterday: 8.8
# Trend of new cases (in %) in the last 5 days: 41.93

# %% [markdown]
# ## Como

# %%
calculate_and_create_chart_for_province(START_DATE, 'Como')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1763
# Total cases up to today: 706
# New cases registered today: 71
# New cases registered today in %: 11.18
# Doubling time in the last five days: 5.6
# Doubling time yesterday: 5.5
# Trend of new cases (in %) in the last 5 days: 85.79

# %% [markdown]
# ## Cremona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cremona')
# Out:
# Total cases per 1000 inhabitants up to today: 8.7816
# Total cases up to today: 3156
# New cases registered today: 95
# New cases registered today in %: 3.1
# Doubling time in the last five days: 12.5
# Doubling time yesterday: 11.9
# Trend of new cases (in %) in the last 5 days: 31.94

# %% [markdown]
# ## Lecco

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecco')
# Out:
# Total cases per 1000 inhabitants up to today: 3.1718
# Total cases up to today: 1076
# New cases registered today: 61
# New cases registered today in %: 6.01
# Doubling time in the last five days: 7.5
# Doubling time yesterday: 5.3
# Trend of new cases (in %) in the last 5 days: 59.17

# %% [markdown]
# ## Lodi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lodi')
# Out:
# Total cases per 1000 inhabitants up to today: 8.2149
# Total cases up to today: 1884
# New cases registered today: 24
# New cases registered today in %: 1.29
# Doubling time in the last five days: 21.0
# Doubling time yesterday: 17.6
# Trend of new cases (in %) in the last 5 days: 17.97

# %% [markdown]
# ## Mantova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Mantova')
# Out:
# Total cases per 1000 inhabitants up to today: 2.8501
# Total cases up to today: 1176
# New cases registered today: 83
# New cases registered today in %: 7.59
# Doubling time in the last five days: 7.1
# Doubling time yesterday: 6.4
# Trend of new cases (in %) in the last 5 days: 62.66

# %% [markdown]
# ## Milano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Milano')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8874
# Total cases up to today: 6074
# New cases registered today: 373
# New cases registered today in %: 6.54
# Doubling time in the last five days: 7.4
# Doubling time yesterday: 6.3
# Trend of new cases (in %) in the last 5 days: 59.67

# %% [markdown]
# ## Monza e della Brianza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Monza e della Brianza')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8265
# Total cases up to today: 1587
# New cases registered today: 133
# New cases registered today in %: 9.15
# Doubling time in the last five days: 5.2
# Doubling time yesterday: 3.2
# Trend of new cases (in %) in the last 5 days: 94.49

# %% [markdown]
# ## Pavia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pavia')
# Out:
# Total cases per 1000 inhabitants up to today: 2.8835
# Total cases up to today: 1578
# New cases registered today: 79
# New cases registered today in %: 5.27
# Doubling time in the last five days: 9.7
# Doubling time yesterday: 8.8
# Trend of new cases (in %) in the last 5 days: 42.81

# %% [markdown]
# ## Sondrio

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sondrio')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5653
# Total cases up to today: 284
# New cases registered today: 31
# New cases registered today in %: 12.25
# Doubling time in the last five days: 6.2
# Doubling time yesterday: 7.1
# Trend of new cases (in %) in the last 5 days: 74.23

# %% [markdown]
# ## Varese

# %%
calculate_and_create_chart_for_province(START_DATE, 'Varese')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5258
# Total cases up to today: 468
# New cases registered today: 18
# New cases registered today in %: 4.0
# Doubling time in the last five days: 10.6
# Doubling time yesterday: 9.3
# Trend of new cases (in %) in the last 5 days: 38.46

# %% [markdown]
# # Casi di COVID-19 nelle Marche - COVID-19 cases in Marche

# %%
calculate_and_create_chart_for_region(START_DATE, 'Marche')
# Out:
# Total cases up to today: 2887
# New cases registered today: 194
# New cases registered today in %: 7.2
# Doubling time in the last five days: 8.8
# Doubling time yesterday: 7.6
# Trend of new cases (in %) in the last 5 days: 48.05

# %% [markdown]
# ## Ancona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ancona')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7295
# Total cases up to today: 820
# New cases registered today: 69
# New cases registered today in %: 9.19
# Doubling time in the last five days: 7.4
# Doubling time yesterday: 6.7
# Trend of new cases (in %) in the last 5 days: 59.84

# %% [markdown]
# ## Ascoli Piceno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ascoli Piceno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.382
# Total cases up to today: 80
# New cases registered today: 16
# New cases registered today in %: 25.0
# Doubling time in the last five days: 5.6
# Doubling time yesterday: 4.0
# Trend of new cases (in %) in the last 5 days: 86.05

# %% [markdown]
# ## Fermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Fermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9151
# Total cases up to today: 160
# New cases registered today: 21
# New cases registered today in %: 15.11
# Doubling time in the last five days: 5.0
# Doubling time yesterday: 4.8
# Trend of new cases (in %) in the last 5 days: 100.0

# %% [markdown]
# ## Macerata

# %%
calculate_and_create_chart_for_province(START_DATE, 'Macerata')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2386
# Total cases up to today: 395
# New cases registered today: 27
# New cases registered today in %: 7.34
# Doubling time in the last five days: 5.7
# Doubling time yesterday: 5.1
# Trend of new cases (in %) in the last 5 days: 83.72

# %% [markdown]
# ## Pesaro e Urbino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pesaro e Urbino')
# Out:
# Total cases per 1000 inhabitants up to today: 3.9699
# Total cases up to today: 1432
# New cases registered today: 61
# New cases registered today in %: 4.45
# Doubling time in the last five days: 13.1
# Doubling time yesterday: 10.4
# Trend of new cases (in %) in the last 5 days: 30.3

# %% [markdown]
# # Casi di COVID-19 in Molise - COVID-19 cases in Molise¶

# %%
calculate_and_create_chart_for_region(START_DATE, 'Molise')
# Out:
# Total cases up to today: 64
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 8.7
# Doubling time yesterday: 6.3
# Trend of new cases (in %) in the last 5 days: 48.84

# %% [markdown]
# ## Campobasso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Campobasso')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2671
# Total cases up to today: 60
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 8.0
# Doubling time yesterday: 5.8
# Trend of new cases (in %) in the last 5 days: 53.85

# %% [markdown]
# ## Isernia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Isernia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0466
# Total cases up to today: 4
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: nan
# Doubling time yesterday: nan
# Trend of new cases (in %) in the last 5 days: 0.0

# %% [markdown]
# # Casi di COVID-19 in Piemonte - COVID-19 cases in Piedmont

# %%
calculate_and_create_chart_for_region(START_DATE, 'Piemonte')
# Out:
# Total cases up to today: 5860
# New cases registered today: 504
# New cases registered today in %: 9.41
# Doubling time in the last five days: 6.2
# Doubling time yesterday: 3.9
# Trend of new cases (in %) in the last 5 days: 75.66

# %% [markdown]
# ## Alessandria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Alessandria')
# Out:
# Total cases per 1000 inhabitants up to today: 2.2172
# Total cases up to today: 946
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 7.5
# Doubling time yesterday: 3.7
# Trend of new cases (in %) in the last 5 days: 58.99

# %% [markdown]
# ## Asti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Asti')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2046
# Total cases up to today: 261
# New cases registered today: 26
# New cases registered today in %: 11.06
# Doubling time in the last five days: 6.3
# Doubling time yesterday: 4.1
# Trend of new cases (in %) in the last 5 days: 72.85

# %% [markdown]
# ## Biella

# %%
calculate_and_create_chart_for_province(START_DATE, 'Biella')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8314
# Total cases up to today: 327
# New cases registered today: 47
# New cases registered today in %: 16.79
# Doubling time in the last five days: 5.5
# Doubling time yesterday: 3.7
# Trend of new cases (in %) in the last 5 days: 86.86

# %% [markdown]
# ## Cuneo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cuneo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7486
# Total cases up to today: 441
# New cases registered today: 32
# New cases registered today in %: 7.82
# Doubling time in the last five days: 5.0
# Doubling time yesterday: 3.4
# Trend of new cases (in %) in the last 5 days: 99.55

# %% [markdown]
# ## Novara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Novara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3968
# Total cases up to today: 517
# New cases registered today: 46
# New cases registered today in %: 9.77
# Doubling time in the last five days: 6.1
# Doubling time yesterday: 3.8
# Trend of new cases (in %) in the last 5 days: 76.45

# %% [markdown]
# ## Torino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Torino')
# Out:
# Total cases per 1000 inhabitants up to today: 1.2349
# Total cases up to today: 2813
# New cases registered today: 317
# New cases registered today in %: 12.7
# Doubling time in the last five days: 5.9
# Doubling time yesterday: 4.0
# Trend of new cases (in %) in the last 5 days: 80.78

# %% [markdown]
# ## 	Verbano-Cusio-Ossola

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verbano-Cusio-Ossola')
# Out:
# Total cases per 1000 inhabitants up to today: 1.547
# Total cases up to today: 247
# New cases registered today: 18
# New cases registered today in %: 7.86
# Doubling time in the last five days: 6.3
# Doubling time yesterday: 3.7
# Trend of new cases (in %) in the last 5 days: 73.94

# %% [markdown]
# ## Vercelli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vercelli')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7715
# Total cases up to today: 308
# New cases registered today: 18
# New cases registered today in %: 6.21
# Doubling time in the last five days: 8.3
# Doubling time yesterday: 4.4
# Trend of new cases (in %) in the last 5 days: 51.72

# %% [markdown]
# # Casi di COVID-19 in Puglia - COVID-19 cases in Apulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Puglia')
# Out:
# Total cases up to today: 1014
# New cases registered today: 78
# New cases registered today in %: 8.33
# Doubling time in the last five days: 5.9
# Doubling time yesterday: 5.0
# Trend of new cases (in %) in the last 5 days: 80.11

# %% [markdown]
# ## Bari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2666
# Total cases up to today: 336
# New cases registered today: 32
# New cases registered today in %: 10.53
# Doubling time in the last five days: 4.9
# Doubling time yesterday: 4.3
# Trend of new cases (in %) in the last 5 days: 103.64

# %% [markdown]
# ## 	Barletta-Andria-Trani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Barletta-Andria-Trani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1656
# Total cases up to today: 65
# New cases registered today: 3
# New cases registered today in %: 4.84
# Doubling time in the last five days: 4.5
# Doubling time yesterday: 4.0
# Trend of new cases (in %) in the last 5 days: 116.67

# %% [markdown]
# ## Brindisi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brindisi')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2921
# Total cases up to today: 116
# New cases registered today: 13
# New cases registered today in %: 12.62
# Doubling time in the last five days: 10.7
# Doubling time yesterday: 10.9
# Trend of new cases (in %) in the last 5 days: 38.1

# %% [markdown]
# ## Foggia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Foggia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4407
# Total cases up to today: 277
# New cases registered today: 22
# New cases registered today in %: 8.63
# Doubling time in the last five days: 6.5
# Doubling time yesterday: 5.4
# Trend of new cases (in %) in the last 5 days: 69.94

# %% [markdown]
# ## Lecce

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecce')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2045
# Total cases up to today: 164
# New cases registered today: 3
# New cases registered today in %: 1.86
# Doubling time in the last five days: 5.6
# Doubling time yesterday: 4.2
# Trend of new cases (in %) in the last 5 days: 86.36

# %% [markdown]
# ## Taranto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Taranto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.096
# Total cases up to today: 56
# New cases registered today: 5
# New cases registered today in %: 9.8
# Doubling time in the last five days: 6.6
# Doubling time yesterday: 4.4
# Trend of new cases (in %) in the last 5 days: 69.7

# %% [markdown]
# # Casi di COVID-19 in Sardegna - COVID-19 cases in Sardinia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sardegna')
# Out:
# Total cases up to today: 442
# New cases registered today: 21
# New cases registered today in %: 4.99
# Doubling time in the last five days: 8.4
# Doubling time yesterday: 4.8
# Trend of new cases (in %) in the last 5 days: 50.85

# %% [markdown]
# ## Cagliari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cagliari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1321
# Total cases up to today: 74
# New cases registered today: 10
# New cases registered today in %: 15.62
# Doubling time in the last five days: 6.4
# Doubling time yesterday: 7.8
# Trend of new cases (in %) in the last 5 days: 72.09

# %% [markdown]
# ## Nuoro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Nuoro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1666
# Total cases up to today: 26
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 20.7
# Doubling time yesterday: 16.2
# Trend of new cases (in %) in the last 5 days: 18.18

# %% [markdown]
# ## Oristano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Oristano')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0435
# Total cases up to today: 7
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 6.2
# Doubling time yesterday: 4.1
# Trend of new cases (in %) in the last 5 days: 75.0

# %% [markdown]
# ## Sassari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sassari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9546
# Total cases up to today: 318
# New cases registered today: 9
# New cases registered today in %: 2.91
# Doubling time in the last five days: 9.0
# Doubling time yesterday: 4.1
# Trend of new cases (in %) in the last 5 days: 47.22

# %% [markdown]
# # Casi di COVID-19 in Sicilia - COVID-19 cases in Sicily

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sicilia')
# Out:
# Total cases up to today: 994
# New cases registered today: 148
# New cases registered today in %: 17.49
# Doubling time in the last five days: 3.9
# Doubling time yesterday: 3.8
# Trend of new cases (in %) in the last 5 days: 143.63

# %% [markdown]
# ## Agrigento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Agrigento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1131
# Total cases up to today: 50
# New cases registered today: 3
# New cases registered today in %: 6.38
# Doubling time in the last five days: 7.2
# Doubling time yesterday: 6.3
# Trend of new cases (in %) in the last 5 days: 61.29

# %% [markdown]
# ## Caltanissetta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caltanissetta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1668
# Total cases up to today: 45
# New cases registered today: 5
# New cases registered today in %: 12.5
# Doubling time in the last five days: 3.8
# Doubling time yesterday: 2.9
# Trend of new cases (in %) in the last 5 days: 150.0

# %% [markdown]
# ## Catania

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catania')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2767
# Total cases up to today: 308
# New cases registered today: 22
# New cases registered today in %: 7.69
# Doubling time in the last five days: 5.4
# Doubling time yesterday: 5.4
# Trend of new cases (in %) in the last 5 days: 90.12

# %% [markdown]
# ## Enna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Enna')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5355
# Total cases up to today: 90
# New cases registered today: 27
# New cases registered today in %: 42.86
# Doubling time in the last five days: 2.7
# Doubling time yesterday: 3.2
# Trend of new cases (in %) in the last 5 days: 260.0

# %% [markdown]
# ## Messina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Messina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2733
# Total cases up to today: 174
# New cases registered today: 35
# New cases registered today in %: 25.18
# Doubling time in the last five days: 2.3
# Doubling time yesterday: 1.6
# Trend of new cases (in %) in the last 5 days: 346.15

# %% [markdown]
# ## Palermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Palermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1522
# Total cases up to today: 193
# New cases registered today: 23
# New cases registered today in %: 13.53
# Doubling time in the last five days: 2.9
# Doubling time yesterday: 2.9
# Trend of new cases (in %) in the last 5 days: 227.12

# %% [markdown]
# ## Ragusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ragusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.0685
# Total cases up to today: 22
# New cases registered today: 13
# New cases registered today in %: 144.44
# Doubling time in the last five days: 3.0
# Doubling time yesterday: 13.8
# Trend of new cases (in %) in the last 5 days: 214.29

# %% [markdown]
# ## Siracusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siracusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1589
# Total cases up to today: 64
# New cases registered today: 15
# New cases registered today in %: 30.61
# Doubling time in the last five days: 7.4
# Doubling time yesterday: 8.8
# Trend of new cases (in %) in the last 5 days: 60.0

# %% [markdown]
# ## Trapani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trapani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1105
# Total cases up to today: 48
# New cases registered today: 5
# New cases registered today in %: 11.63
# Doubling time in the last five days: 6.0
# Doubling time yesterday: 4.8
# Trend of new cases (in %) in the last 5 days: 77.78

# %% [markdown]
# # Casi di COVID-19 in Toscana - COVID-19 cases in Tuscany

# %%
calculate_and_create_chart_for_region(START_DATE, 'Toscana')
# Out:
# Total cases up to today: 2972
# New cases registered today: 273
# New cases registered today in %: 10.11
# Doubling time in the last five days: 6.9
# Doubling time yesterday: 5.8
# Trend of new cases (in %) in the last 5 days: 65.76

# %% [markdown]
# ## Arezzo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Arezzo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.665
# Total cases up to today: 229
# New cases registered today: 18
# New cases registered today in %: 8.53
# Doubling time in the last five days: 5.6
# Doubling time yesterday: 5.5
# Trend of new cases (in %) in the last 5 days: 84.68

# %% [markdown]
# ## Firenze

# %%
calculate_and_create_chart_for_province(START_DATE, 'Firenze')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6989
# Total cases up to today: 709
# New cases registered today: 87
# New cases registered today in %: 13.99
# Doubling time in the last five days: 6.1
# Doubling time yesterday: 6.0
# Trend of new cases (in %) in the last 5 days: 76.81

# %% [markdown]
# ## Grosseto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Grosseto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6591
# Total cases up to today: 147
# New cases registered today: 7
# New cases registered today in %: 5.0
# Doubling time in the last five days: 8.3
# Doubling time yesterday: 7.7
# Trend of new cases (in %) in the last 5 days: 51.55

# %% [markdown]
# ## Livorno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Livorno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5306
# Total cases up to today: 179
# New cases registered today: 17
# New cases registered today in %: 10.49
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 3.6
# Trend of new cases (in %) in the last 5 days: 52.99

# %% [markdown]
# ## Lucca

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lucca')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1178
# Total cases up to today: 436
# New cases registered today: 49
# New cases registered today in %: 12.66
# Doubling time in the last five days: 6.2
# Doubling time yesterday: 6.7
# Trend of new cases (in %) in the last 5 days: 75.1

# %% [markdown]
# ## Massa Carrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Massa Carrara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.6787
# Total cases up to today: 330
# New cases registered today: 16
# New cases registered today in %: 5.1
# Doubling time in the last five days: 9.8
# Doubling time yesterday: 7.7
# Trend of new cases (in %) in the last 5 days: 42.24

# %% [markdown]
# ## Pisa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pisa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7515
# Total cases up to today: 317
# New cases registered today: 32
# New cases registered today in %: 11.23
# Doubling time in the last five days: 6.1
# Doubling time yesterday: 5.2
# Trend of new cases (in %) in the last 5 days: 76.11

# %% [markdown]
# ## Pistoia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pistoia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8703
# Total cases up to today: 254
# New cases registered today: 11
# New cases registered today in %: 4.53
# Doubling time in the last five days: 8.8
# Doubling time yesterday: 6.7
# Trend of new cases (in %) in the last 5 days: 48.54

# %% [markdown]
# ## Prato

# %%
calculate_and_create_chart_for_province(START_DATE, 'Prato')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6991
# Total cases up to today: 178
# New cases registered today: 19
# New cases registered today in %: 11.95
# Doubling time in the last five days: 5.4
# Doubling time yesterday: 4.2
# Trend of new cases (in %) in the last 5 days: 89.36

# %% [markdown]
# ## Siena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siena')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7192
# Total cases up to today: 193
# New cases registered today: 17
# New cases registered today in %: 9.66
# Doubling time in the last five days: 8.4
# Doubling time yesterday: 4.3
# Trend of new cases (in %) in the last 5 days: 50.78

# %% [markdown]
# # Casi di COVID-19 in Provincia Autonoma di Trento - COVID-19 cases in the Autonomous Province of Trento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trento')
# Out:
# Total cases per 1000 inhabitants up to today: 2.2688
# Total cases up to today: 1222
# New cases registered today: 112
# New cases registered today in %: 10.09
# Doubling time in the last five days: 5.4
# Doubling time yesterday: 4.6
# Trend of new cases (in %) in the last 5 days: 90.34

# %% [markdown]
# # Casi di COVID-19 in Umbria - COVID-19 cases in Umbria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Umbria')
# Out:
# Total cases up to today: 686
# New cases registered today: 59
# New cases registered today in %: 9.41
# Doubling time in the last five days: 5.8
# Doubling time yesterday: 5.2
# Trend of new cases (in %) in the last 5 days: 81.96

# %% [markdown]
# ## Perugia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Perugia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7916
# Total cases up to today: 523
# New cases registered today: 51
# New cases registered today in %: 10.81
# Doubling time in the last five days: 5.5
# Doubling time yesterday: 5.0
# Trend of new cases (in %) in the last 5 days: 86.79

# %% [markdown]
# ## Terni

# %%
calculate_and_create_chart_for_province(START_DATE, 'Terni')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7142
# Total cases up to today: 163
# New cases registered today: 8
# New cases registered today in %: 5.16
# Doubling time in the last five days: 6.7
# Doubling time yesterday: 5.7
# Trend of new cases (in %) in the last 5 days: 68.04

# %% [markdown]
# # Casi di COVID-19 in Valle d'Aosta - COVID-19 cases in Aosta Valley

# %%
calculate_and_create_chart_for_province(START_DATE, "Aosta")
# Out:
# Total cases per 1000 inhabitants up to today: 3.1604
# Total cases up to today: 401
# New cases registered today: 1
# New cases registered today in %: 0.25
# Doubling time in the last five days: 8.3
# Doubling time yesterday: 5.6
# Trend of new cases (in %) in the last 5 days: 51.89

# %% [markdown]
# # Casi di COVID-19 in Veneto - COVID-19 cases in Veneto

# %%
calculate_and_create_chart_for_region(START_DATE, 'Veneto')
# Out:
# Total cases up to today: 6200
# New cases registered today: 481
# New cases registered today in %: 8.41
# Doubling time in the last five days: 7.4
# Doubling time yesterday: 6.5
# Trend of new cases (in %) in the last 5 days: 59.67

# %% [markdown]
# ## Belluno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Belluno')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4481
# Total cases up to today: 298
# New cases registered today: 25
# New cases registered today in %: 9.16
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 5.8
# Trend of new cases (in %) in the last 5 days: 52.82

# %% [markdown]
# ## Padova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Padova')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7474
# Total cases up to today: 1636
# New cases registered today: 172
# New cases registered today in %: 11.75
# Doubling time in the last five days: 7.4
# Doubling time yesterday: 7.5
# Trend of new cases (in %) in the last 5 days: 59.45

# %% [markdown]
# ## Rovigo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rovigo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3646
# Total cases up to today: 87
# New cases registered today: 5
# New cases registered today in %: 6.1
# Doubling time in the last five days: 13.3
# Doubling time yesterday: 7.6
# Trend of new cases (in %) in the last 5 days: 29.85

# %% [markdown]
# ## Treviso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Treviso')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3285
# Total cases up to today: 1177
# New cases registered today: 86
# New cases registered today in %: 7.88
# Doubling time in the last five days: 7.0
# Doubling time yesterday: 6.4
# Trend of new cases (in %) in the last 5 days: 63.7

# %% [markdown]
# ## Venezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Venezia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0231
# Total cases up to today: 874
# New cases registered today: 37
# New cases registered today in %: 4.42
# Doubling time in the last five days: 8.2
# Doubling time yesterday: 6.1
# Trend of new cases (in %) in the last 5 days: 52.26

# %% [markdown]
# ## Verona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verona')
# Out:
# Total cases per 1000 inhabitants up to today: 1.415
# Total cases up to today: 1304
# New cases registered today: 76
# New cases registered today in %: 6.19
# Doubling time in the last five days: 6.8
# Doubling time yesterday: 6.0
# Trend of new cases (in %) in the last 5 days: 66.33

# %% [markdown]
# ## Vicenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vicenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9525
# Total cases up to today: 824
# New cases registered today: 80
# New cases registered today in %: 10.75
# Doubling time in the last five days: 7.5
# Doubling time yesterday: 6.2
# Trend of new cases (in %) in the last 5 days: 59.07
