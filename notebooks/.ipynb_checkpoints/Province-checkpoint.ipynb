# %%
import pandas as pd
import sys
import datetime
import matplotlib.pylab as plt
import numpy as np
from math import log, floor, ceil
from typing import Dict

# %%
START_DATE = datetime.date(2020,2,24)

# %%
def create_filename(day_str: str) -> str:
    return ('../dati-province/dpc-covid19-ita-province-' + day_str + '.csv')

# %%
def handle_Toscana_20200326_error(cases: Dict[str, int]) -> Dict[str, int]:
    cases['20200327'] = cases['20200326'] + floor((cases['20200328'] - cases['20200326'])/2)
    cases['20200328'] = cases['20200327'] + ceil((cases['20200328'] - cases['20200326'])/2)
    return cases

# %%
def calculate_and_create_chart_for_province(start_date: datetime.date, province: str):
    day = start_date
    cases: Dict[str,int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]==province]["totale_casi"])
        day: datetime.date = day + datetime.timedelta(days = 1)
    
    if df[df["denominazione_provincia"]==province]["denominazione_regione"].any()=='Toscana':
        cases = handle_Toscana_20200326_error(cases)
    
    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases per 1000 inhabitants up to today:", round(calculate_cases_to_inhabitants_ratio(cases_df_today, province),4))
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_region(start_date: datetime.date, region: str):
    day: datetime.date = start_date
    cases: Dict[str, int] = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[(df["denominazione_regione"]==region)&(df["denominazione_provincia"]!='In fase di definizione/aggiornamento')]["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)
        
    if region == 'Toscana':
        cases = handle_Toscana_20200326_error(cases)

    cases_df = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_and_create_chart_for_Italy(start_date: datetime.date):
    day = start_date
    cases = {}
    while day<=datetime.date.today():
        day_str: str = day.strftime("%Y%m%d")
        filename: str = create_filename(day_str)
        df: pd.DataFrame = pd.read_csv(filename, encoding = "ISO-8859-1")
        cases[day_str] = int(df[df["denominazione_provincia"]!='In fase di definizione/aggiornamento']["totale_casi"].sum())
        day: datetime.date = day + datetime.timedelta(days = 1)

    cases_df: pd.DataFrame = pd.DataFrame.from_dict(cases, orient='index')
    cases_df = cases_df.reset_index()
    cases_df = cases_df.rename(columns={"index": "Day", 0: "Cases"})
    
    calculate_stats(cases_df)

    x = cases_df.index
    y = cases_df["Cases"]
    plt.scatter(x, y)

    z = np.polyfit(x, y, 3)
    p = np.poly1d(z)
    plt.plot(x,p(x),"r--")
    plt.grid()
    plt.yscale("log")
    plt.show()
    return

# %%
def calculate_stats(cases_df):
    cases_df_today = cases_df[cases_df["Day"]==datetime.date.today().strftime("%Y%m%d")]["Cases"].sum()
    cases_df_yesterday = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 1)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_five_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 5)).strftime("%Y%m%d")]["Cases"].sum()
    cases_df_six_days_ago = cases_df[cases_df["Day"]==(datetime.date.today()- datetime.timedelta(days = 6)).strftime("%Y%m%d")]["Cases"].sum()
    print("Total cases up to today:", cases_df_today)
    print("New cases registered today:", cases_df_today-cases_df_yesterday)
    if int(cases_df_yesterday) != 0:
        print("New cases registered today in %:", round((cases_df_today-cases_df_yesterday)/cases_df_yesterday*100,2))

    print("Doubling time in the last five days:", round(calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago), 1))
    print("Doubling time yesterday:", round(calculate_doubling_time_in_the_last_five_days(cases_df_yesterday, cases_df_six_days_ago), 1))
    print("Trend of new cases (in %) in the last 5 days:", round((cases_df_today-cases_df_five_days_ago)/cases_df_five_days_ago*100,2))
    
    return

# %%
def calculate_doubling_time_in_the_last_five_days(cases_df_today, cases_df_five_days_ago):
    if cases_df_five_days_ago ==0:
        return np.nan
    log_result = log(cases_df_today/cases_df_five_days_ago)
    if log_result != 0:
        return (5*log(2))/(log_result)
    else:
        return np.nan

# %%
def calculate_cases_to_inhabitants_ratio(cases: int, province: str) -> float:
    df_province: pd.DataFrame = pd.read_csv("../general/province.csv")
    inhabitants = df_province[df_province["Provincia"]==province]["Residenti"].str.replace('.', '', regex=True).sum()
    return int(cases)/int(inhabitants)*1000

# %% [markdown]
# # Casi di COVID-19 in Italia - COVID-19 cases in Italy

# %%
calculate_and_create_chart_for_Italy(START_DATE)
# Out:
# Total cases up to today: 132476
# New cases registered today: 2872
# New cases registered today in %: 2.22
# Doubling time in the last five days: 20.1
# Doubling time yesterday: 18.1
# Trend of new cases (in %) in the last 5 days: 18.79

# %% [markdown]
# # Casi di COVID-19 in Abruzzo - COVID-19 cases in Abruzzo

# %%
calculate_and_create_chart_for_region(START_DATE, 'Abruzzo')
# Out:
# Total cases up to today: 1799
# New cases registered today: 78
# New cases registered today in %: 4.53
# Doubling time in the last five days: 18.9
# Doubling time yesterday: 19.1
# Trend of new cases (in %) in the last 5 days: 20.17

# %% [markdown]
# ## Chieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Chieti')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8814
# Total cases up to today: 343
# New cases registered today: 16
# New cases registered today in %: 4.89
# Doubling time in the last five days: 25.2
# Doubling time yesterday: 30.6
# Trend of new cases (in %) in the last 5 days: 14.72

# %% [markdown]
# ## L'Aquila

# %%
calculate_and_create_chart_for_province(START_DATE, "L'Aquila")
# Out:
# Total cases per 1000 inhabitants up to today: 0.626
# Total cases up to today: 189
# New cases registered today: 6
# New cases registered today in %: 3.28
# Doubling time in the last five days: 11.5
# Doubling time yesterday: 9.7
# Trend of new cases (in %) in the last 5 days: 35.0

# %% [markdown]
# ## Pescara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pescara')
# Out:
# Total cases per 1000 inhabitants up to today: 2.3529
# Total cases up to today: 756
# New cases registered today: 28
# New cases registered today in %: 3.85
# Doubling time in the last five days: 22.0
# Doubling time yesterday: 24.2
# Trend of new cases (in %) in the last 5 days: 17.03

# %% [markdown]
# ## Teramo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Teramo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.6491
# Total cases up to today: 511
# New cases registered today: 28
# New cases registered today in %: 5.8
# Doubling time in the last five days: 16.1
# Doubling time yesterday: 15.3
# Trend of new cases (in %) in the last 5 days: 24.03

# %% [markdown]
# # Casi di COVID-19 in Basilicata - COVID-19 cases in Basilicata

# %%
calculate_and_create_chart_for_region(START_DATE, 'Basilicata')
# Out:
# Total cases up to today: 291
# New cases registered today: 4
# New cases registered today in %: 1.39
# Doubling time in the last five days: 20.6
# Doubling time yesterday: 18.1
# Trend of new cases (in %) in the last 5 days: 18.29

# %% [markdown]
# ## Matera

# %%
calculate_and_create_chart_for_province(START_DATE, 'Matera')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7211
# Total cases up to today: 144
# New cases registered today: 1
# New cases registered today in %: 0.7
# Doubling time in the last five days: 17.4
# Doubling time yesterday: 15.3
# Trend of new cases (in %) in the last 5 days: 22.03

# %% [markdown]
# ## Potenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Potenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3966
# Total cases up to today: 147
# New cases registered today: 3
# New cases registered today in %: 2.08
# Doubling time in the last five days: 25.0
# Doubling time yesterday: 22.0
# Trend of new cases (in %) in the last 5 days: 14.84

# %% [markdown]
# # Casi di COVID-19 nella Provincia Autonoma di Bolzano - COVID-19 cases in Autonomous Province of Bolzano

# %%
calculate_and_create_chart_for_region(START_DATE, 'P.A. Bolzano')
# Out:
# Total cases up to today: 1811
# New cases registered today: 89
# New cases registered today in %: 5.17
# Doubling time in the last five days: 17.1
# Doubling time yesterday: 17.8
# Trend of new cases (in %) in the last 5 days: 22.45

# %% [markdown]
# # Casi di COVID-19 in Calabria - COVID-19 cases in Calabria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Calabria')
# Out:
# Total cases up to today: 831
# New cases registered today: 16
# New cases registered today in %: 1.96
# Doubling time in the last five days: 18.5
# Doubling time yesterday: 17.3
# Trend of new cases (in %) in the last 5 days: 20.61

# %% [markdown]
# ## Catanzaro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catanzaro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4471
# Total cases up to today: 162
# New cases registered today: 4
# New cases registered today in %: 2.53
# Doubling time in the last five days: 33.3
# Doubling time yesterday: 28.7
# Trend of new cases (in %) in the last 5 days: 10.96

# %% [markdown]
# ## Cosenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cosenza')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3569
# Total cases up to today: 254
# New cases registered today: 11
# New cases registered today in %: 4.53
# Doubling time in the last five days: 12.9
# Doubling time yesterday: 13.5
# Trend of new cases (in %) in the last 5 days: 30.93

# %% [markdown]
# ## Crotone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Crotone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6379
# Total cases up to today: 112
# New cases registered today: 1
# New cases registered today in %: 0.9
# Doubling time in the last five days: 19.8
# Doubling time yesterday: 20.8
# Trend of new cases (in %) in the last 5 days: 19.15

# %% [markdown]
# ## Reggio di Calabria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Reggio di Calabria')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4387
# Total cases up to today: 243
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 21.6
# Doubling time yesterday: 18.3
# Trend of new cases (in %) in the last 5 days: 17.39

# %% [markdown]
# ## Vibo Valentia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vibo Valentia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3712
# Total cases up to today: 60
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 15.5
# Doubling time yesterday: 11.2
# Trend of new cases (in %) in the last 5 days: 25.0

# %% [markdown]
# # Casi di COVID-19 in Campania - COVID-19 cases in Campania

# %%
calculate_and_create_chart_for_region(START_DATE, 'Campania')
# Out:
# Total cases up to today: 2928
# New cases registered today: 109
# New cases registered today in %: 3.87
# Doubling time in the last five days: 14.2
# Doubling time yesterday: 11.7
# Trend of new cases (in %) in the last 5 days: 27.64

# %% [markdown]
# ## Avellino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Avellino')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8855
# Total cases up to today: 375
# New cases registered today: 2
# New cases registered today in %: 0.54
# Doubling time in the last five days: 13.5
# Doubling time yesterday: 9.4
# Trend of new cases (in %) in the last 5 days: 29.31

# %% [markdown]
# ## Benevento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Benevento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3969
# Total cases up to today: 111
# New cases registered today: 3
# New cases registered today in %: 2.78
# Doubling time in the last five days: 13.0
# Doubling time yesterday: 12.0
# Trend of new cases (in %) in the last 5 days: 30.59

# %% [markdown]
# ## Caserta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caserta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3582
# Total cases up to today: 331
# New cases registered today: 23
# New cases registered today in %: 7.47
# Doubling time in the last five days: 13.3
# Doubling time yesterday: 13.4
# Trend of new cases (in %) in the last 5 days: 29.8

# %% [markdown]
# ## Napoli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Napoli')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5288
# Total cases up to today: 1643
# New cases registered today: 75
# New cases registered today in %: 4.78
# Doubling time in the last five days: 13.8
# Doubling time yesterday: 11.5
# Trend of new cases (in %) in the last 5 days: 28.46

# %% [markdown]
# ## Salerno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Salerno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4236
# Total cases up to today: 468
# New cases registered today: 6
# New cases registered today in %: 1.3
# Doubling time in the last five days: 17.8
# Doubling time yesterday: 13.9
# Trend of new cases (in %) in the last 5 days: 21.56

# %% [markdown]
# # Casi di COVID-19 in Emilia Romagna - COVID-19 cases in Emilia Romagna

# %%
calculate_and_create_chart_for_region(START_DATE, 'Emilia Romagna')
# Out:
# Total cases up to today: 0
# New cases registered today: 0
# Doubling time in the last five days: nan
# Doubling time yesterday: nan
# Trend of new cases (in %) in the last 5 days: nan
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in long_scalars
#   del sys.path[0]

# %% [markdown]
# ## Bologna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bologna')
# Out:
# Total cases per 1000 inhabitants up to today: 2.6318
# Total cases up to today: 2656
# New cases registered today: 39
# New cases registered today in %: 1.49
# Doubling time in the last five days: 19.6
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 19.37

# %% [markdown]
# ## Ferrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ferrara')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4984
# Total cases up to today: 522
# New cases registered today: 12
# New cases registered today in %: 2.35
# Doubling time in the last five days: 8.1
# Doubling time yesterday: 7.7
# Trend of new cases (in %) in the last 5 days: 53.08

# %% [markdown]
# ## Modena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Modena')
# Out:
# Total cases per 1000 inhabitants up to today: 3.9352
# Total cases up to today: 2758
# New cases registered today: 67
# New cases registered today in %: 2.49
# Doubling time in the last five days: 26.2
# Doubling time yesterday: 21.9
# Trend of new cases (in %) in the last 5 days: 14.16

# %% [markdown]
# ## Parma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Parma')
# Out:
# Total cases per 1000 inhabitants up to today: 5.2684
# Total cases up to today: 2365
# New cases registered today: 48
# New cases registered today in %: 2.07
# Doubling time in the last five days: 24.2
# Doubling time yesterday: 24.0
# Trend of new cases (in %) in the last 5 days: 15.42

# %% [markdown]
# ## Piacenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Piacenza')
# Out:
# Total cases per 1000 inhabitants up to today: 10.2979
# Total cases up to today: 2953
# New cases registered today: 17
# New cases registered today in %: 0.58
# Doubling time in the last five days: 52.7
# Doubling time yesterday: 44.5
# Trend of new cases (in %) in the last 5 days: 6.8

# %% [markdown]
# ## Ravenna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ravenna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8855
# Total cases up to today: 738
# New cases registered today: 10
# New cases registered today in %: 1.37
# Doubling time in the last five days: 21.3
# Doubling time yesterday: 18.7
# Trend of new cases (in %) in the last 5 days: 17.7

# %% [markdown]
# ## Reggio nell'Emilia

# %%
calculate_and_create_chart_for_province(START_DATE, "Reggio nell'Emilia")
# Out:
# Total cases per 1000 inhabitants up to today: 6.0378
# Total cases up to today: 3215
# New cases registered today: 48
# New cases registered today in %: 1.52
# Doubling time in the last five days: 18.5
# Doubling time yesterday: 16.1
# Trend of new cases (in %) in the last 5 days: 20.64

# %% [markdown]
# ## Rimini

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rimini')
# Out:
# Total cases per 1000 inhabitants up to today: 4.7033
# Total cases up to today: 1584
# New cases registered today: 9
# New cases registered today in %: 0.57
# Doubling time in the last five days: 41.1
# Doubling time yesterday: 40.2
# Trend of new cases (in %) in the last 5 days: 8.79

# %% [markdown]
# # Casi di COVID-19 in Friuli Venezia Giulia - COVID-19 cases in Friuli Venezia Giulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Friuli Venezia Giulia')
# Out:
# Total cases up to today: 2145
# New cases registered today: 48
# New cases registered today in %: 2.29
# Doubling time in the last five days: 19.2
# Doubling time yesterday: 15.5
# Trend of new cases (in %) in the last 5 days: 19.83

# %% [markdown]
# ## Gorizia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Gorizia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.852
# Total cases up to today: 119
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 44.1
# Doubling time yesterday: 30.0
# Trend of new cases (in %) in the last 5 days: 8.18

# %% [markdown]
# ## Pordenone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pordenone')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5382
# Total cases up to today: 480
# New cases registered today: 3
# New cases registered today in %: 0.63
# Doubling time in the last five days: 40.9
# Doubling time yesterday: 26.7
# Trend of new cases (in %) in the last 5 days: 8.84

# %% [markdown]
# ## Trieste

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trieste')
# Out:
# Total cases per 1000 inhabitants up to today: 3.1234
# Total cases up to today: 733
# New cases registered today: 25
# New cases registered today in %: 3.53
# Doubling time in the last five days: 17.0
# Doubling time yesterday: 16.7
# Trend of new cases (in %) in the last 5 days: 22.58

# %% [markdown]
# ## Udine

# %%
calculate_and_create_chart_for_province(START_DATE, 'Udine')
# Out:
# Total cases per 1000 inhabitants up to today: 1.5297
# Total cases up to today: 813
# New cases registered today: 20
# New cases registered today in %: 2.52
# Doubling time in the last five days: 14.6
# Doubling time yesterday: 10.8
# Trend of new cases (in %) in the last 5 days: 26.83

# %% [markdown]
# # Casi di COVID-19 nel Lazio - COVID-19 cases in Lazio

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lazio')
# Out:
# Total cases up to today: 4117
# New cases registered today: 116
# New cases registered today in %: 2.9
# Doubling time in the last five days: 18.5
# Doubling time yesterday: 16.6
# Trend of new cases (in %) in the last 5 days: 20.59

# %% [markdown]
# ## Frosinone

# %%
calculate_and_create_chart_for_province(START_DATE, 'Frosinone')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8133
# Total cases up to today: 401
# New cases registered today: 27
# New cases registered today in %: 7.22
# Doubling time in the last five days: 19.0
# Doubling time yesterday: 27.0
# Trend of new cases (in %) in the last 5 days: 20.06

# %% [markdown]
# ## Latina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Latina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6192
# Total cases up to today: 356
# New cases registered today: 7
# New cases registered today in %: 2.01
# Doubling time in the last five days: 14.4
# Doubling time yesterday: 13.9
# Trend of new cases (in %) in the last 5 days: 27.14

# %% [markdown]
# ## Rieti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rieti')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7025
# Total cases up to today: 268
# New cases registered today: 2
# New cases registered today in %: 0.75
# Doubling time in the last five days: 9.8
# Doubling time yesterday: 10.8
# Trend of new cases (in %) in the last 5 days: 42.55

# %% [markdown]
# ## Roma

# %%
calculate_and_create_chart_for_province(START_DATE, 'Roma')
# Out:
# Total cases per 1000 inhabitants up to today: 0.65
# Total cases up to today: 2830
# New cases registered today: 61
# New cases registered today in %: 2.2
# Doubling time in the last five days: 20.7
# Doubling time yesterday: 17.1
# Trend of new cases (in %) in the last 5 days: 18.26

# %% [markdown]
# ## Viterbo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Viterbo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.8213
# Total cases up to today: 262
# New cases registered today: 19
# New cases registered today in %: 7.82
# Doubling time in the last five days: 19.3
# Doubling time yesterday: 15.0
# Trend of new cases (in %) in the last 5 days: 19.63

# %% [markdown]
# # Casi di COVID-19 in Liguria - COVID-19 cases in Liguria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Liguria')
# Out:
# Total cases up to today: 3796
# New cases registered today: 57
# New cases registered today in %: 1.52
# Doubling time in the last five days: 4.9
# Doubling time yesterday: 4.9
# Trend of new cases (in %) in the last 5 days: 103.21

# %% [markdown]
# ## Genova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Genova')
# Out:
# Total cases per 1000 inhabitants up to today: 2.5374
# Total cases up to today: 2157
# New cases registered today: 155
# New cases registered today in %: 7.74
# Doubling time in the last five days: 5.5
# Doubling time yesterday: 5.9
# Trend of new cases (in %) in the last 5 days: 87.08

# %% [markdown]
# ## Imperia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Imperia')
# Out:
# Total cases per 1000 inhabitants up to today: 3.1005
# Total cases up to today: 667
# New cases registered today: 75
# New cases registered today in %: 12.67
# Doubling time in the last five days: 3.1
# Doubling time yesterday: 3.6
# Trend of new cases (in %) in the last 5 days: 203.18

# %% [markdown]
# ## La Spezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'La Spezia')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0979
# Total cases up to today: 463
# New cases registered today: 13
# New cases registered today in %: 2.89
# Doubling time in the last five days: 5.6
# Doubling time yesterday: 5.7
# Trend of new cases (in %) in the last 5 days: 85.2

# %% [markdown]
# ## Savona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Savona')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8217
# Total cases up to today: 509
# New cases registered today: -186
# New cases registered today in %: -26.76
# Doubling time in the last five days: 4.7
# Doubling time yesterday: 3.4
# Trend of new cases (in %) in the last 5 days: 107.76

# %% [markdown]
# # Casi di COVID-19 in Lombardia - COVID-19 cases in Lombardy

# %%
calculate_and_create_chart_for_region(START_DATE, 'Lombardia')
# Out:
# Total cases up to today: 51178
# New cases registered today: 777
# New cases registered today in %: 1.54
# Doubling time in the last five days: 27.3
# Doubling time yesterday: 24.7
# Trend of new cases (in %) in the last 5 days: 13.55

# %% [markdown]
# ## Bergamo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bergamo')
# Out:
# Total cases per 1000 inhabitants up to today: 8.8906
# Total cases up to today: 9868
# New cases registered today: 53
# New cases registered today in %: 0.54
# Doubling time in the last five days: 47.3
# Doubling time yesterday: 42.1
# Trend of new cases (in %) in the last 5 days: 7.6

# %% [markdown]
# ## Brescia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brescia')
# Out:
# Total cases per 1000 inhabitants up to today: 7.6003
# Total cases up to today: 9594
# New cases registered today: 117
# New cases registered today in %: 1.23
# Doubling time in the last five days: 38.0
# Doubling time yesterday: 35.6
# Trend of new cases (in %) in the last 5 days: 9.56

# %% [markdown]
# ## Como

# %%
calculate_and_create_chart_for_province(START_DATE, 'Como')
# Out:
# Total cases per 1000 inhabitants up to today: 2.5409
# Total cases up to today: 1525
# New cases registered today: 52
# New cases registered today in %: 3.53
# Doubling time in the last five days: 14.7
# Doubling time yesterday: 14.4
# Trend of new cases (in %) in the last 5 days: 26.56

# %% [markdown]
# ## Cremona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cremona')
# Out:
# Total cases per 1000 inhabitants up to today: 12.0288
# Total cases up to today: 4323
# New cases registered today: 63
# New cases registered today in %: 1.48
# Doubling time in the last five days: 41.2
# Doubling time yesterday: 44.5
# Trend of new cases (in %) in the last 5 days: 8.78

# %% [markdown]
# ## Lecco

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecco')
# Out:
# Total cases per 1000 inhabitants up to today: 5.1026
# Total cases up to today: 1731
# New cases registered today: 19
# New cases registered today in %: 1.11
# Doubling time in the last five days: 31.8
# Doubling time yesterday: 28.5
# Trend of new cases (in %) in the last 5 days: 11.53

# %% [markdown]
# ## Lodi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lodi')
# Out:
# Total cases per 1000 inhabitants up to today: 10.1204
# Total cases up to today: 2321
# New cases registered today: 43
# New cases registered today in %: 1.89
# Doubling time in the last five days: 59.2
# Doubling time yesterday: 63.5
# Trend of new cases (in %) in the last 5 days: 6.03

# %% [markdown]
# ## Mantova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Mantova')
# Out:
# Total cases per 1000 inhabitants up to today: 5.1913
# Total cases up to today: 2142
# New cases registered today: 58
# New cases registered today in %: 2.78
# Doubling time in the last five days: 18.8
# Doubling time yesterday: 19.0
# Trend of new cases (in %) in the last 5 days: 20.2

# %% [markdown]
# ## Milano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Milano')
# Out:
# Total cases per 1000 inhabitants up to today: 3.6626
# Total cases up to today: 11787
# New cases registered today: 249
# New cases registered today in %: 2.16
# Doubling time in the last five days: 21.1
# Doubling time yesterday: 18.0
# Trend of new cases (in %) in the last 5 days: 17.82

# %% [markdown]
# ## Monza e della Brianza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Monza e della Brianza')
# Out:
# Total cases per 1000 inhabitants up to today: 3.6899
# Total cases up to today: 3206
# New cases registered today: 49
# New cases registered today in %: 1.55
# Doubling time in the last five days: 17.6
# Doubling time yesterday: 16.0
# Trend of new cases (in %) in the last 5 days: 21.76

# %% [markdown]
# ## Pavia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pavia')
# Out:
# Total cases per 1000 inhabitants up to today: 4.9977
# Total cases up to today: 2735
# New cases registered today: 35
# New cases registered today in %: 1.3
# Doubling time in the last five days: 19.3
# Doubling time yesterday: 16.2
# Trend of new cases (in %) in the last 5 days: 19.69

# %% [markdown]
# ## Sondrio

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sondrio')
# Out:
# Total cases per 1000 inhabitants up to today: 3.4172
# Total cases up to today: 620
# New cases registered today: 6
# New cases registered today in %: 0.98
# Doubling time in the last five days: 19.1
# Doubling time yesterday: 14.6
# Trend of new cases (in %) in the last 5 days: 19.92

# %% [markdown]
# ## Varese

# %%
calculate_and_create_chart_for_province(START_DATE, 'Varese')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4898
# Total cases up to today: 1326
# New cases registered today: 33
# New cases registered today in %: 2.55
# Doubling time in the last five days: 12.4
# Doubling time yesterday: 10.8
# Trend of new cases (in %) in the last 5 days: 32.34

# %% [markdown]
# # Casi di COVID-19 nelle Marche - COVID-19 cases in Marche

# %%
calculate_and_create_chart_for_region(START_DATE, 'Marche')
# Out:
# Total cases up to today: 4598
# New cases registered today: 92
# New cases registered today in %: 2.04
# Doubling time in the last five days: 25.4
# Doubling time yesterday: 23.5
# Trend of new cases (in %) in the last 5 days: 14.63

# %% [markdown]
# ## Ancona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ancona')
# Out:
# Total cases per 1000 inhabitants up to today: 3.014
# Total cases up to today: 1429
# New cases registered today: 28
# New cases registered today in %: 2.0
# Doubling time in the last five days: 20.9
# Doubling time yesterday: 19.6
# Trend of new cases (in %) in the last 5 days: 18.0

# %% [markdown]
# ## Ascoli Piceno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ascoli Piceno')
# Out:
# Total cases per 1000 inhabitants up to today: 1.122
# Total cases up to today: 235
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 100.1
# Doubling time yesterday: 72.3
# Trend of new cases (in %) in the last 5 days: 3.52

# %% [markdown]
# ## Fermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Fermo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7958
# Total cases up to today: 314
# New cases registered today: 2
# New cases registered today in %: 0.64
# Doubling time in the last five days: 34.5
# Doubling time yesterday: 20.3
# Trend of new cases (in %) in the last 5 days: 10.56

# %% [markdown]
# ## Macerata

# %%
calculate_and_create_chart_for_province(START_DATE, 'Macerata')
# Out:
# Total cases per 1000 inhabitants up to today: 2.082
# Total cases up to today: 664
# New cases registered today: 25
# New cases registered today in %: 3.91
# Doubling time in the last five days: 15.8
# Doubling time yesterday: 14.9
# Trend of new cases (in %) in the last 5 days: 24.58

# %% [markdown]
# ## Pesaro e Urbino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pesaro e Urbino')
# Out:
# Total cases per 1000 inhabitants up to today: 5.4226
# Total cases up to today: 1956
# New cases registered today: 37
# New cases registered today in %: 1.93
# Doubling time in the last five days: 32.1
# Doubling time yesterday: 32.0
# Trend of new cases (in %) in the last 5 days: 11.39

# %% [markdown]
# # Casi di COVID-19 in Molise - COVID-19 cases in Molise¶

# %%
calculate_and_create_chart_for_region(START_DATE, 'Molise')
# Out:
# Total cases up to today: 209
# New cases registered today: -1
# New cases registered today in %: -0.48
# Doubling time in the last five days: 11.1
# Doubling time yesterday: 10.1
# Trend of new cases (in %) in the last 5 days: 36.6

# %% [markdown]
# ## Campobasso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Campobasso')
# Out:
# Total cases per 1000 inhabitants up to today: 0.7389
# Total cases up to today: 166
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 22.2
# Doubling time yesterday: 19.5
# Trend of new cases (in %) in the last 5 days: 16.9

# %% [markdown]
# ## Isernia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Isernia')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5011
# Total cases up to today: 43
# New cases registered today: -1
# New cases registered today in %: -2.27
# Doubling time in the last five days: 2.5
# Doubling time yesterday: 2.3
# Trend of new cases (in %) in the last 5 days: 290.91

# %% [markdown]
# # Casi di COVID-19 in Piemonte - COVID-19 cases in Piedmont

# %%
calculate_and_create_chart_for_region(START_DATE, 'Piemonte')
# Out:
# Total cases up to today: 13096
# New cases registered today: 411
# New cases registered today in %: 3.24
# Doubling time in the last five days: 13.5
# Doubling time yesterday: 12.4
# Trend of new cases (in %) in the last 5 days: 29.22

# %% [markdown]
# ## Alessandria

# %%
calculate_and_create_chart_for_province(START_DATE, 'Alessandria')
# Out:
# Total cases per 1000 inhabitants up to today: 4.561
# Total cases up to today: 1946
# New cases registered today: 42
# New cases registered today in %: 2.21
# Doubling time in the last five days: 11.2
# Doubling time yesterday: 10.7
# Trend of new cases (in %) in the last 5 days: 36.27

# %% [markdown]
# ## Asti

# %%
calculate_and_create_chart_for_province(START_DATE, 'Asti')
# Out:
# Total cases per 1000 inhabitants up to today: 2.9029
# Total cases up to today: 629
# New cases registered today: 20
# New cases registered today in %: 3.28
# Doubling time in the last five days: 15.2
# Doubling time yesterday: 12.4
# Trend of new cases (in %) in the last 5 days: 25.55

# %% [markdown]
# ## Biella

# %%
calculate_and_create_chart_for_province(START_DATE, 'Biella')
# Out:
# Total cases per 1000 inhabitants up to today: 3.31
# Total cases up to today: 591
# New cases registered today: 8
# New cases registered today in %: 1.37
# Doubling time in the last five days: 28.4
# Doubling time yesterday: 23.5
# Trend of new cases (in %) in the last 5 days: 13.0

# %% [markdown]
# ## Cuneo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cuneo')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0149
# Total cases up to today: 1187
# New cases registered today: 52
# New cases registered today in %: 4.58
# Doubling time in the last five days: 9.6
# Doubling time yesterday: 9.2
# Trend of new cases (in %) in the last 5 days: 43.7

# %% [markdown]
# ## Novara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Novara')
# Out:
# Total cases per 1000 inhabitants up to today: 2.8989
# Total cases up to today: 1073
# New cases registered today: 65
# New cases registered today in %: 6.45
# Doubling time in the last five days: 20.0
# Doubling time yesterday: 20.9
# Trend of new cases (in %) in the last 5 days: 18.96

# %% [markdown]
# ## Torino

# %%
calculate_and_create_chart_for_province(START_DATE, 'Torino')
# Out:
# Total cases per 1000 inhabitants up to today: 2.7987
# Total cases up to today: 6375
# New cases registered today: 195
# New cases registered today in %: 3.16
# Doubling time in the last five days: 14.2
# Doubling time yesterday: 12.8
# Trend of new cases (in %) in the last 5 days: 27.73

# %% [markdown]
# ## 	Verbano-Cusio-Ossola

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verbano-Cusio-Ossola')
# Out:
# Total cases per 1000 inhabitants up to today: 3.9458
# Total cases up to today: 630
# New cases registered today: 11
# New cases registered today in %: 1.78
# Doubling time in the last five days: 9.9
# Doubling time yesterday: 8.4
# Trend of new cases (in %) in the last 5 days: 41.89

# %% [markdown]
# ## Vercelli

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vercelli')
# Out:
# Total cases per 1000 inhabitants up to today: 3.8247
# Total cases up to today: 665
# New cases registered today: 18
# New cases registered today in %: 2.78
# Doubling time in the last five days: 14.1
# Doubling time yesterday: 12.3
# Trend of new cases (in %) in the last 5 days: 27.88

# %% [markdown]
# # Casi di COVID-19 in Puglia - COVID-19 cases in Apulia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Puglia')
# Out:
# Total cases up to today: 2484
# New cases registered today: 70
# New cases registered today in %: 2.9
# Doubling time in the last five days: 18.1
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 21.05

# %% [markdown]
# ## Bari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Bari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6618
# Total cases up to today: 834
# New cases registered today: 27
# New cases registered today in %: 3.35
# Doubling time in the last five days: 19.8
# Doubling time yesterday: 16.6
# Trend of new cases (in %) in the last 5 days: 19.14

# %% [markdown]
# ## 	Barletta-Andria-Trani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Barletta-Andria-Trani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4509
# Total cases up to today: 177
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 10.2
# Doubling time yesterday: 8.2
# Trend of new cases (in %) in the last 5 days: 40.48

# %% [markdown]
# ## Brindisi

# %%
calculate_and_create_chart_for_province(START_DATE, 'Brindisi')
# Out:
# Total cases per 1000 inhabitants up to today: 0.6598
# Total cases up to today: 262
# New cases registered today: 5
# New cases registered today in %: 1.95
# Doubling time in the last five days: 15.0
# Doubling time yesterday: 11.7
# Trend of new cases (in %) in the last 5 days: 25.96

# %% [markdown]
# ## Foggia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Foggia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.0103
# Total cases up to today: 635
# New cases registered today: 30
# New cases registered today in %: 4.96
# Doubling time in the last five days: 14.7
# Doubling time yesterday: 16.4
# Trend of new cases (in %) in the last 5 days: 26.49

# %% [markdown]
# ## Lecce

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lecce')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4788
# Total cases up to today: 384
# New cases registered today: 6
# New cases registered today in %: 1.59
# Doubling time in the last five days: 41.2
# Doubling time yesterday: 21.2
# Trend of new cases (in %) in the last 5 days: 8.78

# %% [markdown]
# ## Taranto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Taranto')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3291
# Total cases up to today: 192
# New cases registered today: 2
# New cases registered today in %: 1.05
# Doubling time in the last five days: 21.2
# Doubling time yesterday: 13.9
# Trend of new cases (in %) in the last 5 days: 17.79

# %% [markdown]
# # Casi di COVID-19 in Sardegna - COVID-19 cases in Sardinia

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sardegna')
# Out:
# Total cases up to today: 935
# New cases registered today: 13
# New cases registered today in %: 1.41
# Doubling time in the last five days: 21.2
# Doubling time yesterday: 16.3
# Trend of new cases (in %) in the last 5 days: 17.76

# %% [markdown]
# ## Cagliari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Cagliari')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2641
# Total cases up to today: 148
# New cases registered today: 2
# New cases registered today in %: 1.37
# Doubling time in the last five days: 21.5
# Doubling time yesterday: 15.1
# Trend of new cases (in %) in the last 5 days: 17.46

# %% [markdown]
# ## Nuoro

# %%
calculate_and_create_chart_for_province(START_DATE, 'Nuoro')
# Out:
# Total cases per 1000 inhabitants up to today: 0.4164
# Total cases up to today: 65
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 43.3
# Doubling time yesterday: 35.8
# Trend of new cases (in %) in the last 5 days: 8.33

# %% [markdown]
# ## Oristano

# %%
calculate_and_create_chart_for_province(START_DATE, 'Oristano')
# Out:
# Total cases per 1000 inhabitants up to today: 0.1742
# Total cases up to today: 28
# New cases registered today: 1
# New cases registered today in %: 3.7
# Doubling time in the last five days: 7.8
# Doubling time yesterday: 5.9
# Trend of new cases (in %) in the last 5 days: 55.56

# %% [markdown]
# ## Sassari

# %%
calculate_and_create_chart_for_province(START_DATE, 'Sassari')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8612
# Total cases up to today: 620
# New cases registered today: 10
# New cases registered today in %: 1.64
# Doubling time in the last five days: 21.6
# Doubling time yesterday: 16.9
# Trend of new cases (in %) in the last 5 days: 17.42

# %% [markdown]
# # Casi di COVID-19 in Sicilia - COVID-19 cases in Sicily

# %%
calculate_and_create_chart_for_region(START_DATE, 'Sicilia')
# Out:
# Total cases up to today: 2097
# New cases registered today: 51
# New cases registered today in %: 2.49
# Doubling time in the last five days: 22.0
# Doubling time yesterday: 19.8
# Trend of new cases (in %) in the last 5 days: 17.09

# %% [markdown]
# ## Agrigento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Agrigento')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2488
# Total cases up to today: 110
# New cases registered today: 1
# New cases registered today in %: 0.92
# Doubling time in the last five days: 30.0
# Doubling time yesterday: 27.3
# Trend of new cases (in %) in the last 5 days: 12.24

# %% [markdown]
# ## Caltanissetta

# %%
calculate_and_create_chart_for_province(START_DATE, 'Caltanissetta')
# Out:
# Total cases per 1000 inhabitants up to today: 0.3893
# Total cases up to today: 105
# New cases registered today: 1
# New cases registered today in %: 0.96
# Doubling time in the last five days: 12.7
# Doubling time yesterday: 11.0
# Trend of new cases (in %) in the last 5 days: 31.25

# %% [markdown]
# ## Catania

# %%
calculate_and_create_chart_for_province(START_DATE, 'Catania')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5659
# Total cases up to today: 630
# New cases registered today: 16
# New cases registered today in %: 2.61
# Doubling time in the last five days: 23.6
# Doubling time yesterday: 18.7
# Trend of new cases (in %) in the last 5 days: 15.81

# %% [markdown]
# ## Enna

# %%
calculate_and_create_chart_for_province(START_DATE, 'Enna')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7197
# Total cases up to today: 289
# New cases registered today: 2
# New cases registered today in %: 0.7
# Doubling time in the last five days: 17.9
# Doubling time yesterday: 14.0
# Trend of new cases (in %) in the last 5 days: 21.43

# %% [markdown]
# ## Messina

# %%
calculate_and_create_chart_for_province(START_DATE, 'Messina')
# Out:
# Total cases per 1000 inhabitants up to today: 0.5812
# Total cases up to today: 370
# New cases registered today: 8
# New cases registered today in %: 2.21
# Doubling time in the last five days: 25.5
# Doubling time yesterday: 27.4
# Trend of new cases (in %) in the last 5 days: 14.55

# %% [markdown]
# ## Palermo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Palermo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.25
# Total cases up to today: 317
# New cases registered today: 16
# New cases registered today in %: 5.32
# Doubling time in the last five days: 29.6
# Doubling time yesterday: 40.0
# Trend of new cases (in %) in the last 5 days: 12.41

# %% [markdown]
# ## Ragusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Ragusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.168
# Total cases up to today: 54
# New cases registered today: 0
# New cases registered today in %: 0.0
# Doubling time in the last five days: 19.0
# Doubling time yesterday: 16.9
# Trend of new cases (in %) in the last 5 days: 20.0

# %% [markdown]
# ## Siracusa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siracusa')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2805
# Total cases up to today: 113
# New cases registered today: 2
# New cases registered today in %: 1.8
# Doubling time in the last five days: 30.9
# Doubling time yesterday: 27.8
# Trend of new cases (in %) in the last 5 days: 11.88

# %% [markdown]
# ## Trapani

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trapani')
# Out:
# Total cases per 1000 inhabitants up to today: 0.2509
# Total cases up to today: 109
# New cases registered today: 5
# New cases registered today in %: 4.81
# Doubling time in the last five days: 11.2
# Doubling time yesterday: 10.6
# Trend of new cases (in %) in the last 5 days: 36.25

# %% [markdown]
# # Casi di COVID-19 in Toscana - COVID-19 cases in Tuscany

# %%
calculate_and_create_chart_for_region(START_DATE, 'Toscana')
# Out:
# Total cases up to today: 6173
# New cases registered today: 172
# New cases registered today in %: 2.87
# Doubling time in the last five days: 22.0
# Doubling time yesterday: 16.5
# Trend of new cases (in %) in the last 5 days: 17.07

# %% [markdown]
# ## Arezzo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Arezzo')
# Out:
# Total cases per 1000 inhabitants up to today: 1.1499
# Total cases up to today: 396
# New cases registered today: 9
# New cases registered today in %: 2.33
# Doubling time in the last five days: 33.4
# Doubling time yesterday: 28.7
# Trend of new cases (in %) in the last 5 days: 10.92

# %% [markdown]
# ## Firenze

# %%
calculate_and_create_chart_for_province(START_DATE, 'Firenze')
# Out:
# Total cases per 1000 inhabitants up to today: 1.7793
# Total cases up to today: 1805
# New cases registered today: 36
# New cases registered today in %: 2.04
# Doubling time in the last five days: 14.4
# Doubling time yesterday: 8.2
# Trend of new cases (in %) in the last 5 days: 27.2

# %% [markdown]
# ## Grosseto

# %%
calculate_and_create_chart_for_province(START_DATE, 'Grosseto')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3002
# Total cases up to today: 290
# New cases registered today: 6
# New cases registered today in %: 2.11
# Doubling time in the last five days: 36.9
# Doubling time yesterday: 45.1
# Trend of new cases (in %) in the last 5 days: 9.85

# %% [markdown]
# ## Livorno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Livorno')
# Out:
# Total cases per 1000 inhabitants up to today: 0.996
# Total cases up to today: 336
# New cases registered today: 13
# New cases registered today in %: 4.02
# Doubling time in the last five days: 31.5
# Doubling time yesterday: 38.2
# Trend of new cases (in %) in the last 5 days: 11.63

# %% [markdown]
# ## Lucca

# %%
calculate_and_create_chart_for_province(START_DATE, 'Lucca')
# Out:
# Total cases per 1000 inhabitants up to today: 2.3587
# Total cases up to today: 920
# New cases registered today: 32
# New cases registered today in %: 3.6
# Doubling time in the last five days: 25.2
# Doubling time yesterday: 24.5
# Trend of new cases (in %) in the last 5 days: 14.71

# %% [markdown]
# ## Massa Carrara

# %%
calculate_and_create_chart_for_province(START_DATE, 'Massa Carrara')
# Out:
# Total cases per 1000 inhabitants up to today: 3.7338
# Total cases up to today: 734
# New cases registered today: 36
# New cases registered today in %: 5.16
# Doubling time in the last five days: 26.5
# Doubling time yesterday: 26.0
# Trend of new cases (in %) in the last 5 days: 13.98

# %% [markdown]
# ## Pisa

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pisa')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3844
# Total cases up to today: 584
# New cases registered today: 24
# New cases registered today in %: 4.29
# Doubling time in the last five days: 27.6
# Doubling time yesterday: 26.4
# Trend of new cases (in %) in the last 5 days: 13.4

# %% [markdown]
# ## Pistoia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Pistoia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3843
# Total cases up to today: 404
# New cases registered today: 4
# New cases registered today in %: 1.0
# Doubling time in the last five days: 22.4
# Doubling time yesterday: 18.9
# Trend of new cases (in %) in the last 5 days: 16.76

# %% [markdown]
# ## Prato

# %%
calculate_and_create_chart_for_province(START_DATE, 'Prato')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3511
# Total cases up to today: 344
# New cases registered today: 2
# New cases registered today in %: 0.58
# Doubling time in the last five days: 20.7
# Doubling time yesterday: 21.0
# Trend of new cases (in %) in the last 5 days: 18.21

# %% [markdown]
# ## Siena

# %%
calculate_and_create_chart_for_province(START_DATE, 'Siena')
# Out:
# Total cases per 1000 inhabitants up to today: 1.3416
# Total cases up to today: 360
# New cases registered today: 10
# New cases registered today in %: 2.86
# Doubling time in the last five days: 46.2
# Doubling time yesterday: 30.2
# Trend of new cases (in %) in the last 5 days: 7.78

# %% [markdown]
# # Casi di COVID-19 in Provincia Autonoma di Trento - COVID-19 cases in the Autonomous Province of Trento

# %%
calculate_and_create_chart_for_province(START_DATE, 'Trento')
# Out:
# Total cases per 1000 inhabitants up to today: 4.5971
# Total cases up to today: 2476
# New cases registered today: 128
# New cases registered today in %: 5.45
# Doubling time in the last five days: 16.3
# Doubling time yesterday: 15.2
# Trend of new cases (in %) in the last 5 days: 23.61

# %% [markdown]
# # Casi di COVID-19 in Umbria - COVID-19 cases in Umbria

# %%
calculate_and_create_chart_for_region(START_DATE, 'Umbria')
# Out:
# Total cases up to today: 1221
# New cases registered today: 8
# New cases registered today in %: 0.66
# Doubling time in the last five days: 30.5
# Doubling time yesterday: 25.3
# Trend of new cases (in %) in the last 5 days: 12.02

# %% [markdown]
# ## Perugia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Perugia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.4122
# Total cases up to today: 933
# New cases registered today: 4
# New cases registered today in %: 0.43
# Doubling time in the last five days: 34.6
# Doubling time yesterday: 28.3
# Trend of new cases (in %) in the last 5 days: 10.55

# %% [markdown]
# ## Terni

# %%
calculate_and_create_chart_for_province(START_DATE, 'Terni')
# Out:
# Total cases per 1000 inhabitants up to today: 1.262
# Total cases up to today: 288
# New cases registered today: 4
# New cases registered today in %: 1.41
# Doubling time in the last five days: 22.0
# Doubling time yesterday: 18.7
# Trend of new cases (in %) in the last 5 days: 17.07

# %% [markdown]
# # Casi di COVID-19 in Valle d'Aosta - COVID-19 cases in Aosta Valley

# %%
calculate_and_create_chart_for_province(START_DATE, "Aosta")
# Out:
# Total cases per 1000 inhabitants up to today: 6.5809
# Total cases up to today: 835
# New cases registered today: 30
# New cases registered today in %: 3.73
# Doubling time in the last five days: 15.5
# Doubling time yesterday: 14.2
# Trend of new cases (in %) in the last 5 days: 25.0

# %% [markdown]
# # Casi di COVID-19 in Veneto - COVID-19 cases in Veneto

# %%
calculate_and_create_chart_for_region(START_DATE, 'Veneto')
# Out:
# Total cases up to today: 11631
# New cases registered today: 335
# New cases registered today in %: 2.97
# Doubling time in the last five days: 21.1
# Doubling time yesterday: 18.5
# Trend of new cases (in %) in the last 5 days: 17.89

# %% [markdown]
# ## Belluno

# %%
calculate_and_create_chart_for_province(START_DATE, 'Belluno')
# Out:
# Total cases per 1000 inhabitants up to today: 2.804
# Total cases up to today: 577
# New cases registered today: 19
# New cases registered today in %: 3.41
# Doubling time in the last five days: 20.4
# Doubling time yesterday: 17.9
# Trend of new cases (in %) in the last 5 days: 18.48

# %% [markdown]
# ## Padova

# %%
calculate_and_create_chart_for_province(START_DATE, 'Padova')
# Out:
# Total cases per 1000 inhabitants up to today: 3.1668
# Total cases up to today: 2965
# New cases registered today: 102
# New cases registered today in %: 3.56
# Doubling time in the last five days: 19.8
# Doubling time yesterday: 18.3
# Trend of new cases (in %) in the last 5 days: 19.12

# %% [markdown]
# ## Rovigo

# %%
calculate_and_create_chart_for_province(START_DATE, 'Rovigo')
# Out:
# Total cases per 1000 inhabitants up to today: 0.9137
# Total cases up to today: 218
# New cases registered today: 15
# New cases registered today in %: 7.39
# Doubling time in the last five days: 9.6
# Doubling time yesterday: 9.3
# Trend of new cases (in %) in the last 5 days: 43.42

# %% [markdown]
# ## Treviso

# %%
calculate_and_create_chart_for_province(START_DATE, 'Treviso')
# Out:
# Total cases per 1000 inhabitants up to today: 1.9617
# Total cases up to today: 1738
# New cases registered today: 12
# New cases registered today in %: 0.7
# Doubling time in the last five days: 43.9
# Doubling time yesterday: 33.0
# Trend of new cases (in %) in the last 5 days: 8.22

# %% [markdown]
# ## Venezia

# %%
calculate_and_create_chart_for_province(START_DATE, 'Venezia')
# Out:
# Total cases per 1000 inhabitants up to today: 1.8062
# Total cases up to today: 1543
# New cases registered today: 56
# New cases registered today in %: 3.77
# Doubling time in the last five days: 19.6
# Doubling time yesterday: 18.3
# Trend of new cases (in %) in the last 5 days: 19.33

# %% [markdown]
# ## Verona

# %%
calculate_and_create_chart_for_province(START_DATE, 'Verona')
# Out:
# Total cases per 1000 inhabitants up to today: 3.0991
# Total cases up to today: 2856
# New cases registered today: 101
# New cases registered today in %: 3.67
# Doubling time in the last five days: 20.2
# Doubling time yesterday: 18.6
# Trend of new cases (in %) in the last 5 days: 18.75

# %% [markdown]
# ## Vicenza

# %%
calculate_and_create_chart_for_province(START_DATE, 'Vicenza')
# Out:
# Total cases per 1000 inhabitants up to today: 2.0044
# Total cases up to today: 1734
# New cases registered today: 30
# New cases registered today in %: 1.76
# Doubling time in the last five days: 18.2
# Doubling time yesterday: 13.9
# Trend of new cases (in %) in the last 5 days: 20.92
